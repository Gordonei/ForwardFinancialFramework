# %% [markdown]
# # Model Verification Experiment

# %% [markdown]
# Aim:
# * Verify that the approach to modelling the runtime characteristics of execution of a large portfolio of pricing tasks upon a large set of platforms is correct

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Tasks

# %% [markdown]
# The options all have non-zero values for reasonably small numbers of tasks

# %%
import csv

options = []
with open('valid_seeds_file.csv','r') as valid_seeds_file:
    csvreader = csv.DictReader(valid_seeds_file,delimiter=',')
    options = [row for row in csvreader]

# %%
tasks = {}
for o in options:
    temp_task = "%s %s"%(o['underlying'],o['option'])
    if(temp_task not in tasks): tasks[temp_task] = 0
    tasks[temp_task] += 1
    
print("Portfolio of Option Pricing Tasks")
total = 0
for t in sorted(tasks):
    print("%s: %d"%(t,tasks[t]))
    total += tasks[t]
    
print("total tasks:%d"%total)
# Out:
# Portfolio of Option Pricing Tasks
# black_scholes asian: 10
# black_scholes barrier: 10
# black_scholes digital_double_barrier: 5
# black_scholes double_barrier: 10
# heston asian: 25
# heston barrier: 29
# heston digital_double_barrier: 5
# heston double_barrier: 29
# heston european: 5
# total tasks:128

# %%
import ForwardFinancialFramework.bin.option_generator as option_generator

option_tasks = [option_generator.generate_option(int(o['seed']),underlying_type=o['underlying'],option_type=o['option']) for o in options]

# %% [markdown]
# Importing necessary libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import csv

# %% [markdown]
# ## Method

# %% [markdown]
# Model Verification Procedure:
# 1. Run each task for up to (5 minutes)/128 on each platform
# 2. Generate Latency, Accuracy and Latency-Accuracy models for each task.
# 3. Combine the task models for each platform and make a prediction curve for the region of interest [5x2,5x4,5x8,5x16]
# 4. Run verification experiments so as to find that region of interest

# %% [markdown]
# ## Analysis

# %% [markdown]
# #### (1) Benchmark Runs

# %% [markdown]
# Reading data from benchmark runs

# %%
with open('benchmark_data_complete2_3000.csv','r') as benchmark_file:
    csvreader = csv.reader(benchmark_file,delimiter=',')
    
    headings = csvreader.next()
    heading_tuples = [(h,"a30") for h in headings]
    
    data = []
    for row in csvreader: data.append(tuple(row))
            
    data = numpy.array(data,dtype=heading_tuples)

# %% [markdown]
# Generating the list of platforms

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms += [(platform,platform_type)]
    print platforms[-1]
# Out:
# ('', 'multicore_cpu')
# ('ee-snowball2', 'opencl_alterafpga')
# ('phi', 'opencl_gpu')
# ('ee-snowball0', 'opencl_gpu')
# ('amazon-gpu-0', 'opencl_gpu')
# ('amazon-gpu-1', 'opencl_gpu')
# ('amazon-cpu-0', 'multicore_cpu')
# ('amazon-cpu-1', 'multicore_cpu')
# ('ee-snowball1', 'opencl_gpu')
# ('ee-benjamin', 'multicore_cpu')
# ('pi', 'multicore_cpu')
# ('ee-mollie', 'maxeler_fpga')

# %% [markdown]
# #### (2) Generating Models

# %% [markdown]
# ##### Latency Models

# %% [markdown]
# Two sets of data need to be selected:
# * All of the paths and latency data for a particular task
# * All of the paths and latency data under the benchmarking time limit (300S/128) which will be used to create the model

# %% [markdown]
# Latency as a function of the number of simulations. This is a simple linear model - a single degree per simulation component and a constant setup component.

# %%
def generate_latency_model(paths,latency):
    latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
    latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
    
    return lambda N: latency_model_coefficients[0]*N+latency_model_coefficients[1]

# %% [markdown]
# Calculating the relative and absolute errors for the latency model. The error is the verification latency recorded minus the value predicted by the model. An error > 0 means that the model is *underestimating* the simulations required to achieve that latency. An error < 0 means that the model is *overestimating* the latency required.

# %%
relative_latency_errors = []
absolute_latency_errors = []
verification_paths = []

platforms_interest = [(platform,platform_type) for platform,platform_type in platforms[:]] # if ("phi" not in platform and "opencl_gpu" not in platform_type)
for platform,platform_type in platforms_interest:
    print(platform,platform_type)
    relative_latency_errors += [[]]
    absolute_latency_errors += [[]]
    verification_paths += [[]]
    
    benchmark_paths = []
    for t in range(len(option_tasks[:])):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"]==str(t)
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #limiting to the benchmarking time
        
        paths = data[selection]["Paths"].astype(numpy.float)
        latency = data[selection]["Latency"].astype(numpy.float)
        latency_model = generate_latency_model(paths,latency)

        verification_path = data[verification_selection]["Paths"].astype(numpy.float)
        verification_latency = data[verification_selection]["Latency"].astype(numpy.float)
        
        error = (numpy.array(verification_latency-numpy.array([latency_model(p) for p in verification_path])))
        if not(numpy.any(numpy.isnan(error))or numpy.any(numpy.isinf(error))):
            benchmark_paths += [numpy.max(paths)]
            verification_paths[-1] += [verification_path]
            absolute_latency_errors[-1] += [error]
            relative_latency_errors[-1] += [error/verification_latency]
    
    #Find the number of benchmark paths used across the tasks
    benchmark_paths = numpy.min(benchmark_paths)
    
    #massage error arrays down to same size
    max_length = min([len(errors) for errors in relative_latency_errors[-1]])
    
    temp_errors = relative_latency_errors[-1][:]
    relative_latency_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    temp_paths = verification_paths[-1][:]
    verification_paths[-1] = numpy.array([tp[:max_length]/benchmark_paths for tp in temp_paths])
    
    temp_errors = absolute_latency_errors[-1][:]
    absolute_latency_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    print(verification_paths[-1].shape,relative_latency_errors[-1].shape,absolute_latency_errors[-1].shape)
# Out:
# ('', 'multicore_cpu')
# ((128, 16), (128, 16), (128, 16))
# ('ee-snowball2', 'opencl_alterafpga')
# ((128, 21), (128, 21), (128, 21))
# ('phi', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('phi', 'opencl_gpu')
# ((128, 16), (128, 16), (128, 16))
# ('ee-snowball0', 'opencl_gpu')
# ((128, 22), (128, 22), (128, 22))
# ('amazon-gpu-0', 'multicore_cpu')
# ((128, 16), (128, 16), (128, 16))
# ('amazon-gpu-0', 'opencl_gpu')
# ((128, 23), (128, 23), (128, 23))
# ('amazon-gpu-1', 'multicore_cpu')
# ((128, 15), (128, 15), (128, 15))
# ('amazon-gpu-1', 'opencl_gpu')
# ((128, 23), (128, 23), (128, 23))
# ('amazon-cpu-0', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('amazon-cpu-1', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('ee-snowball1', 'opencl_gpu')
# ((128, 22), (128, 22), (128, 22))
# ('ee-benjamin', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('pi', 'multicore_cpu')
# ((128, 9), (128, 9), (128, 9))
# ('ee-mollie', 'multicore_cpu')
# ((128, 15), (128, 15), (128, 15))
# ('ee-mollie', 'maxeler_fpga')
# ((128, 21), (128, 21), (128, 21))

# %% [markdown]
# The relative latency error across the platforms shows a fair amount of variation in the benchmark region, but relatively speaking is surprisingly low outside of it. An explanation for this is that the primary source of error in latency model is in the constant setup component of the model, which is suspetable to multiple sources of noise (OS, network probably being the main culprits).

# %%
f, (ax1, ax2) = plt.subplots(2,sharex=True)

#Top plot
for i,(platform,platform_type) in enumerate(platforms_interest):
    ax1.plot(verification_paths[i][0],100*numpy.mean(relative_latency_errors[i],axis=0),"-x",label=platform+"("+ platform_type+")") #paths should all be the same
    
ax1.axvspan(1, 1,facecolor='g', alpha=1)

#ax1.set_xlabel("Runtime to Benchmark time Ratio")
ax1.set_xscale('log')
ax1.set_ylabel("Relative Latency Error (%)")
#ax1.set_yscale('log')
ax1.set_ylim((-100,100))

#Bottom plot
for i,(platform,platform_type) in enumerate(platforms_interest):
    ax2.plot(verification_paths[i][0],numpy.abs(numpy.mean(absolute_latency_errors[i],axis=0)),"-x",label=platform+"("+ platform_type+")") #paths should all be the same
    
ax2.axvspan(1, 1,facecolor='g', alpha=1)

ax2.set_xlabel("Runtime to Benchmark time Ratio")
ax2.set_xscale('log')
ax2.set_ylabel("Absolute Latency Error (S)")
#ax2.set_ylim((-0.1,0.1))
ax2.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,21)

plt.legend(loc="best")

# %% [markdown]
# ##### Looking at a single Platfom-Latency Pair

# %%
platform = "ee-snowball1"
platform_type = "opencl_gpu"
task = "0"

verification_selection = numpy.logical_and(numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type),data["Task"]==task)
verification_paths = data[verification_selection]["Paths"].astype(numpy.float)
verification_latency = data[verification_selection]["Latency"].astype(numpy.float)

selection = numpy.logical_and(numpy.logical_and(numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type),data["Task"]==task),data["Latency"].astype(numpy.float) < 300.0/128)
paths = data[selection]["Paths"].astype(numpy.float)
latency = data[selection]["Latency"].astype(numpy.float)

# %%
latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
latency_model = lambda N: latency_model_coefficients[0]*N + latency_model_coefficients[1]

# %%
plt.plot(verification_latency,100*abs(numpy.array(map(latency_model,verification_paths))-verification_latency)/verification_latency,"r-x")
plt.axvspan(latency[-1], latency[-1], facecolor='g', alpha=1)

ax = plt.gca()
ax.set_xlabel("Latency (S)")
ax.set_xscale('log')
ax.set_ylabel("Relative Latency Error (%)")
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %% [markdown]
# ##### Accuracy Model

# %% [markdown]
# Function for generating accuracy model

# %%
def generate_accuracy_model(paths,accuracy):
    accuracy_model_data = numpy.column_stack((paths**-0.5,numpy.zeros(len(paths))))
    accuracy_model_coefficients = numpy.linalg.lstsq(accuracy_model_data,accuracy)[0]
    
    return lambda N: accuracy_model_coefficients[0]*N**-0.5

# %% [markdown]
# Calculating the relative and absolute accuracy models. The error is the actual 95% confidence interval measured versus what is the 95% confidence interval predicted by the model for that number of simulations. An error > 0 indicates that the model has *overestimated* the number of simulations required to achieve that level of accuracy, while an error < 0 indicates that the model has *underestimated* the simulations required.
#
# The relative error performance will be limited by any inherent bias in the model.

# %%
relative_accuracy_errors = []
absolute_accuracy_errors = []
verification_paths = []

platforms_interest = [(platform,platform_type) for platform,platform_type in platforms[:]] #if ("phi" not in platform and "opencl_gpu" not in platform_type)
for platform,platform_type in platforms_interest:
    print(platform,platform_type)
    absolute_accuracy_errors += [[]]
    relative_accuracy_errors += [[]]
    verification_paths += [[]]
    
    benchmark_paths = []
    for t in range(len(option_tasks[:])):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"]==str(t)
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #limiting to the benchmarking time
        
        paths = data[selection]["Paths"].astype(numpy.float)
        accuracy = data[selection]["Accuracy"].astype(numpy.float)
        accuracy_model = generate_accuracy_model(paths,accuracy)

        verification_path = data[verification_selection]["Paths"].astype(numpy.float)
        verification_accuracy = data[verification_selection]["Accuracy"].astype(numpy.float)
        
        
        error = (numpy.array(verification_accuracy-numpy.array([accuracy_model(p) for p in verification_path])))
        #print(error)
        if not(numpy.any(numpy.isnan(error))or numpy.any(numpy.isinf(error))):
            benchmark_paths += [max(paths)]
            verification_paths[-1] += [verification_path]
            absolute_accuracy_errors[-1] += [error]
        else: print(t)
        
        if not(numpy.any(error==0.0) or numpy.any(verification_accuracy==0.0) or numpy.any(numpy.isnan(error))): 
            relative_accuracy_errors[-1] += [error/verification_accuracy]
        else: print(t)
        
            
    #Find the number of benchmark paths used across the tasks
    benchmark_paths = numpy.min(benchmark_paths)
    
    #massage down to same size
    max_length = min([len(errors) for errors in relative_accuracy_errors[-1]])
    
    temp_errors = relative_accuracy_errors[-1][:]
    relative_accuracy_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    temp_paths = verification_paths[-1][:]
    verification_paths[-1] = numpy.array([tp[:max_length]/benchmark_paths for tp in temp_paths])
    
    temp_errors = absolute_accuracy_errors[-1][:]
    absolute_accuracy_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    print(verification_paths[-1].shape,relative_accuracy_errors[-1].shape,absolute_accuracy_errors[-1].shape)
# Out:
# ('', 'multicore_cpu')
# 23
# 29
# 30
# 76
# ((128, 16), (124, 16), (128, 16))
# ('ee-snowball2', 'opencl_alterafpga')
# 8
# 16
# 23
# 25
# 29
# 30
# 32
# 76
# ((128, 21), (120, 21), (128, 21))
# ('phi', 'multicore_cpu')
# 8
# 16
# 21
# 23
# 25
# 28
# 29
# 30
# 76
# ((128, 17), (119, 17), (128, 17))
# ('phi', 'opencl_gpu')
# 23
# 29
# 30
# ((128, 16), (125, 16), (128, 16))
# ('ee-snowball0', 'opencl_gpu')
# 8
# 16
# 20
# 20
# 21
# 23
# 25
# 28
# 29
# 30
# ((127, 22), (119, 22), (127, 22))
# ('amazon-gpu-0', 'multicore_cpu')
# 16
# 21
# 23
# 29
# 30
# ((128, 16), (123, 16), (128, 16))
# ('amazon-gpu-0', 'opencl_gpu')
# 0
# 8
# 16
# 21
# 23
# 25
# 28
# 29
# 30
# 60
# 73
# 76
# ((128, 23), (116, 23), (128, 23))
# ('amazon-gpu-1', 'multicore_cpu')
# 16
# 21
# 23
# 29
# 30
# ((128, 15), (123, 15), (128, 15))
# ('amazon-gpu-1', 'opencl_gpu')
# 0
# 8
# 16
# 21
# 23
# 25
# 28
# 29
# 30
# 32
# 61
# 76
# 78
# ((128, 23), (115, 23), (128, 23))
# ('amazon-cpu-0', 'multicore_cpu')
# 8
# 23
# 29
# 30
# ((128, 17), (124, 17), (128, 17))
# ('amazon-cpu-1', 'multicore_cpu')
# 8
# 16
# 23
# 29
# 30
# 76
# ((128, 17), (122, 17), (128, 17))
# ('ee-snowball1', 'opencl_gpu')
# 0
# 1
# 2
# 8
# 16
# 20
# 20
# 21
# 23
# 25
# 28
# 29
# 30
# 76
# ((127, 22), (115, 22), (127, 22))
# ('ee-benjamin', 'multicore_cpu')
# 8
# 16
# 21
# 23
# 29
# 30
# ((128, 17), (122, 17), (128, 17))
# ('pi', 'multicore_cpu')
# 8
# 23
# 25
# 29
# 30
# 76
# ((128, 9), (122, 9), (128, 9))
# ('ee-mollie', 'multicore_cpu')
# 16
# 21
# 23
# 29
# 30
# ((128, 15), (123, 15), (128, 15))
# ('ee-mollie', 'maxeler_fpga')
# 1
# 8
# 16
# 20
# 20
# 21
# 23
# 25
# 28
# 29
# 30
# 32
# 42
# 60
# 70
# 74
# 76
# 77
# 78
# 82
# ((127, 21), (109, 21), (127, 21))

# %% [markdown]
# The relative accuracy error seems to stabalise fairly quickly, but generally it the model is overestimating the accuracy required.
# The absolute error is converging well, suggesting that there is no constant bias in the model that is being used. I've plotted the absolute value of the error (but only after averaging) to show this on a log plot.

# %%
fig, (ax1, ax2) = plt.subplots(2,sharex=True)

numpy.random.seed(1234)
for i,(platform,platform_type) in enumerate(platforms_interest):
    ax1.plot(verification_paths[i][-1],100*(numpy.mean(relative_accuracy_errors[i],axis=0)),"x-",label=platform + " (" + platform_type+")",color=(numpy.random.random(),numpy.random.random(),numpy.random.random())) #paths should all be the same
    
ax1.axvspan(1, 1,facecolor='g', alpha=1)

ax1.set_xscale('log')
ax1.set_ylabel("Relative Accuracy Error (%)")
ax1.set_ylim((-5,10))

numpy.random.seed(1234)
for i,(platform,platform_type) in enumerate(platforms_interest):
    ax2.plot(verification_paths[i][-1],numpy.abs(numpy.mean(absolute_accuracy_errors[i],axis=0)),"x-",label=platform + " (" + platform_type+")",color=(numpy.random.random(),numpy.random.random(),numpy.random.random())) #paths should all be the same
    
ax2.axvspan(1, 1,facecolor='g', alpha=1)

ax2.set_xlabel("Runtime to Benchmark Time Ratio")
ax2.set_xscale('log')
ax2.set_ylabel("Absolute Accuracy Error ($)")
ax2.set_yscale('log')
#ax2.set_ylim((-0.1,0.1))

fig.set_size_inches(18.5,21)

plt.legend(loc="best")

# %% [markdown]
# ##### Looking at a single platform-task pair

# %%
plt.plot(verification_accuracy,100*numpy.abs(numpy.array(map(accuracy_model,verification_paths))-verification_accuracy)/verification_accuracy,"r-x")
plt.axvspan(accuracy[-1], accuracy[-1], facecolor='g', alpha=1)

ax = plt.gca()
ax.set_xlabel("Accuracy ($)")
ax.set_xscale('log')
ax.set_ylabel("Relative Accuracy Error (%)")
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-e59fdc298eaa> in <module>()
# ----> 1 plt.plot(verification_accuracy,100*numpy.abs(numpy.array(map(accuracy_model,verification_paths))-verification_accuracy)/verification_accuracy,"r-x")
#       2 plt.axvspan(accuracy[-1], accuracy[-1], facecolor='g', alpha=1)
#       3
#       4 ax = plt.gca()
#       5 ax.set_xlabel("Accuracy ($)")
#
# ValueError: operands could not be broadcast together with shapes (7,) (20,)

# %% [markdown]
# #### 3. Combine Models and 4. Verify Combined Curves

# %% [markdown]
# ##### Accuracy-Latency Model

# %%
accuracy_range = []
for i in range(-1,3):
    accuracy_range += list(numpy.arange(10**-i,10**-(i+1),-10**-(i+1)))
accuracy_range = numpy.array(accuracy_range)

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))

#platforms = [("ee-snowball1","opencl_gpu")]

# %% [markdown]
# Function for generating a Latency as a function of accuracy model. It could actually be done without the paths variable, which is just used to link the latency and accuracy.
#
# What's quite important is that any model that is returning a nonsensical value, either implicity as a 0 coefficient or a nan is discounted. This isn't very Pythonic, but makes sense in the context of best-effort interfaces.

# %%
def latency_accuracy_model_generate(paths,latency,accuracy):
    latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
    latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
    #latency_model = lambda N: latency_model_coefficients[0]*N + latency_model_coefficients[1]

    accuracy_model_data = numpy.column_stack((paths**-0.5,numpy.zeros(len(paths))))
    accuracy_model_coefficients = numpy.linalg.lstsq(accuracy_model_data,accuracy)[0]
    #accuracy_model = lambda N: accuracy_model_coefficients[0]*N**-0.5 + accuracy_model_coefficients[1]
            
    if(accuracy_model_coefficients[0]<=0 or numpy.isnan(accuracy_model_coefficients[0])): return lambda A: 0.0
    else: return lambda A: latency_model_coefficients[0]*(accuracy_model_coefficients[0]/A)**2 + latency_model_coefficients[1]

# %% [markdown]
# The big issue with the plot below is in comparing model curves and the verification points. Each point should be the time taken to achieve that accuracy for all of the tasks. For the predictive models this is easy to do:
# 1. The latency accuracy model is generated from the benchmark data, i.e. all data for which the time 300.0/number of tasks
# 2. The curve is plotted according to the domain of interest
# These are the dashed curves in the plot.
#
# However, this isn't as straight-forward for the verification data. The verification runs aren't that fine-grained due to the multiplicative stepping. So I've done two things:
# 1. Simply plot the latency-accuracy model using all of the available data as opposed to just the benchmark data. This is the solid line plot.
# 2. Find the accuracies achieved that are below each accuracy point of interest (as defined in the accuracy range), and add the minimum of these latencies to the total for that point of interest. Only those accuracy points which have some high fraction of all tasks are plotted (currently 0.9). This is the scatter plot points.
#
# I should probably do more fine-grained verification runs.

# %%
fig, ax1 = plt.subplots(1)

numpy.random.seed(1234)
ax1.axvspan(300, 300, alpha=0.5)
ax1.axvspan(3000, 3000, alpha=0.5)

platforms_interest = [(platform,platform_type) for platform,platform_type in platforms if "opencl_gpu" in platform_type or "fpga" in platform_type] #if "cpu" in platform_type or "fpga" in platform_type
for platform,platform_type in platforms_interest:
    latency_accuracy_models = []
    verification_latency_accuracy_models = []
    
    verification_latencies = numpy.zeros(accuracy_range.shape)
    verification_sets = [set() for i in verification_latencies]
    for task,dummy in enumerate(option_tasks[:]):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"].astype(numpy.int)==task 
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #constrain the benchmarking
        if(numpy.any(selection)):
            paths = data[selection]["Paths"].astype(numpy.float)
            accuracy = data[selection]["Accuracy"].astype(numpy.float)
            latency = data[selection]["Latency"].astype(numpy.float)
            
            latency_accuracy_models += [latency_accuracy_model_generate(paths,latency,accuracy)]
            
            verification_paths = data[verification_selection]["Paths"].astype(numpy.float)
            verification_accuracy = data[verification_selection]["Accuracy"].astype(numpy.float)
            verification_latency = data[verification_selection]["Latency"].astype(numpy.float)
            
            verification_latency_accuracy_models += [latency_accuracy_model_generate(verification_paths,verification_latency,verification_accuracy)]
            
            #plt.scatter(verification_latency,verification_accuracy,marker="x") #plots all of the task points
            #finding the closest accuracy in the range of interest and accumulating the accuracy
            
            for i,acc in enumerate(accuracy_range):
                accuracy_selection = (verification_accuracy-acc)<=0 #selecting those entries at the required accuracy or lower
                if(numpy.any(accuracy_selection)): 
                    verification_latencies[i] += min(verification_latency[accuracy_selection])
                    verification_sets[i] |= {task}
                
            #for acc,lat in zip(verification_accuracy,verification_latency):
                #index = numpy.argmin([(acc-accuracy_range)<0])
                #verification_latencies[index] += lat
                #
            
    #Building the model of models
    latency_accuracy_model = lambda A: numpy.sum([lam(A) for lam in latency_accuracy_models])
    verification_latency_accuracy_model = lambda A: numpy.sum([lam(A) for lam in verification_latency_accuracy_models])
    
    colour = tuple(numpy.random.random(3))
    plot = ax1.plot([latency_accuracy_model(a) for a in accuracy_range],accuracy_range,"--",label=platform+" ("+ platform_type+")",color=colour)
    
    plot_latencies = []
    plot_accuracies = []
    for lat,acc,vset in zip(verification_latencies,accuracy_range,verification_sets):
        #if( 30 < latency_accuracy_model(acc)< 300 ):
        if(len(vset)>=0.9*len(option_tasks)):
            plot_latencies += [lat]
            plot_accuracies += [acc]
    
    plot = ax1.plot([verification_latency_accuracy_model(a) for a in accuracy_range],accuracy_range,"-",color=colour)
    #plt.scatter(plot_latencies,plot_accuracies,color=colour)
            
ax1.set_xscale('log')
ax1.set_xlabel("Latency (S)")
ax1.set_yscale('log')
ax1.set_ylabel("Accuracy ($)")
ax1.legend(loc='best')

fig.set_size_inches(18.5,10.5)

# %% [markdown]
# ## Data Output

# %% [markdown]
# For using the data in the partitioners, the coefficients for the models are required for each task upon each platform

# %%
def latency_accuracy_model_coefficients(paths,latency,accuracy):
    latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
    latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
    #latency_model = lambda N: latency_model_coefficients[0]*N + latency_model_coefficients[1]

    accuracy_model_data = numpy.column_stack((paths**-0.5,numpy.zeros(len(paths))))
    accuracy_model_coefficients = numpy.linalg.lstsq(accuracy_model_data,accuracy)[0]
    #accuracy_model = lambda N: accuracy_model_coefficients[0]*N**-0.5 + accuracy_model_coefficients[1]
            
    if(latency_model_coefficients[0]<=0 or accuracy_model_coefficients[0]<=0 or numpy.isnan(accuracy_model_coefficients[0])): return (numpy.inf,numpy.inf,numpy.inf)
    else: return (accuracy_model_coefficients[0],latency_model_coefficients[0],latency_model_coefficients[1])

# %%
with open('model_coefficients_complete2.csv','w') as model_coefficients_file:
    coefficient_writer = csv.writer(model_coefficients_file, delimiter=',')
    coefficient_writer.writerow(["Platform","Type","Task","Accuracy Coefficient","Latency Coefficient","Latency Setup"])
    
    for platform,platform_type in platforms:
        for task,dummy in enumerate(option_tasks):
            selection = data["Platform"]==platform
            selection &= data["Type"]==platform_type
            selection &= data["Task"].astype(numpy.int)==task 
            verification_selection = numpy.copy(selection)
            selection &= data["Latency"].astype(numpy.float) < 300.0/128 #constrain the benchmarking
        
            if(numpy.any(selection)):
                paths = data[selection]["Paths"].astype(numpy.float)
                accuracy = data[selection]["Accuracy"].astype(numpy.float)
                latency = data[selection]["Latency"].astype(numpy.float)
            
                accuracy_model_coefficient,latency_model_coefficient,latency_model_setup = latency_accuracy_model_coefficients(paths,latency,accuracy)
            else:
                accuracy_model_coefficient,latency_model_coefficient,latency_model_setup = (numpy.inf,numpy.inf,numpy.inf)
                
            print([platform,platform_type,task,accuracy_model_coefficient,latency_model_coefficient,latency_model_setup])
            coefficient_writer.writerow([platform,platform_type,task,accuracy_model_coefficient,latency_model_coefficient,latency_model_setup])
# Out:
# ['', 'multicore_cpu', 0, 5.119297655979353, 4.1433407032999553e-06, 0.0075208350247853578]
# ['', 'multicore_cpu', 1, 3.6381225809038225, 4.164901996761551e-06, 0.0016817513392833666]
# ['', 'multicore_cpu', 2, 3.69287021094781, 4.0730906306915559e-06, 0.0039902601986861836]
# ['', 'multicore_cpu', 3, 3.2522540427881874, 4.1181762761928962e-06, 0.0064811788704497338]
# ['', 'multicore_cpu', 4, 3.3156781855058228, 4.0796120412145804e-06, 0.0029995730363911038]
# ['', 'multicore_cpu', 5, 20.599241416145379, 4.0678038558551259e-06, 0.007385658092609132]
# ['', 'multicore_cpu', 6, 6.3489196039556326, 4.0796605475993582e-06, 0.0035956846581751555]
# ['', 'multicore_cpu', 7, 13.692421500477746, 4.0675902816940254e-06, 0.0037699476443122243]
# ['', 'multicore_cpu', 8, 0.27314621207974227, 4.3119241071530543e-06, 0.0063856149381479642]
# ['', 'multicore_cpu', 9, 13.44061674780882, 4.1050774166041726e-06, 0.0083818232604615222]
# ['', 'multicore_cpu', 10, 13.424182086175414, 4.0158509744253353e-06, 0.0025862361718565459]
# ['', 'multicore_cpu', 11, 14.589195330367412, 4.1882034651020287e-06, 0.00069230209073620403]
# ['', 'multicore_cpu', 12, 40.962914806253728, 4.2082127570272865e-06, 0.0026671945044850686]
# ['', 'multicore_cpu', 13, 13.607427448423822, 4.1344510533560395e-06, 0.0039101649357271163]
# ['', 'multicore_cpu', 14, 19.010716304428616, 2.1030567894095791e-06, 0.009072081949345747]
# ['', 'multicore_cpu', 15, 13.605572391950819, 3.5390861708409827e-06, 0.0056216957227626686]
# ['', 'multicore_cpu', 16, 1.0494866848809017, 2.4223248522132736e-06, -0.0049326613322115687]
# ['', 'multicore_cpu', 17, 13.128562217231893, 4.1437886613339066e-06, 0.003276245508999917]
# ['', 'multicore_cpu', 18, 9.933223219604324, 3.5154528299312771e-06, -0.0027802991933409114]
# ['', 'multicore_cpu', 19, 11.832450479682848, 4.1899079170896628e-06, 0.0045134689813828011]
# ['', 'multicore_cpu', 20, 0.32089232245386046, 4.4353315165239467e-06, 0.0040377243585103355]
# ['', 'multicore_cpu', 21, 0.23067317098517595, 4.4618201992028452e-06, 0.0030033323226368864]
# ['', 'multicore_cpu', 22, 0.83940290483173585, 4.5194159613898732e-06, 0.0035398277776522448]
# ['', 'multicore_cpu', 23, 0.0014941030813003932, 4.4975093778868411e-06, 0.00011760893189984919]
# ['', 'multicore_cpu', 24, 0.76843490395895853, 4.6452320708239298e-06, 0.0025177201918502434]
# ['', 'multicore_cpu', 25, 6.1735980618816786, 4.3362156099687298e-06, 0.0031090269468650477]
# ['', 'multicore_cpu', 26, 7.4408675885792324, 4.2637001061977395e-06, 0.0035453890394102805]
# ['', 'multicore_cpu', 27, 27.448631598047943, 4.3454675650134349e-06, 0.0031061109973801828]
# ['', 'multicore_cpu', 28, 4.0045294194019547, 4.1863395822154486e-06, 0.0031308486210929846]
# ['', 'multicore_cpu', 29, 0.15954601198373233, 4.2101326973605667e-06, 0.0048789677263074809]
# ['', 'multicore_cpu', 30, 6.6414357221340471e-05, 4.1943212305410287e-06, 0.0022217239702243918]
# ['', 'multicore_cpu', 31, 25.450999013223988, 4.2901216279286475e-06, 0.0024964119320245808]
# ['', 'multicore_cpu', 32, 4.9794184032468891, 4.2888227706229281e-06, 0.010545868729036638]
# ['', 'multicore_cpu', 33, 32.551133112273817, 4.2854057381923103e-06, 0.0026484036985097437]
# ['', 'multicore_cpu', 34, 10.705226051717665, 4.265304704949965e-06, 0.0042732463666201896]
# ['', 'multicore_cpu', 35, 21.715956063801244, 1.0247709277836171e-05, 0.0050989273769186392]
# ['', 'multicore_cpu', 36, 17.902611419966789, 9.9903284538929282e-06, 0.0047192703317046067]
# ['', 'multicore_cpu', 37, 47.933147760605465, 1.0095294677506708e-05, 0.0048057353523381337]
# ['', 'multicore_cpu', 38, 23.594994450764268, 1.0071391733728874e-05, 0.0051098704186149386]
# ['', 'multicore_cpu', 39, 19.275741801308072, 1.0188040033249783e-05, 0.0018229856580046244]
# ['', 'multicore_cpu', 40, 25.494180470034642, 1.0387330749282967e-05, 0.0043292128628274872]
# ['', 'multicore_cpu', 41, 43.963733400996851, 1.0141147693321709e-05, 0.0037785536238440069]
# ['', 'multicore_cpu', 42, 4.4307542739197041, 1.0135148032147157e-05, 0.0029438585821164676]
# ['', 'multicore_cpu', 43, 40.518583605721453, 1.0129967378432592e-05, 0.0036220724642990077]
# ['', 'multicore_cpu', 44, 51.513826930102617, 1.0370971200467993e-05, 0.0050704389232762905]
# ['', 'multicore_cpu', 45, 35.140693871715847, 1.0038358072798327e-05, 0.0046892571699470578]
# ['', 'multicore_cpu', 46, 20.537683610247601, 1.035835057739875e-05, 0.0051540179839506877]
# ['', 'multicore_cpu', 47, 30.667939590697756, 1.039577956062234e-05, 0.0040168665699193886]
# ['', 'multicore_cpu', 48, 22.598572108406593, 1.046821387743245e-05, 0.0045440194346828078]
# ['', 'multicore_cpu', 49, 30.339730756049505, 1.02787346296796e-05, 0.0047333117779612376]
# ['', 'multicore_cpu', 50, 48.541607368294635, 1.0126764643620249e-05, 0.0033495503562679953]
# ['', 'multicore_cpu', 51, 24.575759554527377, 1.0386131862046645e-05, 0.0028173921042239708]
# ['', 'multicore_cpu', 52, 14.478157836545909, 1.0083117317105664e-05, 0.0043533567279482972]
# ['', 'multicore_cpu', 53, 25.174651309422615, 1.0114940155353357e-05, 0.0047004887680095284]
# ['', 'multicore_cpu', 54, 38.839032102499338, 1.0344439804978661e-05, 0.0062757752218959911]
# ['', 'multicore_cpu', 55, 25.367983475334217, 1.0384142104003397e-05, 0.005746518202460792]
# ['', 'multicore_cpu', 56, 10.780639523720946, 1.0246283275371811e-05, 0.0041394546306774502]
# ['', 'multicore_cpu', 57, 19.338164883963032, 1.0342912092871918e-05, 0.004331647516114776]
# ['', 'multicore_cpu', 58, 54.197824292887631, 1.0386621741312213e-05, 0.0041232225689926605]
# ['', 'multicore_cpu', 59, 31.657466647937966, 1.0528772645187422e-05, 0.0016360584116443934]
# ['', 'multicore_cpu', 60, 10.498353070068767, 1.0631749405130561e-05, 0.0025964276231212331]
# ['', 'multicore_cpu', 61, 26.66326567799269, 1.0324784508744252e-05, 0.0037686150704783782]
# ['', 'multicore_cpu', 62, 25.422886896702266, 7.834005294539304e-06, 0.0034812431589648874]
# ['', 'multicore_cpu', 63, 24.942038036221721, 9.1453369371339921e-06, 0.0050922673935325487]
# ['', 'multicore_cpu', 64, 80.853255662110342, 1.0647034244108363e-05, 0.003250041379468042]
# ['', 'multicore_cpu', 65, 43.671152534929945, 1.0468039338461689e-05, 0.0060214751790598261]
# ['', 'multicore_cpu', 66, 159.92087970733508, 1.0384764862420648e-05, 0.0033887565489908729]
# ['', 'multicore_cpu', 67, 38.023824618355242, 8.8937992321204956e-06, 0.0041063148599956491]
# ['', 'multicore_cpu', 68, 22.761758547044249, 1.0244169337727084e-05, 0.0066198786885235646]
# ['', 'multicore_cpu', 69, 114.06574516717436, 1.0583826889970595e-05, 0.0044815567168862737]
# ['', 'multicore_cpu', 70, 12.79599297248631, 8.0085309822986236e-06, 0.0028780114285783752]
# ['', 'multicore_cpu', 71, 71.106865390379326, 1.0560735315210781e-05, 0.0037432665272659955]
# ['', 'multicore_cpu', 72, 52.68540299251034, 5.6978365892624239e-06, 0.004162536508759869]
# ['', 'multicore_cpu', 73, 17.531360115866875, 1.0311748990449235e-05, 0.0057044662949953407]
# ['', 'multicore_cpu', 74, 10.74878750194598, 9.3382388027501465e-06, 0.0051452743454039789]
# ['', 'multicore_cpu', 75, 131.17123685839405, 1.0487716249030904e-05, 0.0049167841135503969]
# ['', 'multicore_cpu', 76, 1.4309081106867765, 5.8065862723888972e-06, 0.003113158589158861]
# ['', 'multicore_cpu', 77, 33.838216417332404, 3.3338254054161599e-06, 0.0057074718888768129]
# ['', 'multicore_cpu', 78, 7.1603368115803256, 7.1785557091942403e-06, 0.0031040351210274699]
# ['', 'multicore_cpu', 79, 44.573795416613486, 9.4863980027722786e-06, 0.0045492393217524034]
# ['', 'multicore_cpu', 80, 6.2450916502369855, 7.4589787677494724e-06, 0.0045885756578287811]
# ['', 'multicore_cpu', 81, 42.551164099618845, 4.8093199243496202e-06, 0.0042251539617934458]
# ['', 'multicore_cpu', 82, 27.17566080447132, 1.0520425655411128e-05, 0.0037305322159280471]
# ['', 'multicore_cpu', 83, 86.817102467438204, 1.0585433747643239e-05, 0.0048300136858220218]
# ['', 'multicore_cpu', 84, 39.581943556725591, 6.2335900544614911e-06, 0.005578581272299963]
# ['', 'multicore_cpu', 85, 20.14895786080389, 1.0727253962629193e-05, 0.003401123648264703]
# ['', 'multicore_cpu', 86, 36.009313960880938, 5.3284113009035889e-06, 0.005167346295377454]
# ['', 'multicore_cpu', 87, 55.775602943430236, 4.8801668733317522e-06, 0.0035604109096121976]
# ['', 'multicore_cpu', 88, 11.045202877621838, 8.8696407808356572e-06, 0.0062076958934016609]
# ['', 'multicore_cpu', 89, 0.93384149004470041, 1.0809046947950213e-05, 0.0051182446069535908]
# ['', 'multicore_cpu', 90, 0.81761382788984327, 1.077675862070912e-05, 0.0048077318478879751]
# ['', 'multicore_cpu', 91, 0.82146828537249561, 1.0804562864530472e-05, 0.0051923096543612145]
# ['', 'multicore_cpu', 92, 0.86555315824889356, 1.0892091165435542e-05, 0.0059162048084713719]
# ['', 'multicore_cpu', 93, 0.8924845835183246, 1.0513168261180523e-05, 0.0054645716890266011]
# ['', 'multicore_cpu', 94, 64.511590171479824, 1.0703714323594391e-05, 0.0057390307775013723]
# ['', 'multicore_cpu', 95, 49.015146202214787, 1.0809480144788875e-05, 0.0048504917051215655]
# ['', 'multicore_cpu', 96, 37.115296882133798, 1.0746557589099028e-05, 0.0036742642927934167]
# ['', 'multicore_cpu', 97, 50.486567689675788, 1.0471368048821206e-05, 0.0072824673744579793]
# ['', 'multicore_cpu', 98, 41.622379878130836, 1.0365347857201042e-05, 0.0064993742835725713]
# ['', 'multicore_cpu', 99, 64.020481300339497, 1.0465722473559843e-05, 0.0055107879833911147]
# ['', 'multicore_cpu', 100, 63.013631128589893, 1.0310339543168843e-05, 0.006226571607836697]
# ['', 'multicore_cpu', 101, 78.927591877053487, 1.0753262224580903e-05, 0.0041855874284364653]
# ['', 'multicore_cpu', 102, 103.51077617851411, 1.063607107390024e-05, 0.0061539853297014491]
# ['', 'multicore_cpu', 103, 167.45018745927919, 1.0390476112497203e-05, 0.0069695998099282164]
# ['', 'multicore_cpu', 104, 141.2114162642296, 1.0451825353063599e-05, 0.0072483258113035061]
# ['', 'multicore_cpu', 105, 47.140803526354652, 1.0651210334428528e-05, 0.0069999222305605086]
# ['', 'multicore_cpu', 106, 18.365483321701866, 1.0421926307138243e-05, 0.0052133085832487564]
# ['', 'multicore_cpu', 107, 35.114270131078086, 1.0470450034453781e-05, 0.0078267402667545581]
# ['', 'multicore_cpu', 108, 50.642013799348284, 1.0416200147724367e-05, 0.0057845766895579685]
# ['', 'multicore_cpu', 109, 47.340429343340844, 1.051289809675097e-05, 0.0063230459762307137]
# ['', 'multicore_cpu', 110, 47.591109324649523, 1.0527776850325709e-05, 0.0039638412189786582]
# ['', 'multicore_cpu', 111, 111.23971054559637, 1.0435371933331836e-05, 0.0059129683598187627]
# ['', 'multicore_cpu', 112, 85.745080034783527, 1.0635537193304456e-05, 0.0047714908791679396]
# ['', 'multicore_cpu', 113, 126.95903570061792, 1.066971416529319e-05, 0.0065133023945362573]
# ['', 'multicore_cpu', 114, 127.1527746217108, 1.0405371734483249e-05, 0.0080627602000515556]
# ['', 'multicore_cpu', 115, 49.066074396976532, 1.0805056028541345e-05, 0.0014197897783713633]
# ['', 'multicore_cpu', 116, 37.652507038457053, 1.0642093445485071e-05, 0.0077556867157806452]
# ['', 'multicore_cpu', 117, 115.84116033442642, 1.0723846276367994e-05, 0.0058863856275970525]
# ['', 'multicore_cpu', 118, 164.91868984587109, 1.0624194299969198e-05, 0.0092362897431450663]
# ['', 'multicore_cpu', 119, 123.29330473508121, 1.0650639006647912e-05, 0.0061432344865190325]
# ['', 'multicore_cpu', 120, 81.517935865520855, 1.039967062686291e-05, 0.0082165409205692212]
# ['', 'multicore_cpu', 121, 53.220003838335579, 1.071312867868381e-05, 0.0043316341784057355]
# ['', 'multicore_cpu', 122, 77.235991244305197, 1.0625655224603916e-05, 0.0066716640695528608]
# ['', 'multicore_cpu', 123, 46.318574629100482, 1.0017171604108484e-05, 0.0075566079431068781]
# ['', 'multicore_cpu', 124, 73.009444763477916, 1.0050048356441139e-05, 0.0076423146356913814]
# ['', 'multicore_cpu', 125, 46.455920951021554, 9.8190746898465507e-06, 0.009622882812736067]
# ['', 'multicore_cpu', 126, 89.754272041609298, 1.0145844380542434e-05, 0.0053782354528273141]
# ['', 'multicore_cpu', 127, 58.362382665644404, 1.0168699920547328e-05, 0.0048366650191889685]
# ['ee-snowball2', 'opencl_alterafpga', 0, 3.2795828766586688, 7.4987355179633426e-08, 0.15112965685118157]
# ['ee-snowball2', 'opencl_alterafpga', 1, 2.2741473663349816, 6.7894313376042775e-08, 0.17305874038462513]
# ['ee-snowball2', 'opencl_alterafpga', 2, 2.6142909793479179, 6.9057473916022275e-08, 0.16392956349351592]
# ['ee-snowball2', 'opencl_alterafpga', 3, 5.2364173275955332, 6.8854969460768119e-08, 0.16622272126815457]
# ['ee-snowball2', 'opencl_alterafpga', 4, 4.2355426756635541, 6.9420244740889059e-08, 0.15992482784959364]
# ['ee-snowball2', 'opencl_alterafpga', 5, 18.99876265001026, 6.9086812692060072e-08, 0.17623734851798228]
# ['ee-snowball2', 'opencl_alterafpga', 6, 6.3982951750486858, 7.3681517375386717e-08, 0.16106848820868169]
# ['ee-snowball2', 'opencl_alterafpga', 7, 11.849261123279902, 6.8551551318607648e-08, 0.16611027086692282]
# ['ee-snowball2', 'opencl_alterafpga', 8, 0.37488513781211646, 6.9295339780011384e-08, 0.16996533992177348]
# ['ee-snowball2', 'opencl_alterafpga', 9, 12.795262241790569, 7.0646463764238568e-08, 0.15619768540818235]
# ['ee-snowball2', 'opencl_alterafpga', 10, 14.121498037208582, 6.0190946057825697e-08, 0.16533363405565357]
# ['ee-snowball2', 'opencl_alterafpga', 11, 14.588376101771164, 5.9489870134607098e-08, 0.18151989939693516]
# ['ee-snowball2', 'opencl_alterafpga', 12, 42.949539251393169, 5.9580025098366028e-08, 0.1760130444816024]
# ['ee-snowball2', 'opencl_alterafpga', 13, 14.693948926572791, 5.9812351407278583e-08, 0.17121589705483639]
# ['ee-snowball2', 'opencl_alterafpga', 14, 21.74086717492554, 6.0839939677954859e-08, 0.15822407190799573]
# ['ee-snowball2', 'opencl_alterafpga', 15, 12.692956240314466, 6.0624927287085726e-08, 0.16853218368345138]
# ['ee-snowball2', 'opencl_alterafpga', 16, 0.49518773403646549, 5.9804802559162641e-08, 0.16145700055452181]
# ['ee-snowball2', 'opencl_alterafpga', 17, 12.907576982254687, 5.9591830183709721e-08, 0.16966698110902745]
# ['ee-snowball2', 'opencl_alterafpga', 18, 10.645465110588974, 5.9219922003490337e-08, 0.17002671732238089]
# ['ee-snowball2', 'opencl_alterafpga', 19, 11.637515727178149, 5.8729462930645255e-08, 0.1701636183370456]
# ['ee-snowball2', 'opencl_alterafpga', 20, 0.33691213315410373, 7.0905790260640183e-08, 0.17441370821501012]
# ['ee-snowball2', 'opencl_alterafpga', 21, 0.23743983467130977, 7.1702833196087062e-08, 0.1703982918592738]
# ['ee-snowball2', 'opencl_alterafpga', 22, 0.88098797729316014, 7.2632520856297944e-08, 0.15912464815755631]
# ['ee-snowball2', 'opencl_alterafpga', 23, 0.00069232148548258878, 7.2566068372422981e-08, 0.16787139672883725]
# ['ee-snowball2', 'opencl_alterafpga', 24, 0.73207303323298356, 7.2349181502633774e-08, 0.17865901973375165]
# ['ee-snowball2', 'opencl_alterafpga', 25, 2.8914252126757498, 5.7088682163299714e-08, 0.1696581234949204]
# ['ee-snowball2', 'opencl_alterafpga', 26, 4.8702315111299104, 5.8951805780196911e-08, 0.16317694487616519]
# ['ee-snowball2', 'opencl_alterafpga', 27, 26.720015664998982, 5.7550557335679704e-08, 0.17017798980084778]
# ['ee-snowball2', 'opencl_alterafpga', 28, 5.3699436570997419, 5.8946380279479195e-08, 0.17059408761809008]
# ['ee-snowball2', 'opencl_alterafpga', 29, 0.0029626610024621881, 5.7510261133979791e-08, 0.169033240706078]
# ['ee-snowball2', 'opencl_alterafpga', 30, 2.5534069130552353e-05, 5.9405208300223432e-08, 0.1695541878880964]
# ['ee-snowball2', 'opencl_alterafpga', 31, 26.671696652190416, 5.6774677171184131e-08, 0.17124620952651937]
# ['ee-snowball2', 'opencl_alterafpga', 32, 2.4054048025956178, 5.7007947596202261e-08, 0.16431028666411476]
# ['ee-snowball2', 'opencl_alterafpga', 33, 38.71602394417031, 6.2601039996937372e-08, 0.17122701568702192]
# ['ee-snowball2', 'opencl_alterafpga', 34, 9.6023394689585562, 5.6650541407797989e-08, 0.17510197365187749]
# ['ee-snowball2', 'opencl_alterafpga', 35, 22.595878420867088, 1.0845441239125762e-07, 0.156416823311613]
# ['ee-snowball2', 'opencl_alterafpga', 36, 18.722900350077893, 1.0050927984965887e-07, 0.17831959283667484]
# ['ee-snowball2', 'opencl_alterafpga', 37, 56.756851722104578, 1.0177776829256152e-07, 0.16680457883429234]
# ['ee-snowball2', 'opencl_alterafpga', 38, 25.733204622994876, 1.0155904869414969e-07, 0.16651899155568756]
# ['ee-snowball2', 'opencl_alterafpga', 39, 15.328695808964882, 9.9722780698711226e-08, 0.17961329928407258]
# ['ee-snowball2', 'opencl_alterafpga', 40, 24.068967516880655, 1.032247279814875e-07, 0.17733170756529348]
# ['ee-snowball2', 'opencl_alterafpga', 41, 41.23423149687779, 1.10660329594312e-07, 0.1665224433218008]
# ['ee-snowball2', 'opencl_alterafpga', 42, 4.2828372045243697, 1.0008543696485506e-07, 0.18002268483221337]
# ['ee-snowball2', 'opencl_alterafpga', 43, 38.67171693683872, 1.0970927957091241e-07, 0.15873923379967475]
# ['ee-snowball2', 'opencl_alterafpga', 44, 69.167203049028174, 9.9518602254687023e-08, 0.17941178885066281]
# ['ee-snowball2', 'opencl_alterafpga', 45, 28.176793642020666, 1.1037954316714837e-07, 0.16434111301697213]
# ['ee-snowball2', 'opencl_alterafpga', 46, 17.326252550948727, 1.1318014391663678e-07, 0.1624000277018906]
# ['ee-snowball2', 'opencl_alterafpga', 47, 28.473274175418695, 1.0229996708419336e-07, 0.16984042955370549]
# ['ee-snowball2', 'opencl_alterafpga', 48, 20.238896136137861, 9.741829476413963e-08, 0.17842012213423789]
# ['ee-snowball2', 'opencl_alterafpga', 49, 30.498159978165923, 1.0520697361423463e-07, 0.17976488730385104]
# ['ee-snowball2', 'opencl_alterafpga', 50, 44.818145093623833, 1.0780539094655842e-07, 0.17328035869320754]
# ['ee-snowball2', 'opencl_alterafpga', 51, 23.946342971621821, 1.0128203567002008e-07, 0.17139906340656907]
# ['ee-snowball2', 'opencl_alterafpga', 52, 16.680414503572973, 1.0874966212193948e-07, 0.16759049906910675]
# ['ee-snowball2', 'opencl_alterafpga', 53, 19.907571824177626, 9.989274949785944e-08, 0.18815948615755929]
# ['ee-snowball2', 'opencl_alterafpga', 54, 54.293040825351184, 1.0569145424778068e-07, 0.17494781732572362]
# ['ee-snowball2', 'opencl_alterafpga', 55, 25.235271873037082, 1.0324624422390573e-07, 0.16990833414627457]
# ['ee-snowball2', 'opencl_alterafpga', 56, 13.170141830380052, 1.0316320209388272e-07, 0.16168493222793173]
# ['ee-snowball2', 'opencl_alterafpga', 57, 19.236806887764686, 9.9509697903459551e-08, 0.18032820549619608]
# ['ee-snowball2', 'opencl_alterafpga', 58, 63.709137885809888, 1.0160337284355777e-07, 0.15815087330696459]
# ['ee-snowball2', 'opencl_alterafpga', 59, 30.318932407797629, 1.027235555711328e-07, 0.16599214746801769]
# ['ee-snowball2', 'opencl_alterafpga', 60, 13.13650154239032, 1.4022918116161537e-07, 0.18432900498060667]
# ['ee-snowball2', 'opencl_alterafpga', 61, 22.566666212386444, 1.3908091782311643e-07, 0.17932970391296699]
# ['ee-snowball2', 'opencl_alterafpga', 62, 30.722762708848709, 1.4288441274758105e-07, 0.1756757736957778]
# ['ee-snowball2', 'opencl_alterafpga', 63, 23.367848094029767, 1.4224480411442551e-07, 0.17435920172720562]
# ['ee-snowball2', 'opencl_alterafpga', 64, 106.94904884798588, 1.5387413094784142e-07, 0.17809686422851942]
# ['ee-snowball2', 'opencl_alterafpga', 65, 45.424186588077688, 1.4583972876615939e-07, 0.17914410183968466]
# ['ee-snowball2', 'opencl_alterafpga', 66, 107.45398310925685, 1.5363257809467958e-07, 0.16664296436499521]
# ['ee-snowball2', 'opencl_alterafpga', 67, 35.526634253987581, 1.3906230186664934e-07, 0.1843128633259295]
# ['ee-snowball2', 'opencl_alterafpga', 68, 28.826977543344331, 1.507812043727741e-07, 0.16865211455593376]
# ['ee-snowball2', 'opencl_alterafpga', 69, 93.568217120964135, 1.4298570268926865e-07, 0.16237177320709725]
# ['ee-snowball2', 'opencl_alterafpga', 70, 14.312172826063335, 1.3928223868811221e-07, 0.18250105541520553]
# ['ee-snowball2', 'opencl_alterafpga', 71, 62.64760557488254, 1.4141679756241546e-07, 0.17359911582512211]
# ['ee-snowball2', 'opencl_alterafpga', 72, 49.875837452691336, 1.5283079786509614e-07, 0.16475619433173891]
# ['ee-snowball2', 'opencl_alterafpga', 73, 13.024177008310483, 1.524838586952692e-07, 0.16089127047864255]
# ['ee-snowball2', 'opencl_alterafpga', 74, 7.8457651515041702, 1.4217840825014817e-07, 0.1621016081833116]
# ['ee-snowball2', 'opencl_alterafpga', 75, 137.62401549402094, 1.4002150997991953e-07, 0.17239718825433609]
# ['ee-snowball2', 'opencl_alterafpga', 76, 0.85781469424344614, 1.3970722413363593e-07, 0.18061098066346978]
# ['ee-snowball2', 'opencl_alterafpga', 77, 28.990593057201693, 1.5276899705641282e-07, 0.15506973284140166]
# ['ee-snowball2', 'opencl_alterafpga', 78, 6.001347582684148, 1.4227791773823883e-07, 0.16575723863692907]
# ['ee-snowball2', 'opencl_alterafpga', 79, 43.692403759030199, 1.3962193683008192e-07, 0.17565914336782945]
# ['ee-snowball2', 'opencl_alterafpga', 80, 7.0083215746781411, 1.4081673379893187e-07, 0.16810332991126714]
# ['ee-snowball2', 'opencl_alterafpga', 81, 39.73959191427133, 1.3917073057034823e-07, 0.17008135347389272]
# ['ee-snowball2', 'opencl_alterafpga', 82, 23.917261208021813, 1.4348810150852488e-07, 0.17022056947362676]
# ['ee-snowball2', 'opencl_alterafpga', 83, 97.352793196975583, 1.4702437574427387e-07, 0.16790874000071218]
# ['ee-snowball2', 'opencl_alterafpga', 84, 40.402837688313859, 1.3722483112039237e-07, 0.17959655010195413]
# ['ee-snowball2', 'opencl_alterafpga', 85, 22.199222666409021, 1.5418139806510137e-07, 0.16445966127755313]
# ['ee-snowball2', 'opencl_alterafpga', 86, 34.087218383424116, 1.3913304866954185e-07, 0.18003491262093801]
# ['ee-snowball2', 'opencl_alterafpga', 87, 52.659051087230971, 1.4181987869109727e-07, 0.17851781072224673]
# ['ee-snowball2', 'opencl_alterafpga', 88, 8.5744201493729406, 1.5347348349724595e-07, 0.16879719767826884]
# ['ee-snowball2', 'opencl_alterafpga', 89, 0.93986116802678377, 2.1145979143768543e-07, 0.17631388016341365]
# ['ee-snowball2', 'opencl_alterafpga', 90, 0.85362395069465336, 2.0914687296099877e-07, 0.16524207852694819]
# ['ee-snowball2', 'opencl_alterafpga', 91, 0.82471239865541746, 2.0712050536764912e-07, 0.169632316652576]
# ['ee-snowball2', 'opencl_alterafpga', 92, 0.86446045137065852, 2.0787185096235639e-07, 0.17843562752712563]
# ['ee-snowball2', 'opencl_alterafpga', 93, 0.91646233080520978, 2.0738751630059886e-07, 0.17770433710917655]
# ['ee-snowball2', 'opencl_alterafpga', 94, 62.83165339389214, 2.3754437861726326e-07, 0.16993526308969129]
# ['ee-snowball2', 'opencl_alterafpga', 95, 51.868604941410545, 2.4212991540987265e-07, 0.15618494658426066]
# ['ee-snowball2', 'opencl_alterafpga', 96, 33.499952020331548, 2.2925569387967061e-07, 0.1726035089924719]
# ['ee-snowball2', 'opencl_alterafpga', 97, 64.90199980834322, 2.3709753923065117e-07, 0.16186249509778938]
# ['ee-snowball2', 'opencl_alterafpga', 98, 58.497558542440999, 2.2848256846155295e-07, 0.1683266134003317]
# ['ee-snowball2', 'opencl_alterafpga', 99, 65.413077707170729, 2.3666480204110932e-07, 0.16923269353105508]
# ['ee-snowball2', 'opencl_alterafpga', 100, 74.97310133248665, 2.3179082898453141e-07, 0.17414842684273976]
# ['ee-snowball2', 'opencl_alterafpga', 101, 86.634482304283779, 2.2643225295007068e-07, 0.16501934838946367]
# ['ee-snowball2', 'opencl_alterafpga', 102, 244.74144582997437, 2.4221548566778748e-07, 0.17124996811615528]
# ['ee-snowball2', 'opencl_alterafpga', 103, 191.19334377117627, 2.450453697428683e-07, 0.17874359118559491]
# ['ee-snowball2', 'opencl_alterafpga', 104, 94.792957284092296, 2.3758754760431618e-07, 0.16692903029432923]
# ['ee-snowball2', 'opencl_alterafpga', 105, 49.243717778538347, 2.4223431569438406e-07, 0.17070748613608633]
# ['ee-snowball2', 'opencl_alterafpga', 106, 17.099534724583837, 2.3972177828779291e-07, 0.16531108987573909]
# ['ee-snowball2', 'opencl_alterafpga', 107, 31.971582651767164, 2.3682312901801654e-07, 0.17057450135651026]
# ['ee-snowball2', 'opencl_alterafpga', 108, 63.083967957810401, 2.4026626991314962e-07, 0.1618593818774495]
# ['ee-snowball2', 'opencl_alterafpga', 109, 47.812734382323967, 2.2486655056116529e-07, 0.16701517615420944]
# ['ee-snowball2', 'opencl_alterafpga', 110, 48.462391258832625, 2.2733900610421789e-07, 0.17707875784648075]
# ['ee-snowball2', 'opencl_alterafpga', 111, 102.22816783354145, 2.2713563545050385e-07, 0.16570689754744758]
# ['ee-snowball2', 'opencl_alterafpga', 112, 132.77773980449589, 2.3947772027475214e-07, 0.1548343440009157]
# ['ee-snowball2', 'opencl_alterafpga', 113, 77.988139947864241, 2.4468511831704255e-07, 0.17320168707946201]
# ['ee-snowball2', 'opencl_alterafpga', 114, 145.1098647664472, 2.3673537324684585e-07, 0.16593158966614727]
# ['ee-snowball2', 'opencl_alterafpga', 115, 48.253104690591435, 2.4107970619566919e-07, 0.16515300564218388]
# ['ee-snowball2', 'opencl_alterafpga', 116, 40.466814230218553, 2.2847062293231428e-07, 0.16910751148615841]
# ['ee-snowball2', 'opencl_alterafpga', 117, 96.755574872821839, 2.2967339660423024e-07, 0.16849048592268157]
# ['ee-snowball2', 'opencl_alterafpga', 118, 120.56465255665292, 2.3622309863607489e-07, 0.17024369512118551]
# ['ee-snowball2', 'opencl_alterafpga', 119, 104.57036177226169, 2.4405601861881716e-07, 0.17343033691726328]
# ['ee-snowball2', 'opencl_alterafpga', 120, 72.92381669737172, 2.3694076325424368e-07, 0.17612807562142307]
# ['ee-snowball2', 'opencl_alterafpga', 121, 48.630833211393472, 2.2690112384375906e-07, 0.18223335137292029]
# ['ee-snowball2', 'opencl_alterafpga', 122, 83.616103739287894, 2.2866162050501027e-07, 0.17102451435351157]
# ['ee-snowball2', 'opencl_alterafpga', 123, 47.982248612474244, 1.1680383096268322e-07, 0.16620800839334435]
# ['ee-snowball2', 'opencl_alterafpga', 124, 61.508023824607399, 1.1550499321329593e-07, 0.17313571023788482]
# ['ee-snowball2', 'opencl_alterafpga', 125, 35.49445436585232, 1.1741427214189021e-07, 0.17246171498866525]
# ['ee-snowball2', 'opencl_alterafpga', 126, 109.38878720409907, 1.0835408339132246e-07, 0.17599857100406749]
# ['ee-snowball2', 'opencl_alterafpga', 127, 56.059225051279725, 1.1941004698354908e-07, 0.16980190238733689]
# ['phi', 'multicore_cpu', 0, 3.4912474799106232, 1.8764985007862253e-06, 0.35832395644741405]
# ['phi', 'multicore_cpu', 1, 2.5766033724736808, 1.8546549779171271e-06, 0.35641123802067526]
# ['phi', 'multicore_cpu', 2, 3.7479800753651102, 1.9084819595556662e-06, 0.35939647152211951]
# ['phi', 'multicore_cpu', 3, 2.7945428618331389, 2.0965060817052325e-06, 0.36426066411430391]
# ['phi', 'multicore_cpu', 4, 4.2444901308653238, 1.9573977612477778e-06, 0.36386680263126664]
# ['phi', 'multicore_cpu', 5, 21.143206282167281, 1.8976580046898753e-06, 0.359717641980971]
# ['phi', 'multicore_cpu', 6, 6.1568407509586809, 1.9354063921676041e-06, 0.36164275772487259]
# ['phi', 'multicore_cpu', 7, 13.498864606208377, 2.0910558058761936e-06, 0.36075208479701476]
# ['phi', 'multicore_cpu', 8, 0.080617182808058047, 1.8919450315677285e-06, 0.36100466729914199]
# ['phi', 'multicore_cpu', 9, 13.621914762553468, 1.9872315950868227e-06, 0.35814785392934106]
# ['phi', 'multicore_cpu', 10, 15.70325327186327, 2.0574086096432671e-06, 0.35741426827283329]
# ['phi', 'multicore_cpu', 11, 15.643379734125007, 2.0532652983380398e-06, 0.35995697654464731]
# ['phi', 'multicore_cpu', 12, 42.319380614114998, 1.9848181301066511e-06, 0.35728950945576166]
# ['phi', 'multicore_cpu', 13, 13.830961226563998, 1.8757044756945125e-06, 0.37954416989204731]
# ['phi', 'multicore_cpu', 14, 21.421194457625571, 1.0451499437833011e-06, 0.36386073936095764]
# ['phi', 'multicore_cpu', 15, 13.919990977400682, 1.8286435185003238e-06, 0.36217349794729098]
# ['phi', 'multicore_cpu', 16, 0.09655124555360721, 1.0710316377287896e-06, 0.36191478857586423]
# ['phi', 'multicore_cpu', 17, 14.690347674870104, 2.0708381822443423e-06, 0.36558218246887508]
# ['phi', 'multicore_cpu', 18, 10.3439739012146, 1.711463210150818e-06, 0.36150366943650464]
# ['phi', 'multicore_cpu', 19, 11.598245213568894, 2.2661262014584187e-06, 0.3449992946901142]
# ['phi', 'multicore_cpu', 20, 0.24401507113129259, 2.1505296526945424e-06, 0.35999726999947629]
# ['phi', 'multicore_cpu', 21, 0.10277590203268534, 2.1742055878109675e-06, 0.38140339675688217]
# ['phi', 'multicore_cpu', 22, 0.85567149113449859, 2.2060641856791018e-06, 0.35464060037125944]
# ['phi', 'multicore_cpu', 23, 0.017413137617292657, 2.1608708649561813e-06, 0.36500786409285402]
# ['phi', 'multicore_cpu', 24, 0.76406468764689162, 2.3949315610811536e-06, 0.34226387632744304]
# ['phi', 'multicore_cpu', 25, 1.9492901714490021, 2.0788984625779634e-06, 0.36021358966232159]
# ['phi', 'multicore_cpu', 26, 5.2399920833482065, 2.2786405054656826e-06, 0.35255264402445802]
# ['phi', 'multicore_cpu', 27, 29.245128203455458, 2.1488519750839823e-06, 0.36488526825827039]
# ['phi', 'multicore_cpu', 28, 1.8220812220372782, 2.227128416521062e-06, 0.34676648692816037]
# ['phi', 'multicore_cpu', 29, 0.082756927145965359, 2.208141114580796e-06, 0.35276853129160307]
# ['phi', 'multicore_cpu', 30, 6.8446556227544277e-05, 2.3541547937831481e-06, 0.33982507919676691]
# ['phi', 'multicore_cpu', 31, 26.444287609071178, 2.0509122738121005e-06, 0.35839089812848607]
# ['phi', 'multicore_cpu', 32, 4.2747782164579968, 2.2571975423862864e-06, 0.35528290845685351]
# ['phi', 'multicore_cpu', 33, 31.39855821673741, 2.1236005241059796e-06, 0.39370527644381259]
# ['phi', 'multicore_cpu', 34, 10.824124799465929, 2.455570991934272e-06, 0.35148977423506872]
# ['phi', 'multicore_cpu', 35, 20.764532089986375, 5.7907541675858249e-06, 0.35446010849384646]
# ['phi', 'multicore_cpu', 36, 26.996348983784628, 5.4439994572368168e-06, 0.35635405436278172]
# ['phi', 'multicore_cpu', 37, 51.311750341197616, 5.3921071644692585e-06, 0.3484498668212837]
# ['phi', 'multicore_cpu', 38, 25.754209916864038, 5.1214181782401011e-06, 0.35755940565670769]
# ['phi', 'multicore_cpu', 39, 18.197562690691289, 5.3406067514739875e-06, 0.36625501468727961]
# ['phi', 'multicore_cpu', 40, 24.483615500454455, 5.4284435461877023e-06, 0.35499244043478528]
# ['phi', 'multicore_cpu', 41, 42.826969461461559, 5.7092080344527963e-06, 0.34894556001415838]
# ['phi', 'multicore_cpu', 42, 4.5734137913835404, 5.5468171261639827e-06, 0.35514695330896268]
# ['phi', 'multicore_cpu', 43, 37.068228905005491, 5.2969541305292843e-06, 0.36323852340331869]
# ['phi', 'multicore_cpu', 44, 61.922828426062409, 5.5701230134158099e-06, 0.36085185424479665]
# ['phi', 'multicore_cpu', 45, 28.506411635670609, 5.2805313215700533e-06, 0.35890596275936776]
# ['phi', 'multicore_cpu', 46, 22.158642177631609, 5.5179196297025614e-06, 0.35692015573632491]
# ['phi', 'multicore_cpu', 47, 29.915154624310606, 6.1777378438067585e-06, 0.34671806752861123]
# ['phi', 'multicore_cpu', 48, 23.885575663824536, 6.1973277146569489e-06, 0.3496624927684443]
# ['phi', 'multicore_cpu', 49, 28.44332767219899, 5.5865769428506511e-06, 0.36333907194434178]
# ['phi', 'multicore_cpu', 50, 64.14836554682563, 5.4908551922056819e-06, 0.35831439376973162]
# ['phi', 'multicore_cpu', 51, 25.231348431771959, 5.5392016089182881e-06, 0.35706785136549979]
# ['phi', 'multicore_cpu', 52, 16.343115324388677, 5.3895704025636615e-06, 0.35573409601588218]
# ['phi', 'multicore_cpu', 53, 22.107968130283467, 5.3654619907711626e-06, 0.36222639136615786]
# ['phi', 'multicore_cpu', 54, 45.863333535991224, 5.2395506897581198e-06, 0.35440930294083506]
# ['phi', 'multicore_cpu', 55, 23.565952359271147, 5.440636631780632e-06, 0.35722910378837103]
# ['phi', 'multicore_cpu', 56, 9.4861121937037307, 5.2167577086774443e-06, 0.3540176245928256]
# ['phi', 'multicore_cpu', 57, 13.956587477459024, 5.5001131623388769e-06, 0.3491972178627229]
# ['phi', 'multicore_cpu', 58, 67.42647049806115, 5.2103167910952501e-06, 0.36093369677532328]
# ['phi', 'multicore_cpu', 59, 31.510586598903441, 5.4996277649168235e-06, 0.36036667535457528]
# ['phi', 'multicore_cpu', 60, 6.9037496921458255, 5.5821216785487303e-06, 0.35710427544245565]
# ['phi', 'multicore_cpu', 61, 19.457294100291744, 5.6650077033958783e-06, 0.35199732481196905]
# ['phi', 'multicore_cpu', 62, 30.496800753142558, 3.9123142852618423e-06, 0.35583091182061372]
# ['phi', 'multicore_cpu', 63, 24.520803911448315, 4.6217224713071681e-06, 0.36895159205185019]
# ['phi', 'multicore_cpu', 64, 87.726172323856531, 5.8702298064206248e-06, 0.35937451993233749]
# ['phi', 'multicore_cpu', 65, 42.676769628167101, 5.598616679256358e-06, 0.35999456075697644]
# ['phi', 'multicore_cpu', 66, 158.23110641986091, 5.5619612436839592e-06, 0.35500603712265461]
# ['phi', 'multicore_cpu', 67, 35.616496469222604, 4.4998746661076377e-06, 0.35676751985194471]
# ['phi', 'multicore_cpu', 68, 20.584397457983933, 5.5541274622092898e-06, 0.35720145596467201]
# ['phi', 'multicore_cpu', 69, 132.68115540797115, 6.1105001073518345e-06, 0.34882191578928579]
# ['phi', 'multicore_cpu', 70, 16.342685207887413, 3.9895784521591042e-06, 0.36520077758580544]
# ['phi', 'multicore_cpu', 71, 71.850391782565239, 5.5560642252268492e-06, 0.35841280669988085]
# ['phi', 'multicore_cpu', 72, 49.952282471741263, 3.0619517331666726e-06, 0.35439789168532304]
# ['phi', 'multicore_cpu', 73, 13.88600201317948, 5.3877165959996711e-06, 0.36641833067244151]
# ['phi', 'multicore_cpu', 74, 9.0988707878416051, 4.7555537788635836e-06, 0.35780512846713891]
# ['phi', 'multicore_cpu', 75, 97.340694489427278, 6.4387806282876631e-06, 0.37257060270486048]
# ['phi', 'multicore_cpu', 76, 1.456787000691014, 3.2754044772248234e-06, 0.35368035418305005]
# ['phi', 'multicore_cpu', 77, 30.254481264374412, 1.7793603594618474e-06, 0.35271276806299023]
# ['phi', 'multicore_cpu', 78, 6.0829904807827031, 3.8511743234458449e-06, 0.35808471502287748]
# ['phi', 'multicore_cpu', 79, 41.038409799422688, 5.2025800808413016e-06, 0.36056352852643664]
# ['phi', 'multicore_cpu', 80, 7.8470343660966844, 3.9725842994352612e-06, 0.36282014673085838]
# ['phi', 'multicore_cpu', 81, 45.138961840852936, 2.3830483429198279e-06, 0.36146949030187231]
# ['phi', 'multicore_cpu', 82, 18.066603454202319, 5.4551780423920522e-06, 0.36529548273753976]
# ['phi', 'multicore_cpu', 83, 115.67109186518354, 5.010240406159222e-06, 0.36680670124922216]
# ['phi', 'multicore_cpu', 84, 38.785583906630492, 3.176113618277538e-06, 0.36151218714163058]
# ['phi', 'multicore_cpu', 85, 21.800259827315806, 5.6123277327652933e-06, 0.35513367959264064]
# ['phi', 'multicore_cpu', 86, 37.653315688320113, 2.8723519442982013e-06, 0.35994813297408768]
# ['phi', 'multicore_cpu', 87, 55.374632425840396, 2.904270178048828e-06, 0.35262038510447724]
# ['phi', 'multicore_cpu', 88, 9.690627511611817, 4.5803906203067704e-06, 0.35908931072991968]
# ['phi', 'multicore_cpu', 89, 0.94336629710330522, 5.9244338865533241e-06, 0.35236178381543426]
# ['phi', 'multicore_cpu', 90, 0.76970597925864148, 5.6077101689877727e-06, 0.35972350699940564]
# ['phi', 'multicore_cpu', 91, 0.82826337851433884, 5.924747623371373e-06, 0.36338828220947722]
# ['phi', 'multicore_cpu', 92, 0.8692238151767705, 5.4982418712100931e-06, 0.35888628405033074]
# ['phi', 'multicore_cpu', 93, 0.90373556323432613, 5.5700564808734662e-06, 0.35813369119421712]
# ['phi', 'multicore_cpu', 94, 62.87776401176032, 6.0728011182518362e-06, 0.34556426283122305]
# ['phi', 'multicore_cpu', 95, 54.312016941915147, 7.5604444285417634e-06, 0.33769805341374715]
# ['phi', 'multicore_cpu', 96, 39.467933319342023, 5.2283064556756585e-06, 0.36853549906474309]
# ['phi', 'multicore_cpu', 97, 53.722106983919417, 5.5509756611181827e-06, 0.36072803095547568]
# ['phi', 'multicore_cpu', 98, 48.274238388574979, 5.0113109227568064e-06, 0.36493170433866245]
# ['phi', 'multicore_cpu', 99, 63.445371648242912, 5.4370766033627308e-06, 0.35396768840747472]
# ['phi', 'multicore_cpu', 100, 68.545958190062862, 6.1404438692829415e-06, 0.35072541928749668]
# ['phi', 'multicore_cpu', 101, 88.522883423031558, 5.654648142594587e-06, 0.35110989598830439]
# ['phi', 'multicore_cpu', 102, 124.59159699301404, 5.3961629231599202e-06, 0.359173709218293]
# ['phi', 'multicore_cpu', 103, 181.67187424779124, 4.819227779097499e-06, 0.36722799022521052]
# ['phi', 'multicore_cpu', 104, 75.619874585322947, 5.5868607234695609e-06, 0.35635250134039964]
# ['phi', 'multicore_cpu', 105, 49.704332106182385, 6.5779351898867052e-06, 0.35452777106919864]
# ['phi', 'multicore_cpu', 106, 20.159093207776102, 5.0397315867630533e-06, 0.36135494665958739]
# ['phi', 'multicore_cpu', 107, 28.458702721496365, 5.7976309208458028e-06, 0.35637868489686153]
# ['phi', 'multicore_cpu', 108, 44.36384119190366, 5.4637701841904354e-06, 0.35305340428612114]
# ['phi', 'multicore_cpu', 109, 46.813452643327153, 5.4458223933387232e-06, 0.35967052801011135]
# ['phi', 'multicore_cpu', 110, 47.370571290826049, 6.0064570717913988e-06, 0.34620751570509695]
# ['phi', 'multicore_cpu', 111, 83.755621151273601, 6.2011125975531172e-06, 0.35679657485118577]
# ['phi', 'multicore_cpu', 112, 90.971146465288996, 5.5950414909050455e-06, 0.3598954407614558]
# ['phi', 'multicore_cpu', 113, 132.69252535337893, 5.965405850826901e-06, 0.35199729517886513]
# ['phi', 'multicore_cpu', 114, 97.463356249715247, 5.9292624008541202e-06, 0.36182629212681727]
# ['phi', 'multicore_cpu', 115, 47.069946543561024, 6.0586856516569874e-06, 0.34988105703794686]
# ['phi', 'multicore_cpu', 116, 39.78758403184014, 6.0361946952777157e-06, 0.36064880768761903]
# ['phi', 'multicore_cpu', 117, 98.29455321994466, 5.5162236848881866e-06, 0.3461065062344173]
# ['phi', 'multicore_cpu', 118, 194.01347780848641, 5.6788315654657349e-06, 0.35796775685405557]
# ['phi', 'multicore_cpu', 119, 97.545446510025243, 5.0327481540957902e-06, 0.39617605597243816]
# ['phi', 'multicore_cpu', 120, 78.554995226051233, 5.5895700710406036e-06, 0.34743840245570362]
# ['phi', 'multicore_cpu', 121, 50.481093091350417, 5.8808051820400723e-06, 0.33466196290783196]
# ['phi', 'multicore_cpu', 122, 74.49599103371952, 5.4009732201045005e-06, 0.33828918921132572]
# ['phi', 'multicore_cpu', 123, 50.396049049998069, 6.0730203942285712e-06, 0.33152094119612507]
# ['phi', 'multicore_cpu', 124, 68.962852004069433, 5.3520418435651768e-06, 0.34096761614236964]
# ['phi', 'multicore_cpu', 125, 41.901477118621443, 5.7045056542949358e-06, 0.34046537186842857]
# ['phi', 'multicore_cpu', 126, 120.18179044287437, 5.7591166963841685e-06, 0.34228635833049975]
# ['phi', 'multicore_cpu', 127, 58.140601912452645, 5.3566619368754974e-06, 0.34529888655772872]
# ['phi', 'opencl_gpu', 0, 3.644849825822698, 1.0857112729760838e-06, 1.3733786795892162]
# ['phi', 'opencl_gpu', 1, 2.7790563988765697, 1.177439622817501e-06, 1.3242856414467257]
# ['phi', 'opencl_gpu', 2, 3.8110073116311276, 1.0446850698965948e-06, 1.3486692755247611]
# ['phi', 'opencl_gpu', 3, 3.6021588723621885, 1.8016689155238842e-06, 1.2933735603509948]
# ['phi', 'opencl_gpu', 4, 3.6596691147091476, 1.0717378276473544e-06, 1.3633213120155874]
# ['phi', 'opencl_gpu', 5, 20.509629048476466, 1.1818964296190241e-06, 1.3262340222266928]
# ['phi', 'opencl_gpu', 6, 6.3736388654944749, 1.1252070290869018e-06, 1.3330589007903835]
# ['phi', 'opencl_gpu', 7, 13.133365235531256, 1.7368210030481366e-06, 1.303416587071007]
# ['phi', 'opencl_gpu', 8, 0.28435121155563697, 1.1197564674219626e-06, 1.3312725302285864]
# ['phi', 'opencl_gpu', 9, 13.625683031695118, 1.1499951342060305e-06, 1.3292799439266223]
# ['phi', 'opencl_gpu', 10, 14.280880984924471, 3.0825392451698048e-06, 1.5458891864184747]
# ['phi', 'opencl_gpu', 11, 15.117220808143575, 3.762946303710074e-06, 1.4402300698284052]
# ['phi', 'opencl_gpu', 12, 39.817726823386849, 3.3790243684356388e-06, 1.4785797961027252]
# ['phi', 'opencl_gpu', 13, 13.752606318471212, 4.3849969041928721e-06, 1.3731738636697779]
# ['phi', 'opencl_gpu', 14, 21.051518615679505, 1.8975948277364596e-06, 1.5204076019141564]
# ['phi', 'opencl_gpu', 15, 13.734786954235215, 3.8878096211401081e-06, 1.4682764415611089]
# ['phi', 'opencl_gpu', 16, 0.33106657675287893, 4.2030106271471651e-06, 1.4111480053296819]
# ['phi', 'opencl_gpu', 17, 13.485394889292934, 1.9158497990230726e-06, 1.4997873550802037]
# ['phi', 'opencl_gpu', 18, 10.102134923563511, 1.9323721701015287e-06, 1.516510915327929]
# ['phi', 'opencl_gpu', 19, 11.760377062787342, 4.1847191695802018e-06, 1.4628613868344158]
# ['phi', 'opencl_gpu', 20, 0.33636432575114611, 4.2034656207668434e-06, 1.3748435266055026]
# ['phi', 'opencl_gpu', 21, 0.24164616371432032, 4.3863407506310756e-06, 1.4155973622539169]
# ['phi', 'opencl_gpu', 22, 0.8782540165666417, 1.8303026399738827e-06, 1.5692465487769554]
# ['phi', 'opencl_gpu', 23, 0.016984737177580048, 3.5912656041626299e-06, 1.4362167835003674]
# ['phi', 'opencl_gpu', 24, 0.76684225172757559, 4.4022681491128271e-06, 1.4449489510476825]
# ['phi', 'opencl_gpu', 25, 5.980925475347953, 4.2296330072650943e-06, 1.4166450618769877]
# ['phi', 'opencl_gpu', 26, 6.5269713127161504, 3.576275793864327e-06, 1.4078748967860923]
# ['phi', 'opencl_gpu', 27, 27.162094284772543, 4.3368957369603538e-06, 1.4153568713117668]
# ['phi', 'opencl_gpu', 28, 3.2654245855885824, 3.5707441998901311e-06, 1.4542141545143576]
# ['phi', 'opencl_gpu', 29, 0.055605010712441207, 3.9284928920006241e-06, 1.4659396157422417]
# ['phi', 'opencl_gpu', 30, 0.00094954967549165604, 4.0674117461169289e-06, 1.4490898912982719]
# ['phi', 'opencl_gpu', 31, 27.395857302014548, 4.1947230641193263e-06, 1.3963439770709682]
# ['phi', 'opencl_gpu', 32, 6.429725253446203, 3.6432941073106051e-06, 1.3761903461547216]
# ['phi', 'opencl_gpu', 33, 32.450458191994471, 3.8704323473785449e-06, 1.462178632767748]
# ['phi', 'opencl_gpu', 34, 10.193818551028944, 3.7827630282833543e-06, 1.4552166570717262]
# ['phi', 'opencl_gpu', 35, inf, inf, inf]
# ['phi', 'opencl_gpu', 36, inf, inf, inf]
# ['phi', 'opencl_gpu', 37, 48.155961086106679, 2.020325038744098e-06, 1.0112659298855327]
# ['phi', 'opencl_gpu', 38, inf, inf, inf]
# ['phi', 'opencl_gpu', 39, 18.494945418268181, 7.5939717500115695e-07, 1.0162154591601831]
# ['phi', 'opencl_gpu', 40, 26.486818830037851, 9.7026327381963965e-06, 0.93449420514314052]
# ['phi', 'opencl_gpu', 41, 44.029708094405535, 1.1151198718858831e-05, 0.9454045140224957]
# ['phi', 'opencl_gpu', 42, inf, inf, inf]
# ['phi', 'opencl_gpu', 43, 38.935694744542303, 1.1301077967104763e-05, 0.94476445032202705]
# ['phi', 'opencl_gpu', 44, inf, inf, inf]
# ['phi', 'opencl_gpu', 45, 28.372440018341027, 2.8783072596021898e-07, 1.0099838588548744]
# ['phi', 'opencl_gpu', 46, 21.739424672480144, 3.8501422301583679e-06, 1.0232959685118306]
# ['phi', 'opencl_gpu', 47, 29.526433662938942, 1.6573582524838887e-06, 1.0061908027400142]
# ['phi', 'opencl_gpu', 48, 22.770066743195869, 1.6054103685463221e-06, 0.98209676224252429]
# ['phi', 'opencl_gpu', 49, 29.667636212541428, 1.3722407299540522e-06, 1.0106707023537675]
# ['phi', 'opencl_gpu', 50, 47.947849124865805, 9.6943876017701187e-07, 1.0130636505458668]
# ['phi', 'opencl_gpu', 51, 24.462862996070136, 7.9003431486048262e-06, 0.96176856082418649]
# ['phi', 'opencl_gpu', 52, inf, inf, inf]
# ['phi', 'opencl_gpu', 53, 23.397494517415701, 1.667213108228606e-05, 0.91454891018245565]
# ['phi', 'opencl_gpu', 54, 39.06290166682632, 1.6822355933811382e-05, 0.92410303820734452]
# ['phi', 'opencl_gpu', 55, 24.962920632508709, 8.6474972185881073e-06, 0.94773171051688831]
# ['phi', 'opencl_gpu', 56, 12.518572632674037, 8.9313179513682839e-06, 0.96773940687594229]
# ['phi', 'opencl_gpu', 57, inf, inf, inf]
# ['phi', 'opencl_gpu', 58, 53.115515538732502, 1.2284448872442716e-06, 1.0085076052209605]
# ['phi', 'opencl_gpu', 59, 39.184877265215896, 1.0060370072074603e-05, 0.95012458822001578]
# ['phi', 'opencl_gpu', 60, 9.1086253457477842, 5.4636192321778549e-06, 1.1716602087020873]
# ['phi', 'opencl_gpu', 61, inf, inf, inf]
# ['phi', 'opencl_gpu', 62, 30.358616680862163, 5.4346841314564914e-06, 1.2070287548977399]
# ['phi', 'opencl_gpu', 63, 23.348617231990534, 1.2277706809666144e-06, 1.2137520759002027]
# ['phi', 'opencl_gpu', 64, 96.013335690120172, 1.6060332837312164e-05, 1.0770454541496615]
# ['phi', 'opencl_gpu', 65, inf, inf, inf]
# ['phi', 'opencl_gpu', 66, 165.57456586855079, 1.2482502356819595e-05, 1.0712953660799112]
# ['phi', 'opencl_gpu', 67, 37.806790820468784, 1.682132845339674e-06, 1.1989301474198051]
# ['phi', 'opencl_gpu', 68, inf, inf, inf]
# ['phi', 'opencl_gpu', 69, 124.3920367618053, 1.9556653810584073e-05, 1.0551367956659072]
# ['phi', 'opencl_gpu', 70, inf, inf, inf]
# ['phi', 'opencl_gpu', 71, inf, inf, inf]
# ['phi', 'opencl_gpu', 72, 50.162113251283913, 3.8506516166356212e-06, 1.2275922267333321]
# ['phi', 'opencl_gpu', 73, inf, inf, inf]
# ['phi', 'opencl_gpu', 74, 9.5245984579418401, 3.9245155583258436e-06, 1.1366210657617322]
# ['phi', 'opencl_gpu', 75, inf, inf, inf]
# ['phi', 'opencl_gpu', 76, 2.5122390788425508, 3.9580383922742817e-05, 0.98226224546847163]
# ['phi', 'opencl_gpu', 77, inf, inf, inf]
# ['phi', 'opencl_gpu', 78, inf, inf, inf]
# ['phi', 'opencl_gpu', 79, 43.187172884523648, 2.7572900315989702e-05, 1.0546419744906224]
# ['phi', 'opencl_gpu', 80, 6.4991910611201815, 2.2758490106335184e-06, 1.2223521626513936]
# ['phi', 'opencl_gpu', 81, 43.571886514635459, 5.8519469136778212e-06, 1.2182579538096556]
# ['phi', 'opencl_gpu', 82, inf, inf, inf]
# ['phi', 'opencl_gpu', 83, 100.9873239554537, 9.3668730362615298e-07, 1.175198693897413]
# ['phi', 'opencl_gpu', 84, inf, inf, inf]
# ['phi', 'opencl_gpu', 85, inf, inf, inf]
# ['phi', 'opencl_gpu', 86, 36.210713153568378, 1.4861947971841605e-05, 1.1427896966104925]
# ['phi', 'opencl_gpu', 87, 55.08125393466527, 3.9817391271177271e-06, 1.1693545600642328]
# ['phi', 'opencl_gpu', 88, 10.980254121713118, 1.7564951647882919e-05, 1.1130201039106953]
# ['phi', 'opencl_gpu', 89, 0.93085012697250036, 1.0861452144125305e-05, 1.0886732350225035]
# ['phi', 'opencl_gpu', 90, 0.84376479620916367, 1.5809275792992709e-05, 1.0730646651724109]
# ['phi', 'opencl_gpu', 91, 0.82205261574952493, 3.9855015381522889e-05, 0.92547818681468119]
# ['phi', 'opencl_gpu', 92, 0.86024291309466117, 3.1331369151241368e-06, 1.1550394576528795]
# ['phi', 'opencl_gpu', 93, 0.91186990617454622, 2.2453362838081805e-05, 1.0372039411378944]
# ['phi', 'opencl_gpu', 94, inf, inf, inf]
# ['phi', 'opencl_gpu', 95, 52.332671076933025, 2.5102930483610902e-05, 1.032708416814389]
# ['phi', 'opencl_gpu', 96, inf, inf, inf]
# ['phi', 'opencl_gpu', 97, inf, inf, inf]
# ['phi', 'opencl_gpu', 98, inf, inf, inf]
# ['phi', 'opencl_gpu', 99, 65.029406687835177, 2.1437116291213278e-06, 1.1691808120064116]
# ['phi', 'opencl_gpu', 100, 70.969328600349201, 2.2140315304631825e-05, 1.0253358664719956]
# ['phi', 'opencl_gpu', 101, 110.0539958575812, 1.2061680296193083e-05, 1.0684723729672641]
# ['phi', 'opencl_gpu', 102, 139.88057073703035, 3.6468942269035147e-05, 0.93825344106425379]
# ['phi', 'opencl_gpu', 103, inf, inf, inf]
# ['phi', 'opencl_gpu', 104, 96.634195649989806, 1.5656448032545052e-05, 1.0663196480792503]
# ['phi', 'opencl_gpu', 105, 47.749117349348658, 1.2291226179704302e-06, 1.1824835652890415]
# ['phi', 'opencl_gpu', 106, inf, inf, inf]
# ['phi', 'opencl_gpu', 107, 31.346736191509358, 1.5768816160120312e-06, 1.1821751407955003]
# ['phi', 'opencl_gpu', 108, 51.235682086888197, 1.939016549483593e-05, 1.0463973802068962]
# ['phi', 'opencl_gpu', 109, 50.731529771977826, 2.8822995890741865e-05, 1.0203103956968886]
# ['phi', 'opencl_gpu', 110, 48.099021673976807, 1.5222412606944319e-05, 1.0667188053545742]
# ['phi', 'opencl_gpu', 111, inf, inf, inf]
# ['phi', 'opencl_gpu', 112, inf, inf, inf]
# ['phi', 'opencl_gpu', 113, 108.92581283394911, 4.8887750376831321e-07, 1.15797408145407]
# ['phi', 'opencl_gpu', 114, 135.79945710637554, 2.4776775940605623e-06, 1.1595297637193103]
# ['phi', 'opencl_gpu', 115, inf, inf, inf]
# ['phi', 'opencl_gpu', 116, 40.152329171060707, 1.549500589785481e-06, 1.171721223126287]
# ['phi', 'opencl_gpu', 117, inf, inf, inf]
# ['phi', 'opencl_gpu', 118, 187.99843402612453, 2.2600201316501915e-05, 1.0370871948159257]
# ['phi', 'opencl_gpu', 119, 100.98044681337535, 8.5669511297476111e-06, 1.0936249100643656]
# ['phi', 'opencl_gpu', 120, 75.642685267396772, 4.2362001667852844e-06, 1.1530282455941907]
# ['phi', 'opencl_gpu', 121, 49.516950323124142, 1.7585392827573084e-05, 1.0564521043196973]
# ['phi', 'opencl_gpu', 122, inf, inf, inf]
# ['phi', 'opencl_gpu', 123, 49.486761212419914, 2.1528137117152774e-05, 0.90758547409921797]
# ['phi', 'opencl_gpu', 124, 86.732263622138319, 2.167782368867373e-06, 0.98482431328814934]
# ['phi', 'opencl_gpu', 125, 47.91616932383689, 5.1674198646789421e-05, 0.86193967743299549]
# ['phi', 'opencl_gpu', 126, 100.85740931735467, 1.0860566488421518e-05, 1.0516624030942054]
# ['phi', 'opencl_gpu', 127, 56.429761435195573, 2.0720282514044563e-05, 0.90404484069093682]
# ['ee-snowball0', 'opencl_gpu', 0, 2.6305902027772352, 6.7823654788492238e-08, 0.085819313797952518]
# ['ee-snowball0', 'opencl_gpu', 1, 2.5022704462198124, 6.7311470629925126e-08, 0.091044901602092262]
# ...
# ['ee-mollie', 'multicore_cpu', 96, 35.744690254367747, 1.5682799993272036e-05, 0.091207689088297253]
# ['ee-mollie', 'multicore_cpu', 97, 50.634014145699446, 1.5351663906831498e-05, 0.07977021977528953]
# ['ee-mollie', 'multicore_cpu', 98, 49.314309498554429, 1.4998245784703958e-05, 0.067859428399131685]
# ['ee-mollie', 'multicore_cpu', 99, 63.356591732484432, 1.5290773745506235e-05, 0.062679500619962886]
# ['ee-mollie', 'multicore_cpu', 100, 63.464555076448519, 1.5350252725074372e-05, 0.0811855419058089]
# ['ee-mollie', 'multicore_cpu', 101, 87.853937491526437, 1.5909080463200745e-05, 0.082876330987027805]
# ['ee-mollie', 'multicore_cpu', 102, 131.36340718148836, 1.5928281080035587e-05, 0.079492188394178612]
# ['ee-mollie', 'multicore_cpu', 103, 189.36282806745632, 1.5672281086982949e-05, 0.092665903929428722]
# ['ee-mollie', 'multicore_cpu', 104, 121.74660717376284, 1.5704448955199925e-05, 0.054070461673087468]
# ['ee-mollie', 'multicore_cpu', 105, 47.364673442760235, 1.5453649772629378e-05, 0.082116451156126272]
# ['ee-mollie', 'multicore_cpu', 106, 19.094049774291648, 1.55506350394898e-05, 0.074355602779102248]
# ['ee-mollie', 'multicore_cpu', 107, 31.624864640914478, 1.5369234740457939e-05, 0.08610449507696219]
# ['ee-mollie', 'multicore_cpu', 108, 48.274932190070054, 1.520264485450187e-05, 0.078148615552181194]
# ['ee-mollie', 'multicore_cpu', 109, 39.810782846026079, 1.5367808115417062e-05, 0.054797850360025879]
# ['ee-mollie', 'multicore_cpu', 110, 48.840064902607651, 1.5431207014840913e-05, 0.08673940623936259]
# ['ee-mollie', 'multicore_cpu', 111, 111.28374969844735, 1.540778343849299e-05, 0.087523263114911029]
# ['ee-mollie', 'multicore_cpu', 112, 125.29997047328706, 1.5608696845311486e-05, 0.061682344896209704]
# ['ee-mollie', 'multicore_cpu', 113, 139.26754587759228, 1.5769534680078042e-05, 0.078319234792190717]
# ['ee-mollie', 'multicore_cpu', 114, 140.68507471618494, 1.5356653546899033e-05, 0.060529563542996483]
# ['ee-mollie', 'multicore_cpu', 115, 48.58336067637574, 1.5757880608180036e-05, 0.067739572544216461]
# ['ee-mollie', 'multicore_cpu', 116, 42.237205840295147, 1.5396879439356844e-05, 0.069684227787440683]
# ['ee-mollie', 'multicore_cpu', 117, 91.534684454480654, 1.5824063178058379e-05, 0.075547489799774437]
# ['ee-mollie', 'multicore_cpu', 118, 154.49301885352955, 1.5774894297454739e-05, 0.054083352720523635]
# ['ee-mollie', 'multicore_cpu', 119, 114.46321851367792, 1.578694009395516e-05, 0.068616802933187268]
# ['ee-mollie', 'multicore_cpu', 120, 76.151457219140966, 1.5082845450360109e-05, 0.065007593759982607]
# ['ee-mollie', 'multicore_cpu', 121, 52.783458857043023, 1.5419317753835558e-05, 0.064830438326533069]
# ['ee-mollie', 'multicore_cpu', 122, 82.684961524676098, 1.5663739626174839e-05, 0.075279772565166755]
# ['ee-mollie', 'multicore_cpu', 123, 50.319459754134101, 1.4999177569322493e-05, 0.07970460730509743]
# ['ee-mollie', 'multicore_cpu', 124, 87.567265760142305, 1.4942217196282332e-05, 0.080867801635552336]
# ['ee-mollie', 'multicore_cpu', 125, 61.010188632794012, 1.4598807442719318e-05, 0.066483492812872996]
# ['ee-mollie', 'multicore_cpu', 126, 90.624228308543834, 1.4791182700409607e-05, 0.059342041409935938]
# ['ee-mollie', 'multicore_cpu', 127, 53.214282452635182, 1.4684532046038217e-05, 0.061763480797469975]
# ['ee-mollie', 'maxeler_fpga', 0, 2.2709256561442546, 1.401325701664816e-07, 0.057621971011713922]
# ['ee-mollie', 'maxeler_fpga', 1, 0.45473436834091596, 1.3846789585013431e-07, 0.066698917038640171]
# ['ee-mollie', 'maxeler_fpga', 2, 4.304225995147263, 1.3599577864754484e-07, 0.067547627894364068]
# ['ee-mollie', 'maxeler_fpga', 3, 3.3745286412284496, 1.356297504970347e-07, 0.077101840083543011]
# ['ee-mollie', 'maxeler_fpga', 4, 3.5274089566932516, 1.3772872614913261e-07, 0.063683044640752001]
# ['ee-mollie', 'maxeler_fpga', 5, 17.498256575144733, 1.3638396633467756e-07, 0.063067199400566626]
# ['ee-mollie', 'maxeler_fpga', 6, 6.2388376057078254, 1.3792340812525289e-07, 0.058471471093087701]
# ['ee-mollie', 'maxeler_fpga', 7, 12.039858058955417, 1.3554241966961985e-07, 0.067411949929226098]
# ['ee-mollie', 'maxeler_fpga', 8, 0.011496090187124525, 1.3884599610307714e-07, 0.063668116167972216]
# ['ee-mollie', 'maxeler_fpga', 9, 12.788836841645791, 1.3930344378437176e-07, 0.064818188946557553]
# ['ee-mollie', 'maxeler_fpga', 10, 14.423917361512384, 1.3825690899794484e-07, 0.065131660074522466]
# ['ee-mollie', 'maxeler_fpga', 11, 13.387516623301433, 1.3760954498589954e-07, 0.071130029852262952]
# ['ee-mollie', 'maxeler_fpga', 12, 33.419291830759278, 1.3878737013784628e-07, 0.068958867737198171]
# ['ee-mollie', 'maxeler_fpga', 13, 13.832533330387715, 1.3845969522149368e-07, 0.071918361541562795]
# ['ee-mollie', 'maxeler_fpga', 14, 23.314191431898777, 1.3873657059944528e-07, 0.060036574908755802]
# ['ee-mollie', 'maxeler_fpga', 15, 12.813417807073161, 1.3799982430132754e-07, 0.068972777476390801]
# ['ee-mollie', 'maxeler_fpga', 16, 0.027500203353261629, 1.3683389829959383e-07, 0.066905474223885208]
# ['ee-mollie', 'maxeler_fpga', 17, 15.377635876221484, 1.4098794805698913e-07, 0.066886613211865176]
# ['ee-mollie', 'maxeler_fpga', 18, 8.8745861170847746, 1.3762116437332678e-07, 0.069296664355139218]
# ['ee-mollie', 'maxeler_fpga', 19, 5.3260704746100629, 1.4183933082586404e-07, 0.062493959265640428]
# ['ee-mollie', 'maxeler_fpga', 20, inf, inf, inf]
# ['ee-mollie', 'maxeler_fpga', 21, 0.077392618211916203, 1.3935985154339013e-07, 0.072649927007474108]
# ['ee-mollie', 'maxeler_fpga', 22, 0.83957781485927574, 1.4071456090360116e-07, 0.075568644588181716]
# ['ee-mollie', 'maxeler_fpga', 23, 0.00014073931761348138, 1.3836604579736327e-07, 0.080519767742252168]
# ['ee-mollie', 'maxeler_fpga', 24, 0.86780593135730855, 1.4221492512769329e-07, 0.078217996056129238]
# ['ee-mollie', 'maxeler_fpga', 25, 0.23743294648362123, 1.4291146813043069e-07, 0.078069431864148553]
# ['ee-mollie', 'maxeler_fpga', 26, 9.3152308455864379, 1.4372905491201227e-07, 0.072591321625096572]
# ['ee-mollie', 'maxeler_fpga', 27, 20.695853031201732, 1.3998169898692431e-07, 0.073620225871717584]
# ['ee-mollie', 'maxeler_fpga', 28, 0.2796814808339706, 1.4110738340586911e-07, 0.07829831312426376]
# ['ee-mollie', 'maxeler_fpga', 29, 0.0014856480921525408, 1.4217639656314697e-07, 0.080739160530510237]
# ['ee-mollie', 'maxeler_fpga', 30, 9.3912977625917297e-07, 1.4109843653504996e-07, 0.086032793493317647]
# ['ee-mollie', 'maxeler_fpga', 31, 34.98505873921912, 1.4080569916113536e-07, 0.083914542326807257]
# ['ee-mollie', 'maxeler_fpga', 32, 5.2268264164324707, 1.432948690829207e-07, 0.078924003263223977]
# ['ee-mollie', 'maxeler_fpga', 33, 26.018898561752067, 1.4069636335656476e-07, 0.090126055647240105]
# ['ee-mollie', 'maxeler_fpga', 34, 8.0502576964716859, 1.4114416403251526e-07, 0.078806738661472212]
# ['ee-mollie', 'maxeler_fpga', 35, 16.625880849146473, 2.8352880800745915e-07, 0.073311162835258958]
# ['ee-mollie', 'maxeler_fpga', 36, 13.716037275500707, 2.8441331354128268e-07, 0.084591929000164115]
# ['ee-mollie', 'maxeler_fpga', 37, 40.097593526761088, 2.6614141730105296e-07, 0.095202229724722531]
# ['ee-mollie', 'maxeler_fpga', 38, 21.677722525658929, 2.9361023802643247e-07, 0.083466744131684853]
# ['ee-mollie', 'maxeler_fpga', 39, 22.786970515690943, 2.8144364101033791e-07, 0.088871432098148517]
# ['ee-mollie', 'maxeler_fpga', 40, 40.608097235995274, 2.7962981152789023e-07, 0.096995909394339344]
# ['ee-mollie', 'maxeler_fpga', 41, 42.711345428628476, 2.8339154590031279e-07, 0.086014303971584438]
# ['ee-mollie', 'maxeler_fpga', 42, 2.4211381285314344, 2.8323122868931259e-07, 0.089522226153098863]
# ['ee-mollie', 'maxeler_fpga', 43, 40.239520840012787, 2.6531898700540923e-07, 0.12337740615871373]
# ['ee-mollie', 'maxeler_fpga', 44, 29.476763654278109, 2.780930966829295e-07, 0.099045994286578634]
# ['ee-mollie', 'maxeler_fpga', 45, 33.478027928788102, 2.8799512163019312e-07, 0.086487622052796073]
# ['ee-mollie', 'maxeler_fpga', 46, 18.89310044729973, 2.9060710105165413e-07, 0.086540116330093439]
# ['ee-mollie', 'maxeler_fpga', 47, 29.407399610635764, 2.8507808937414299e-07, 0.095521950243013867]
# ['ee-mollie', 'maxeler_fpga', 48, 16.249754809306715, 2.8696101583331128e-07, 0.079297042998380127]
# ['ee-mollie', 'maxeler_fpga', 49, 36.21032443689991, 2.8096847941215516e-07, 0.085709420920980481]
# ['ee-mollie', 'maxeler_fpga', 50, 51.050399197171508, 2.8240564123236042e-07, 0.10884249119597574]
# ['ee-mollie', 'maxeler_fpga', 51, 24.341684436578412, 2.8947366254755096e-07, 0.081474566722717648]
# ['ee-mollie', 'maxeler_fpga', 52, 13.248551085559361, 2.8955325003818417e-07, 0.085817103996974273]
# ['ee-mollie', 'maxeler_fpga', 53, 14.592699081087297, 2.9138856277333694e-07, 0.086833898722569969]
# ['ee-mollie', 'maxeler_fpga', 54, 47.663169555734505, 2.8337615718877143e-07, 0.098592527661579679]
# ['ee-mollie', 'maxeler_fpga', 55, 22.995179447183514, 2.8091326181032166e-07, 0.076879421903317757]
# ['ee-mollie', 'maxeler_fpga', 56, 10.709613921739836, 3.0341986779149707e-07, 0.088765757599523862]
# ['ee-mollie', 'maxeler_fpga', 57, 25.152714350951779, 2.954132763693791e-07, 0.091764448487503467]
# ['ee-mollie', 'maxeler_fpga', 58, 58.618059421367896, 2.8872095034855153e-07, 0.092864633922089032]
# ['ee-mollie', 'maxeler_fpga', 59, 125.30513791746705, 2.8586736907745459e-07, 0.088446232660310709]
# ['ee-mollie', 'maxeler_fpga', 60, 2.1743317021958077, 2.854149235609305e-07, 0.11971921432570125]
# ['ee-mollie', 'maxeler_fpga', 61, 23.337090166575436, 2.8420878466782366e-07, 0.11030938250718905]
# ['ee-mollie', 'maxeler_fpga', 62, 18.111326181852423, 2.952275640961693e-07, 0.085380629220137325]
# ['ee-mollie', 'maxeler_fpga', 63, 25.046233859597809, 2.9114419886094661e-07, 0.11652945931337635]
# ['ee-mollie', 'maxeler_fpga', 64, 90.209004760412981, 2.9190824415492196e-07, 0.10483204477802435]
# ['ee-mollie', 'maxeler_fpga', 65, 51.503194979079119, 2.7868918177909668e-07, 0.082145626343561207]
# ['ee-mollie', 'maxeler_fpga', 66, 100.87817950801566, 2.8463901464643147e-07, 0.099316109911596645]
# ['ee-mollie', 'maxeler_fpga', 67, 28.703345079239956, 2.8366397199487656e-07, 0.097510221394631613]
# ['ee-mollie', 'maxeler_fpga', 68, 25.090744079347431, 2.898602567836418e-07, 0.083585464786303382]
# ['ee-mollie', 'maxeler_fpga', 69, 183.20038272935113, 2.9125846061314942e-07, 0.092803668359277267]
# ['ee-mollie', 'maxeler_fpga', 70, 8.8506926375027941, 2.8772723789309479e-07, 0.098896165412790879]
# ['ee-mollie', 'maxeler_fpga', 71, 63.121434376720032, 2.8500117196335538e-07, 0.077686490914130532]
# ['ee-mollie', 'maxeler_fpga', 72, 46.533512024756369, 2.8659111842802862e-07, 0.096742382450386008]
# ['ee-mollie', 'maxeler_fpga', 73, 27.438098035295599, 2.9042713846910647e-07, 0.078111762517286701]
# ['ee-mollie', 'maxeler_fpga', 74, 7.3272858619089813, 2.8526881164674882e-07, 0.092723189775238024]
# ['ee-mollie', 'maxeler_fpga', 75, 134.84793212725666, 2.7127731878895014e-07, 0.085276202088762007]
# ['ee-mollie', 'maxeler_fpga', 76, 0.40435153504178822, 2.93601307940269e-07, 0.087521846782258453]
# ['ee-mollie', 'maxeler_fpga', 77, 10.277493363328301, 2.8160488447885987e-07, 0.077140915639234281]
# ['ee-mollie', 'maxeler_fpga', 78, 2.6952260622728357, 2.8753629007305419e-07, 0.098400041416341621]
# ['ee-mollie', 'maxeler_fpga', 79, 51.210609906442293, 2.8866642601142172e-07, 0.07181799942002004]
# ['ee-mollie', 'maxeler_fpga', 80, 8.5221205435397742, 2.8260222120694911e-07, 0.098191959988992175]
# ['ee-mollie', 'maxeler_fpga', 81, 45.702942456895691, 2.780884077665832e-07, 0.082995744933500051]
# ['ee-mollie', 'maxeler_fpga', 82, 8.5714956304389478, 2.8692180377585905e-07, 0.093159589599523543]
# ['ee-mollie', 'maxeler_fpga', 83, 95.263498300416657, 2.8854452600215074e-07, 0.084119135503516448]
# ['ee-mollie', 'maxeler_fpga', 84, 32.254793212996944, 2.9114753075964884e-07, 0.076345417677655666]
# ['ee-mollie', 'maxeler_fpga', 85, 28.629266669598451, 2.92475792549149e-07, 0.071278879722414618]
# ['ee-mollie', 'maxeler_fpga', 86, 32.385909684759497, 2.8633056752589368e-07, 0.094088169779825204]
# ['ee-mollie', 'maxeler_fpga', 87, 61.053243499426635, 2.8807973677052519e-07, 0.093889210001260215]
# ['ee-mollie', 'maxeler_fpga', 88, 7.3357059104713773, 2.9656639804822897e-07, 0.099813168692298296]
# ['ee-mollie', 'maxeler_fpga', 89, 0.83160260706871902, 2.9455175606862086e-07, 0.083073205176471696]
# ['ee-mollie', 'maxeler_fpga', 90, 0.83399044183155446, 2.8667376710861897e-07, 0.080845377360779125]
# ['ee-mollie', 'maxeler_fpga', 91, 0.83760452549106512, 2.9780380162527284e-07, 0.069178352269332402]
# ['ee-mollie', 'maxeler_fpga', 92, 0.87638911434315125, 2.9072836820673297e-07, 0.10384477127206329]
# ['ee-mollie', 'maxeler_fpga', 93, 0.88184283157764121, 2.8666281552730474e-07, 0.10338597001658437]
# ['ee-mollie', 'maxeler_fpga', 94, 65.185545257798111, 2.9180757953423551e-07, 0.077746002175060627]
# ['ee-mollie', 'maxeler_fpga', 95, 55.75233204220676, 3.0231721830860739e-07, 0.095355419000055272]
# ['ee-mollie', 'maxeler_fpga', 96, 34.326067881079702, 2.910881288475943e-07, 0.095192984587106899]
# ['ee-mollie', 'maxeler_fpga', 97, 38.039483086910039, 2.9738050194257741e-07, 0.11508045396295033]
# ['ee-mollie', 'maxeler_fpga', 98, 73.477419248774083, 3.0103238385808901e-07, 0.099708129976473242]
# ['ee-mollie', 'maxeler_fpga', 99, 68.041706649983396, 2.9718039456695782e-07, 0.093571937474366942]
# ['ee-mollie', 'maxeler_fpga', 100, 51.498880081167066, 3.0042927757232674e-07, 0.082278305059548223]
# ['ee-mollie', 'maxeler_fpga', 101, 48.64898612098326, 2.9379375792200056e-07, 0.1048600950783988]
# ['ee-mollie', 'maxeler_fpga', 102, 150.14527289449663, 2.8699927122214367e-07, 0.099972497471919913]
# ['ee-mollie', 'maxeler_fpga', 103, 139.64633885506962, 2.8923899666908469e-07, 0.076950119711819018]
# ['ee-mollie', 'maxeler_fpga', 104, 104.74945213514184, 2.9224189339077205e-07, 0.093670450656734336]
# ['ee-mollie', 'maxeler_fpga', 105, 53.277192385734281, 2.8756998289099831e-07, 0.064623222858668006]
# ['ee-mollie', 'maxeler_fpga', 106, 18.598690942877209, 2.8220370629049754e-07, 0.065542650803666211]
# ['ee-mollie', 'maxeler_fpga', 107, 29.778046839207178, 2.8202245463967022e-07, 0.06927089803749828]
# ['ee-mollie', 'maxeler_fpga', 108, 44.215696819358946, 2.8133301001292425e-07, 0.061588558173113941]
# ['ee-mollie', 'maxeler_fpga', 109, 105.69586609019798, 2.8788421865395603e-07, 0.061248897864276133]
# ['ee-mollie', 'maxeler_fpga', 110, 55.393960904895174, 2.8482644434374784e-07, 0.0617199111288751]
# ['ee-mollie', 'maxeler_fpga', 111, 146.42831141602005, 2.8121098093154886e-07, 0.065901607328408898]
# ['ee-mollie', 'maxeler_fpga', 112, 91.34835884128168, 2.8258259274476061e-07, 0.064383128071282769]
# ['ee-mollie', 'maxeler_fpga', 113, 147.76216266906331, 2.8040960493085284e-07, 0.06141527756852834]
# ['ee-mollie', 'maxeler_fpga', 114, 131.22269343963157, 2.7915825248606211e-07, 0.066502304042855592]
# ['ee-mollie', 'maxeler_fpga', 115, 49.45836357088848, 2.7646402058018305e-07, 0.065261783220263089]
# ['ee-mollie', 'maxeler_fpga', 116, 28.714134249668035, 2.7859765703422737e-07, 0.067424170877128015]
# ['ee-mollie', 'maxeler_fpga', 117, 94.457117516708763, 2.8278713366482375e-07, 0.061940687221984259]
# ['ee-mollie', 'maxeler_fpga', 118, 150.84253337910104, 2.8276161428638952e-07, 0.06780562764037508]
# ['ee-mollie', 'maxeler_fpga', 119, 87.885370784052768, 2.7876500393565841e-07, 0.057570902884752105]
# ['ee-mollie', 'maxeler_fpga', 120, 73.74648525359224, 2.8746592890337765e-07, 0.064578179766359267]
# ['ee-mollie', 'maxeler_fpga', 121, 47.365236781972747, 2.7536856620551422e-07, 0.06735724525731393]
# ['ee-mollie', 'maxeler_fpga', 122, 76.191394468895595, 2.7804430627616797e-07, 0.059424318017071723]
# ['ee-mollie', 'maxeler_fpga', 123, 50.599820254021871, 2.7911150815010835e-07, 0.058716782892374447]
# ['ee-mollie', 'maxeler_fpga', 124, 65.954791475930207, 2.8194091019251954e-07, 0.058659205709731238]
# ['ee-mollie', 'maxeler_fpga', 125, 43.491260001029453, 2.7908461534900102e-07, 0.05934961362573539]
# ['ee-mollie', 'maxeler_fpga', 126, 67.856076377478999, 2.8198859964390508e-07, 0.059046607356266295]
# ['ee-mollie', 'maxeler_fpga', 127, 53.907688459935706, 2.7701195902652105e-07, 0.05736583384490488]
