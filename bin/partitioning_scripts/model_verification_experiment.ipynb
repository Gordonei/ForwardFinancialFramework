# %% [markdown]
# # Partitioning Verification Experiment

# %% [markdown]
# Aim:
# * Verify that the approach to modelling the runtime characteristics of execution of tasks upon various platforms is correct, and that the
# * Verify the SCIP-based partitioner schedule based upon these model inputs

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Option Pricing Tasks

# %% [markdown]
# The options all have non-zero values for reasonably small numbers of tasks

# %%
import csv

options = []
with open('valid_seeds_file.csv','r') as valid_seeds_file:
    csvreader = csv.DictReader(valid_seeds_file,delimiter=',')
    options = [row for row in csvreader]

# %%
tasks = {}
for o in options:
    temp_task = "%s %s"%(o['underlying'],o['option'])
    if(temp_task not in tasks): tasks[temp_task] = 0
    tasks[temp_task] += 1
    
print("Portfolio of Option Pricing Tasks")
total = 0
for t in sorted(tasks):
    print("%s: %d"%(t,tasks[t]))
    total += tasks[t]
    
print("total tasks:%d"%total)
# Out:
# Portfolio of Option Pricing Tasks
# black_scholes asian: 10
# black_scholes barrier: 10
# black_scholes digital_double_barrier: 5
# black_scholes double_barrier: 10
# heston asian: 25
# heston barrier: 29
# heston digital_double_barrier: 5
# heston double_barrier: 29
# heston european: 5
# total tasks:128

# %%
compile_string = ""
for t in tasks: compile_string += "python2.7 mc_solver_option_test.py CPU \"Generate Compile\" 1000 \"%s 1234\";"%t
print(compile_string)
# Out:
# python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "black_scholes barrier 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "heston european 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "heston barrier 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "heston double_barrier 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "black_scholes asian 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "heston digital_double_barrier 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "black_scholes double_barrier 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "heston asian 1234";python2.7 mc_solver_option_test.py CPU "Generate Compile" 1000 "black_scholes digital_double_barrier 1234";

# %%
import ForwardFinancialFramework.bin.option_generator as option_generator

option_tasks = [option_generator.generate_option(int(o['seed']),underlying_type=o['underlying'],option_type=o['option']) for o in options]

# %% [markdown]
# ### Platforms

# %%
from ForwardFinancialFramework.Platforms.MulticoreCPU import MulticoreCPU_MonteCarlo, MulticoreCPU
from ForwardFinancialFramework.Platforms.OpenCLGPU import OpenCLGPU_MonteCarlo,OpenCLGPU
from ForwardFinancialFramework.Platforms.OpenCLAlteraFPGA import OpenCLAlteraFPGA_MonteCarlo,OpenCLAlteraFPGA
from ForwardFinancialFramework.Platforms.MaxelerFPGA import MaxelerFPGA_MonteCarlo,MaxelerFPGA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-164-44c62fdd4f2d> in <module>()
# ----> 1 from ForwardFinancialFramework.Platforms.MulticoreCPU import MulticoreCPU_MonteCarlo, MulticoreCPU
#       2 from ForwardFinancialFramework.Platforms.OpenCLGPU import OpenCLGPU_MonteCarlo,OpenCLGPU
#       3 from ForwardFinancialFramework.Platforms.OpenCLAlteraFPGA import OpenCLAlteraFPGA_MonteCarlo,OpenCLAlteraFPGA
#       4 from ForwardFinancialFramework.Platforms.MaxelerFPGA import MaxelerFPGA_MonteCarlo,MaxelerFPGA
#
# ImportError: No module named ForwardFinancialFramework.Platforms.MulticoreCPU

# %% [markdown]
# #### Local Platform

# %%
platforms = [MulticoreCPU.MulticoreCPU(threads=7)]

# %% [markdown]
# #### Remote CPUs

# %%
platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="ee-benjamin"),MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="pi"),MulticoreCPU.MulticoreCPU(threads=7,remote=True,ssh_alias="ee-mollie")]

# %% [markdown]
# #### Remote GPUs

# %%
platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball0"),OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball1")]

# %% [markdown]
# #### Remote FPGAs

# %%
platforms += [MaxelerFPGA.MaxelerFPGA(remote=True,ssh_alias="ee-mollie")]

# %%
platforms += [OpenCLAlteraFPGA.OpenCLAlteraFPGA(remote=True,ssh_alias="ee-snowball2")]

# %% [markdown]
# ## Verifying the Models

# %% [markdown]
# Model Verification Procedure:
#     1. Run each task for up to (5 minutes)/128 on each platform
#     2. Generate Latency, Accuracy and Latency-Accuracy models for each task.
#     3. Combine the task models for each platform and make a prediction curve for the region of interest [5x2,5x4,5x8,5x16]
#     4. Run verification experiments so as to find that region of interest

# %% [markdown]
# ### 1. Benchmark Each Task

# %%
import multiprocessing
import numpy

# %% [markdown]
# #### Constants

# %% [markdown]
# * The benchmarking time should be 5 minutes (300 seconds). This should be shared equally between all of the tasks.
# * Each task starts with 100 paths

# %%
benchmarking_time = 300.0
paths_start_value = 100
benchmarking_time_per_task = benchmarking_time/len(option_tasks)

# %% [markdown]
# #### Function used for running the benchmark on a specific platform

# %%
def platform_benchmark(platform,option_tasks,timelimit,queue,output_queue,):
    import subprocess32 as subprocess
    
    for i,o in enumerate(option_tasks):
        paths = paths_start_value
        total_time = 0.0
        results = []
        retries = 3
        while(total_time < timelimit and 0<retries):
            if(isinstance(platform,MulticoreCPU.MulticoreCPU)): mc_solver = MulticoreCPU_MonteCarlo.MulticoreCPU_MonteCarlo([o],paths,platform)
            elif(isinstance(platform,OpenCLGPU.OpenCLGPU)): mc_solver = OpenCLGPU_MonteCarlo.OpenCLGPU_MonteCarlo([o],paths,platform)
            elif(isinstance(platform,OpenCLAlteraFPGA.OpenCLAlteraFPGA)): mc_solver = OpenCLAlteraFPGA_MonteCarlo.OpenCLAlteraFPGA_MonteCarlo([o],paths,platform)
            elif(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                if("heston" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=8)
                elif("black_scholes" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=16)
            
            try:
                if(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                    mc_solver.dummy_run()
                    mc_solver.execute()
                result = mc_solver.execute()
                retries = 3
                
                results.append((paths,result[-1]/10e6,float(result[1])))
        
                total_time += result[-1]/10e6
                
                
                paths *= 2
            except subprocess.CalledProcessError as e:
                output_queue.put_nowait("Error!\nCommand:" + str(e.cmd) + "\nReturn: " + str(e.output) + "\nReturncode: " + str(e.returncode) + "\nretries remaining: " + str(retries))
                retries -= 1
        
        if(results): 
            output_queue.put_nowait(str(i) + " on " + platform.ssh_alias + "("+platform.name+")" + ": " + str(results) + "\n")
            queue.put_nowait((platform.ssh_alias,platform.name,i,results))

# %% [markdown]
# #### Code that launches benchmarking on separate threads

# %%
queue = multiprocessing.Queue(len(platforms)*len(option_tasks)*2)
output_queue = multiprocessing.Queue()

# %%
results = []
try:
    pool = [multiprocessing.Process(target=platform_benchmark,args=(p,option_tasks,benchmarking_time_per_task,queue,output_queue,)) for p in platforms]
    
    for p in pool: p.start()
        
    while(True):
        while not(output_queue.empty()): print(output_queue.get())
        while not(queue.empty()): results += [queue.get()]
        
        flag = True
        for p in pool: 
            if(p.is_alive() and flag): flag = False
        if(flag): break
            
    for p in pool: 
        p.join()
        del p
except:
    for p in pool: 
        p.terminate()
        del p

#for p in platforms: platform_benchmark(p,option_tasks,benchmarking_time_per_task,queue,output_queue,)
# Out:
# 0 on ee-snowball1(opencl_gpu): [(100, 0.13846120834350586, 0.0), (200, 0.14816610813140868, 0.014432), (400, 0.14811580181121825, 0.274387), (800, 0.14003391265869142, 0.214908), (1600, 0.11672899723052979, 0.057237), (3200, 0.1400211811065674, 0.055309), (6400, 0.13990650177001954, 0.044362), (12800, 0.14994428157806397, 0.033779), (25600, 0.1439656972885132, 0.022953), (51200, 0.13783729076385498, 0.015669), (102400, 0.16324129104614257, 0.011484), (204800, 0.14672019481658935, 0.008139), (409600, 0.16636979579925537, 0.005757), (819200, 0.21395251750946045, 0.004022), (1638400, 0.2843040943145752, 0.002904)]
#
# 0 on ee-snowball0(opencl_gpu): [(100, 0.09603180885314941, 0.231374), (200, 0.06535768508911133, 0.135228), (400, 0.07902870178222657, 0.201312), (800, 0.09527039527893066, 0.155248), (1600, 0.06335840225219727, 0.078285), (3200, 0.10930020809173584, 0.068373), (6400, 0.06290228366851806, 0.050083), (12800, 0.08137998580932618, 0.031868), (25600, 0.1075775146484375, 0.022595), (51200, 0.06516978740692139, 0.016264), (102400, 0.13459908962249756, 0.011354), (204800, 0.08363118171691894, 0.008106), (409600, 0.11277000904083252, 0.005732), (819200, 0.1539283037185669, 0.004059), (1638400, 0.21423239707946778, 0.002867), (3276800, 0.31320528984069823, 0.002038), (6553600, 0.5498271942138672, 0.001442)]
# 0 on ee-mollie(multicore_cpu): [(100, 0.33799760341644286, 0.703416), (200, 0.04926719665527344, 0.212956), (400, 0.02809748649597168, 0.159098), (800, 0.04108011722564697, 0.125218), (1600, 0.03633739948272705, 0.091575), (3200, 0.06876549720764161, 0.065939), (6400, 0.12651259899139405, 0.044576), (12800, 0.18977510929107666, 0.033797), (25600, 0.2119455099105835, 0.023392), (51200, 0.3197967052459717, 0.016145), (102400, 0.7009115934371948, 0.0115), (204800, 1.2756890058517456, 0.008195)]
# 0 on pi(multicore_cpu): [(100, 0.1560822010040283, 0.48755), (200, 0.21092019081115723, 0.240173), (400, 0.2956883907318115, 0.156258), (800, 0.4636414051055908, 0.115865), (1600, 0.8051831960678101, 0.097467), (3200, 1.4804971933364868, 0.062644)]
# 1 on (multicore_cpu): [(100, 0.0012920856475830077, 0.191616), (200, 0.002285408973693848, 0.108398), (400, 0.0033510923385620117, 0.158655), (800, 0.004783821105957031, 0.112069), (1600, 0.008398485183715821, 0.073443), (3200, 0.014200711250305175, 0.04548), (6400, 0.02931971549987793, 0.034495), (12800, 0.05560820102691651, 0.024915), (25600, 0.11212739944458008, 0.016931), (51200, 0.24444050788879396, 0.011974), (102400, 0.4269507884979248, 0.008748), (204800, 0.8190799951553345, 0.006189), (409600, 1.631513786315918, 0.004412)]
# 1 on pi(multicore_cpu): [(100, 0.16562530994415284, 0.111555), (200, 0.213224196434021, 0.1451), (400, 0.2998818874359131, 0.136403), (800, 0.46811158657073976, 0.090049), (1600, 0.8202746868133545, 0.071127), (3200, 1.4755213975906372, 0.048768)]
# 1 on ee-benjamin(multicore_cpu): [(100, 0.0626410961151123, 0.148249), (200, 0.05816748142242432, 0.159739), (400, 0.08216760158538819, 0.151115), (800, 0.05467510223388672, 0.116772), (1600, 0.07875599861145019, 0.067718), (3200, 0.08082520961761475, 0.053157), (6400, 0.08317909240722657, 0.0334), (12800, 0.08391439914703369, 0.024764), (25600, 0.11364190578460694, 0.018144), (51200, 0.09368419647216797, 0.012397), (102400, 0.1639880895614624, 0.008723), (204800, 0.215812087059021, 0.006268), (409600, 0.39274120330810547, 0.00439), (819200, 0.7344090223312378, 0.003129), (1638400, 1.3194208145141602, 0.002193)]
# 2 on ee-snowball1(opencl_gpu): [(100, 0.13158190250396729, 0.736092), (200, 0.13353989124298096, 0.227235), (400, 0.14997611045837403, 0.219701), (800, 0.13208382129669188, 0.131252), (1600, 0.13958148956298827, 0.108432), (3200, 0.158132004737854, 0.070699), (6400, 0.15509979724884032, 0.050064), (12800, 0.15035488605499267, 0.040876), (25600, 0.11633670330047607, 0.025903), (51200, 0.1531095027923584, 0.018263), (102400, 0.14681470394134521, 0.012408), (204800, 0.14315378665924072, 0.009116), (409600, 0.14498441219329833, 0.006292), (819200, 0.18718039989471436, 0.004578), (1638400, 0.2893200159072876, 0.003171), (3276800, 0.4726205825805664, 0.002294)]
# 2 on ee-snowball0(opencl_gpu): [(100, 0.11092710494995117, 0.255), (200, 0.0978896141052246, 0.218525), (400, 0.0719900131225586, 0.25819), (800, 0.10310590267181396, 0.119381), (1600, 0.07587358951568604, 0.091761), (3200, 0.12312369346618653, 0.077386), (6400, 0.11519138813018799, 0.050663), (12800, 0.09911749362945557, 0.035307), (25600, 0.06481919288635254, 0.025831), (51200, 0.08391349315643311, 0.018068), (102400, 0.10518779754638671, 0.012734), (204800, 0.10142710208892822, 0.009166), (409600, 0.13128230571746827, 0.006414), (819200, 0.14566271305084227, 0.004566), (1638400, 0.1793286085128784, 0.00321), (3276800, 0.28486340045928954, 0.002286), (6553600, 0.5393765926361084, 0.00161)]

# %% [markdown]
# #### Collating results

# %% [markdown]
# Results are an array of (paths,latency,accuracy) for each platform and task,
#
# i.e. benchmark_results[i][j] would be the results array for the jth task on the ith platform

# %%
#platforms, tasks, results (paths, time, accuracy)
benchmark_results = [[[] for t in range(len(option_tasks))] for p in range(len(platforms))]
platform_names = [p.name+"_"+p.ssh_alias for p in platforms]

for result in results:
    benchmark_results[platform_names.index(result[1]+"_"+results[0])][result[2]] = result[3]

for p in range(len(platforms)):
    for t in range(len(option_tasks)):
        benchmark_results[p][t] = numpy.array(benchmark_results[p][t],dtype=[('paths','f8'),('latency','f8'),('accuracy','f8')]) #
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15
# []
# Task 125:
# []
# Task 126:
# []
# Task 127:
# []

# %%
platform_data = []
flag = True
for i,p in enumerate(platforms):
    #print "Platform "+p.ssh_alias+":"
    flag = True
    for j,t in enumerate(option_tasks):
        #print "Task "+str(j)+":"
        if not(benchmark_results[i][j].size):
            print(p.ssh_alias,j)
            platform_data.append(j)
            flag = False
            break
            
    if(flag): 
        print(p.ssh_alias,len(option_tasks))
        platform_data.append(len(option_tasks))
            
print platform_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ac9d8cc64cc2> in <module>()
#       6     for j,t in enumerate(option_tasks):
#       7         #print "Task "+str(j)+":"
# ----> 8         if not(benchmark_results[i][j].size):
#       9             print(p.ssh_alias,j)
#      10             platform_data.append(j)
#
# AttributeError: 'list' object has no attribute 'size'

# %%
with open('benchmark_data_complete.csv','w') as benchmark_file:
    csvwriter = csv.writer(benchmark_file,delimiter=',')
    
    csvwriter.writerow(['Platform','Type','Task','Paths','Latency','Accuracy'])
    for i,p in enumerate(platforms):
        for j,t in enumerate(option_tasks):
            for r in benchmark_results[i][j]:
                    csvwriter.writerow([p.ssh_alias,p.name,j]+list(r))

# %% [markdown]
# ## 2. Generate Models

# %% [markdown]
# ### Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import csv

# %%
with open('benchmark_data_complete_3000.csv','r') as benchmark_file:
    csvreader = csv.reader(benchmark_file,delimiter=',')
    
    headings = csvreader.next()
    heading_tuples = [(h,"a30") for h in headings]
    
    data = []
    for row in csvreader: data.append(tuple(row))
            
    data = numpy.array(data,dtype=heading_tuples)

# %% [markdown]
# ### Latency Model

# %% [markdown]
# Two sets of data need to be selected:
# * All of the paths and latency data for a particular task
# * All of the paths and latency data under the benchmarking time limit (300S/128) which will be used to create the model

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))

# %%
def generate_latency_model(paths,latency):
    latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
    latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
    
    return lambda N: latency_model_coefficients[0]*N+latency_model_coefficients[1]

# %%
relative_latency_errors = []
absolute_latency_errors = []
verification_paths = []
for platform,platform_type in platforms:
    print(platform,platform_type)
    relative_latency_errors += [[]]
    absolute_latency_errors += [[]]
    verification_paths += [[]]
    for t in range(len(option_tasks[:])):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"]==str(t)
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #limiting to the benchmarking time
        
        paths = data[selection]["Paths"].astype(numpy.float)
        latency = data[selection]["Latency"].astype(numpy.float)
        latency_model = generate_latency_model(paths,latency)

        verification_path = data[verification_selection]["Paths"].astype(numpy.float)
        verification_latency = data[verification_selection]["Latency"].astype(numpy.float)
        verification_paths[-1] += [verification_path]
        
        error = (numpy.array(verification_latency-numpy.array([latency_model(p) for p in verification_path])))
        if not(numpy.any(numpy.isnan(error))or numpy.any(numpy.isinf(error))):
            absolute_latency_errors[-1] += [error]
            relative_latency_errors[-1] += [error/verification_latency]
        
    #massage down to same size
    max_length = min([len(errors) for errors in relative_latency_errors[-1]])
    
    temp_errors = relative_latency_errors[-1][:]
    relative_latency_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    temp_paths = verification_paths[-1][:]
    verification_paths[-1] = numpy.array([tp[:max_length] for tp in temp_paths])
    
    temp_errors = absolute_latency_errors[-1][:]
    absolute_latency_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    print(verification_paths[-1].shape,relative_latency_errors[-1].shape,absolute_latency_errors[-1].shape)
# Out:
# ('', 'multicore_cpu')
# ((128, 15), (128, 15), (128, 15))
# ('ee-snowball1', 'opencl_gpu')
# ((128, 21), (128, 21), (128, 21))
# ('ee-snowball0', 'opencl_gpu')
# ((128, 21), (128, 21), (128, 21))
# ('ee-benjamin', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('pi', 'multicore_cpu')
# ((128, 8), (128, 8), (128, 8))
# ('ee-mollie', 'multicore_cpu')
# ((128, 14), (128, 14), (128, 14))
# ('ee-mollie', 'maxeler_fpga')
# ((128, 20), (128, 20), (128, 20))

# %%
i = 0
for platform,platform_type in platforms:
    plt.plot(verification_paths[i][0],numpy.mean(relative_latency_errors[i],axis=0),label=platform+"("+ platform_type+")") #paths should all be the same
    i += 1
    
#plt.axvspan(accuracy[-1], accuracy[-1], facecolor='g', alpha=1)
ax = plt.gca()
ax.set_xlabel("Simulations")
ax.set_xscale('log')
ax.set_ylabel("Latency Error (%)")
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.legend(loc="best")

# %%
platform = "ee-snowball1"
platform_type = "opencl_gpu"
task = "0"

verification_selection = numpy.logical_and(numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type),data["Task"]==task)
verification_paths = data[verification_selection]["Paths"].astype(numpy.float)
verification_latency = data[verification_selection]["Latency"].astype(numpy.float)

selection = numpy.logical_and(numpy.logical_and(numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type),data["Task"]==task),data["Latency"].astype(numpy.float) < 300.0/128)
paths = data[selection]["Paths"].astype(numpy.float)
latency = data[selection]["Latency"].astype(numpy.float)

# %%
latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
latency_model = lambda N: latency_model_coefficients[0]*N + latency_model_coefficients[1]

# %%
plt.plot(verification_latency,100*abs(numpy.array(map(latency_model,verification_paths))-verification_latency)/verification_latency,"r-x")
plt.axvspan(latency[-1], latency[-1], facecolor='g', alpha=1)

ax = plt.gca()
ax.set_xlabel("Latency (S)")
ax.set_xscale('log')
ax.set_ylabel("Relative Latency Error (%)")
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %% [markdown]
# ### Accuracy Model

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))

#platforms = [("","multicore_cpu")]

# %% [markdown]
# Function for generating accuracy model

# %%
def generate_accuracy_model(paths,accuracy):
    accuracy_model_data = numpy.column_stack((paths**-0.5,numpy.zeros(len(paths))))
    accuracy_model_coefficients = numpy.linalg.lstsq(accuracy_model_data,accuracy)[0]
    
    return lambda N: accuracy_model_coefficients[0]*N**-0.5

# %% [markdown]
# Calculating the relative and absolute accuracy models. The absolute models look a lot better. This makes sense, as the accuracy (95% CI) is shrinking, so the absolute error should also be shrinking. The relative error performance will be limited by any inherent bias in the model.
#
# Should probably add an indication of the benchmarking for each platform.

# %%
relative_accuracy_errors = []
absolute_accuracy_errors = []
verification_paths = []
for platform,platform_type in platforms:
    print(platform,platform_type)
    absolute_accuracy_errors += [[]]
    relative_accuracy_errors += [[]]
    verification_paths += [[]]
    for t in range(len(option_tasks[:])):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"]==str(t)
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #limiting to the benchmarking time
        
        paths = data[selection]["Paths"].astype(numpy.float)
        accuracy = data[selection]["Accuracy"].astype(numpy.float)
        accuracy_model = generate_accuracy_model(paths,accuracy)

        verification_path = data[verification_selection]["Paths"].astype(numpy.float)
        verification_accuracy = data[verification_selection]["Accuracy"].astype(numpy.float)
        verification_paths[-1] += [verification_path]
        
        error = (numpy.array(verification_accuracy-numpy.array([accuracy_model(p) for p in verification_path])))
        if not(numpy.any(numpy.isnan(error))or numpy.any(numpy.isinf(error))):
            absolute_accuracy_errors[-1] += [error]
            relative_accuracy_errors[-1] += [error/verification_accuracy]
        
    #massage down to same size
    max_length = min([len(errors) for errors in relative_accuracy_errors[-1]])
    
    temp_errors = relative_accuracy_errors[-1][:]
    relative_accuracy_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    temp_paths = verification_paths[-1][:]
    verification_paths[-1] = numpy.array([tp[:max_length] for tp in temp_paths])
    
    temp_errors = absolute_accuracy_errors[-1][:]
    absolute_accuracy_errors[-1] = numpy.array([te[:max_length] for te in temp_errors])
    
    print(verification_paths[-1].shape,relative_accuracy_errors[-1].shape,absolute_accuracy_errors[-1].shape)
# Out:
# ('', 'multicore_cpu')
# ((128, 15), (128, 15), (128, 15))
# ('ee-snowball1', 'opencl_gpu')
# ((128, 21), (128, 21), (128, 21))
# ('ee-snowball0', 'opencl_gpu')
# ((128, 21), (128, 21), (128, 21))
# ('ee-benjamin', 'multicore_cpu')
# ((128, 17), (128, 17), (128, 17))
# ('pi', 'multicore_cpu')
# ((128, 8), (128, 8), (128, 8))
# ('ee-mollie', 'multicore_cpu')
# ((128, 14), (128, 14), (128, 14))
# ('ee-mollie', 'maxeler_fpga')
# ((128, 20), (127, 20), (127, 20))

# %%
i = 0
for platform,platform_type in platforms:
    plt.plot(verification_paths[i][0],numpy.mean(numpy.abs(absolute_accuracy_errors[i]),axis=0),label=platform+"("+ platform_type+")") #paths should all be the same
    i += 1
    
#plt.axvspan(accuracy[-1], accuracy[-1], facecolor='g', alpha=1)
ax = plt.gca()
ax.set_xlabel("Simulations")
ax.set_xscale('log')
ax.set_ylabel("Accuracy Error ($)")
ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.legend(loc="best")
# Out:
# [-0.12393533  0.09196117  0.0511298   0.04766529  0.04012395  0.01242536
#   0.01718377  0.01117145  0.00959081  0.00642833  0.0049712   0.00391832
#   0.00255741  0.00168986  0.00126727]
# [-0.12936101 -0.02365776  0.13393558  0.08824021  0.09726132  0.06269787
#   0.04987865  0.03596245  0.02233616  0.02033234  0.01272516  0.00960345
#   0.00667333  0.00486393  0.00338804  0.00231869  0.00173429  0.00119226
#   0.0009289   0.00056384  0.00041296]
# [ 0.06525021 -0.08220636 -0.02439582 -0.00495472 -0.00218842  0.02689879
#   0.0086255   0.00978258  0.00559235  0.00376343  0.00207087  0.00214482
#   0.00158246  0.00113078  0.00077335  0.00060773  0.00049906  0.00028349
#   0.0002058   0.00015008  0.00010071]
# [-0.3772928   0.19533073  0.27803133  0.12443093  0.10505426  0.08673402
#   0.05934911  0.03950928  0.02914023  0.02163388  0.01494689  0.01083024
#   0.00735363  0.00521519  0.00378471  0.00271352  0.00189367]
# [ 0.38969481 -0.33351099 -0.23389051 -0.10119482 -0.00468147 -0.04588661
#  -0.02877292 -0.01915553]
# [  1.25730765e-01  -1.34644566e-01  -3.42828872e-02  -2.75947363e-02
#   -1.56839670e-02  -4.04930648e-04   2.67087976e-03  -5.33289543e-04
#   -4.95603090e-04   2.91716348e-05   3.51088595e-03   2.23006612e-05
#    2.13025009e-04   1.99790956e-04]
# [-0.51144363  0.37671582  0.19697983  0.14982263  0.12723833  0.20591262
#   0.09126268  0.08372744  0.05075839  0.03784331  0.0265168   0.01955192
#   0.01675042  0.01052668  0.0077327   0.00509204  0.00360712  0.00251663
#   0.00180048  0.00127265]

# %%
plt.plot(verification_accuracy,100*numpy.abs(numpy.array(map(accuracy_model,verification_paths))-verification_accuracy)/verification_accuracy,"r-x")
plt.axvspan(accuracy[-1], accuracy[-1], facecolor='g', alpha=1)

ax = plt.gca()
ax.set_xlabel("Accuracy ($)")
ax.set_xscale('log')
ax.set_ylabel("Accuracy Error (%)")
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %% [markdown]
# ## 3. Combine Models and 4. Verify Combined Curves

# %% [markdown]
# ### Accuracy-Latency Model

# %%
accuracy_range = []
for i in range(-1,3):
    accuracy_range += list(numpy.arange(10**-i,10**-(i+1),-10**-(i+1)))
accuracy_range = numpy.array(accuracy_range)

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))

#platforms = [("ee-snowball1","opencl_gpu")]

# %% [markdown]
# Function for generating a Latency as a function of accuracy model. It could actually be done without the paths variable, which is just used to link the latency and accuracy.
#
# What's quite important is that any model that is returning a nonsensical value, either implicity as a 0 coefficient or a nan is discounted. This isn't very Pythonic, but makes sense in the context of best-effort interfaces.

# %%
def latency_accuracy_model_generate(paths,latency,accuracy):
    latency_model_data = numpy.column_stack((paths,numpy.ones(len(paths))))
    latency_model_coefficients = numpy.linalg.lstsq(latency_model_data,latency)[0]
    #latency_model = lambda N: latency_model_coefficients[0]*N + latency_model_coefficients[1]

    accuracy_model_data = numpy.column_stack((paths**-0.5,numpy.zeros(len(paths))))
    accuracy_model_coefficients = numpy.linalg.lstsq(accuracy_model_data,accuracy)[0]
    #accuracy_model = lambda N: accuracy_model_coefficients[0]*N**-0.5 + accuracy_model_coefficients[1]
            
    if(accuracy_model_coefficients[0]<=0 or numpy.isnan(accuracy_model_coefficients[0])): return lambda A: 0.0
    else: return lambda A: latency_model_coefficients[0]*(accuracy_model_coefficients[0]/A)**2 + latency_model_coefficients[1]

# %% [markdown]
# The big issue with the plot below is in comparing model curves and the verification points. Each point should be the time taken to achieve that accuracy for all of the tasks. For the predictive models this is easy to do:
# 1. The latency accuracy model is generated from the benchmark data, i.e. all data for which the time 300.0/number of tasks
# 2. The curve is plotted according to the domain of interest
# These are the dashed curves in the plot.
#
# However, this isn't as straight-forward for the verification data. The verification runs aren't that fine-grained due to the multiplicative stepping. So I've done two things:
# 1. Simply plot the latency-accuracy model using all of the available data as opposed to just the benchmark data. This is the solid line plot.
# 2. Find the accuracies achieved that are below each accuracy point of interest (as defined in the accuracy range), and add the minimum of these latencies to the total for that point of interest. Only those accuracy points which have some high fraction of all tasks are plotted (currently 0.9). This is the scatter plot points.
#
# I should probably do more fine-grained verification runs.

# %%
for platform,platform_type in platforms:
    latency_accuracy_models = []
    verification_latency_accuracy_models = []
    
    verification_latencies = numpy.zeros(accuracy_range.shape)
    verification_sets = [set() for i in verification_latencies]
    for task,dummy in enumerate(option_tasks[:]):
        selection = data["Platform"]==platform
        selection &= data["Type"]==platform_type
        selection &= data["Task"].astype(numpy.int)==task 
        verification_selection = numpy.copy(selection)
        selection &= data["Latency"].astype(numpy.float) < 300.0/128 #constrain the benchmarking
        if(numpy.any(selection)):
            paths = data[selection]["Paths"].astype(numpy.float)
            accuracy = data[selection]["Accuracy"].astype(numpy.float)
            latency = data[selection]["Latency"].astype(numpy.float)
            
            latency_accuracy_models += [latency_accuracy_model_generate(paths,latency,accuracy)]
            
            verification_paths = data[verification_selection]["Paths"].astype(numpy.float)
            verification_accuracy = data[verification_selection]["Accuracy"].astype(numpy.float)
            verification_latency = data[verification_selection]["Latency"].astype(numpy.float)
            
            verification_latency_accuracy_models += [latency_accuracy_model_generate(verification_paths,verification_latency,verification_accuracy)]
            
            #plt.scatter(verification_latency,verification_accuracy,marker="x") #plots all of the task points
            #finding the closest accuracy in the range of interest and accumulating the accuracy
            
            for i,acc in enumerate(accuracy_range):
                accuracy_selection = (verification_accuracy-acc)<=0 #selecting those entries at the required accuracy or lower
                if(numpy.any(accuracy_selection)): 
                    verification_latencies[i] += min(verification_latency[accuracy_selection])
                    verification_sets[i] |= {task}
                
            #for acc,lat in zip(verification_accuracy,verification_latency):
                #index = numpy.argmin([(acc-accuracy_range)<0])
                #verification_latencies[index] += lat
                #
            
    #Building the model of models
    latency_accuracy_model = lambda A: numpy.sum([lam(A) for lam in latency_accuracy_models])
    verification_latency_accuracy_model = lambda A: numpy.sum([lam(A) for lam in verification_latency_accuracy_models])
    
    colour = tuple(numpy.random.random(3))
    plot = plt.plot([latency_accuracy_model(a) for a in accuracy_range],accuracy_range,"--",label=platform+"("+ platform_type+")",color=colour)
    plt.axvspan(300, 300, facecolor=colour, alpha=0.5)
    plt.axvspan(3000, 3000, facecolor=colour, alpha=0.5)
    
    plot_latencies = []
    plot_accuracies = []
    for lat,acc,vset in zip(verification_latencies,accuracy_range,verification_sets):
        #if( 30 < latency_accuracy_model(acc)< 300 ):
        if(len(vset)>=0.9*len(option_tasks)):
            plot_latencies += [lat]
            plot_accuracies += [acc]
    
    plot = plt.plot([verification_latency_accuracy_model(a) for a in accuracy_range],accuracy_range,"-",color=colour)
    #plt.scatter(plot_latencies,plot_accuracies,color=colour)
            
axis = plt.gca()
axis.set_xscale('log')
axis.set_xlabel("Latency (S)")
axis.set_yscale('log')
axis.set_ylabel("Accuracy ($)")
plt.legend(loc='best')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %%
selection = data["Task"].astype(numpy.int)>=0
#selection &= data["Task"].astype(numpy.int)>5
plt.hist(data[selection]["Latency"].astype(numpy.float),bins=10)
plt.axhspan(128, 128, facecolor=colour, alpha=0.5)

ax = plt.gca()
ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)
