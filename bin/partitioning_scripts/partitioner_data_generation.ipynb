# %% [markdown]
# # Partitioner Data Generation

# %% [markdown]
# Aim:
# * Use the predictive models to produce latency projections for a reasonable accuracy region (\$10,\$1,\$0.1,\$0.01)
# * Use these latency projections to generate three partitions:
#  * Simple inverse arithmetic (proportional)
#  * Machine learning-based (simulated annealling with Nelder-Mead polishing)
#  * SCIP-based
# * Run these partitions on the set of platforms

# %% [markdown]
# ## Setup

# %% [markdown]
# Importing necessary libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import scipy
import scipy.optimize
import csv,time,copy

# %% [markdown]
# ## Method

# %% [markdown]
# Model Verification Procedure:
# 1. Create $$Path(Accuracy)$$ and $$Latency(Accuracy)$$ models for each task upon each platform
# 2. Generate Task Partitions for the accuracy range of interest for all tasks using all of the platforms

# %% [markdown]
# ## Generating Models

# %% [markdown]
# ### Reading in Model Coefficients

# %% [markdown]
# Reading model coefficient data

# %%
with open('model_coefficients_complete2.csv','r') as benchmark_file:
    csvreader = csv.reader(benchmark_file,delimiter=',')
    
    headings = csvreader.next()
    heading_tuples = [(h,"a30") for h in headings if h in ["Platform","Type"]]
    heading_tuples += [(h,"f8") for h in headings if h not in ["Platform","Type"]]
    
    data = []
    for row in csvreader: data.append(tuple(row))
            
    data = numpy.array(data,dtype=heading_tuples)

# %% [markdown]
# Generating the list of platforms

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))
            
platforms = [(platform,platform_type) for platform,platform_type in platforms] #if not(platform=="phi" and platform_type=="opencl_gpu")

for platform in platforms: print(platform)
# Out:
# ('', 'multicore_cpu')
# ('ee-snowball2', 'opencl_alterafpga')
# ('phi', 'multicore_cpu')
# ('phi', 'opencl_gpu')
# ('ee-snowball0', 'opencl_gpu')
# ('amazon-gpu-0', 'multicore_cpu')
# ('amazon-gpu-0', 'opencl_gpu')
# ('amazon-gpu-1', 'multicore_cpu')
# ('amazon-gpu-1', 'opencl_gpu')
# ('amazon-cpu-0', 'multicore_cpu')
# ('amazon-cpu-1', 'multicore_cpu')
# ('ee-snowball1', 'opencl_gpu')
# ('ee-benjamin', 'multicore_cpu')
# ('pi', 'multicore_cpu')
# ('ee-mollie', 'multicore_cpu')
# ('ee-mollie', 'maxeler_fpga')

# %% [markdown]
# list of task identifiers:

# %%
tasks = sorted(list(set(data["Task"])))

# %% [markdown]
# ### Model Functions

# %% [markdown]
# #### Paths(Accuracy) Model

# %%
def paths_accuracy(A,accuracy_coefficient):
    return (accuracy_coefficient/A)**2

# %% [markdown]
# #### Latency(Accuracy) Model

# %%
def latency_accuracy(accuracy_coefficient,latency_coefficient,latency_setup):
    return lambda A,latency_coefficient=latency_coefficient,accuracy_coefficient=accuracy_coefficient: latency_coefficient*paths_accuracy(A,accuracy_coefficient) + latency_setup

# %% [markdown]
# #### Latency(Accuracy) Coefficient Model

# %%
def latency_accuracy_coefficient(accuracy_coefficient,latency_coefficient):
    return lambda A,latency_coefficient=latency_coefficient,accuracy_coefficient=accuracy_coefficient: latency_coefficient*paths_accuracy(A,accuracy_coefficient)

# %% [markdown]
# ## Generating Partitions

# %% [markdown]
# ### Setup

# %% [markdown]
# Accuracy range of interest, with logarithmic stepping:

# %%
"""
accuracy_range = range(10,1,-1) #1
accuracy_range += list(numpy.arange(1,0.1,-0.1)) #0.1
accuracy_range += list(numpy.arange(0.1,0.01,-0.01)) #0.01
accuracy_range += list(numpy.arange(0.01,0.001,-0.001)) #0.001
accuracy_range += [0.001]
"""
accuracy_range = [10,1,0.1,0.01,0.001]

accuracy_range = numpy.array(accuracy_range)
print(accuracy_range)
# Out:
# [  1.00000000e+01   1.00000000e+00   1.00000000e-01   1.00000000e-02
#    1.00000000e-03]

# %% [markdown]
# Function for selection the coefficients for a particular platform-task combination from the coefficient data array:

# %%
def select_coefficients(data,platform,platform_type,task):
    selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
    selection = numpy.logical_and(selection[:],data["Task"]==task)
    accuracy_coefficient,latency_coefficient,latency_setup = data[selection]["Accuracy Coefficient"],data[selection]["Latency Coefficient"],data[selection]["Latency Setup"]
    
    return accuracy_coefficient,latency_coefficient,latency_setup

# %% [markdown]
# Generating the cost models that are used by all of the partitioners:

# %%
cost_models = []
for platform,platform_type in platforms:
    cost_models += [[]]
    for task in tasks[:]:
        accuracy_coefficient,latency_coefficient,latency_setup = select_coefficients(data,platform,platform_type,task)
        coefficient_model = latency_accuracy_coefficient(accuracy_coefficient,latency_coefficient)
        setup_model = lambda A,latency_setup=latency_setup: latency_setup
        cost_models[-1] += [(coefficient_model,setup_model)]

# %% [markdown]
# Using the cost models to generate both the per-path latency matrices as well as the setup latency matrices for the accuracy range of interest

# %%
cost_matrices = []
for accuracy_target in accuracy_range[:]:
    pp_latencies = []
    setup_latencies = []
    for platform_models in cost_models:
        pp_latencies += [[]]
        setup_latencies += [[]]
        for task_pp_model,task_setup_model in platform_models:
            pp_latencies[-1] += [task_pp_model(accuracy_target)]
            setup_latencies[-1] += [task_setup_model(accuracy_target)]
     
    pp_latencies = numpy.copy(numpy.array(pp_latencies).reshape(len(platforms),len(tasks[:])))
    setup_latencies = numpy.copy(numpy.array(setup_latencies).reshape(len(platforms),len(tasks[:])))
    
    cost_matrices += [(setup_latencies,pp_latencies)]

# %% [markdown]
# Function for calculating the value of an allocation, given its cost matrices:

# %%
def allocation_cost(allocation,pp_costs,setup_costs):
    #platforms = setup_costs.shape[0]
    #tasks = setup_costs.shape[1]
    
    #platform_allocation_totals = []
    #for p in range(platforms):
    platform_allocation_totals = pp_costs*allocation+setup_costs
    selection = numpy.logical_not(numpy.isinf(platform_allocation_totals))#avoiding those tasks which don't have sensible coefficents
    
    cost = numpy.max(numpy.sum(platform_allocation_totals[selection],axis=1)) #find the longest running platform
    #if(numpy.isinf(cost)): cost = numpy.finfo(numpy.float64).max

    return cost

# %% [markdown]
# Function for plotting partitions for a ranage of accuracies.

# %%
def platform_task_allocations(allocations,accuracy_range,platforms,tasks,step_size=1):
    plot_number = len(allocations)
    step_size = 1
    fig, axes = plt.subplots(plot_number,sharex=True,sharey=True)
    imgs = []

    print(platforms)
    for i,ax in enumerate(axes):
        index = step_size*i
        ax.set_title("$%.4f"%accuracy_range[index])
        imgs += [ax.imshow(numpy.array(allocations[index]),interpolation='nearest',cmap='hot',vmin=0,vmax=1)]
        print("$%.4f: "%accuracy_range[index],numpy.sum(allocations[index]))
        
        print(numpy.mean(allocations[index],axis=1))
        #print("$%.4f: "%accuracy_range[index],allocations[index].T)

    #tasks = allocations[0].shape[1]
    
    axes[-1].set_xticks(range(len(tasks)))
    axes[-1].set_xticklabels([])
    axes[-1].set_yticks(range(len(platforms)))
    axes[-1].set_yticklabels([(platform,platform_types) for platform,platform_types in platforms]) #,rotation=90

    cax,kw = matplotlib.colorbar.make_axes([ax for ax in axes.flat])
    fig.colorbar(imgs[-1], cax=cax, **kw)

    fig.set_size_inches(30,20)

# %% [markdown]
# ### Proportional Partitioner

# %% [markdown]
# In generating the proportional partition, the relative platform latencies (i.e. the sum of all of the tasks upon that platform) are used used to partition the workload. This is given by $$ \vec{A} = \frac{\frac{1}{\hat{L}_p}}{\sum\nolimits_{k \in \mu}{\frac{1}{\hat{L}_k}}}$$, where $$\vec{L}_p = \sum\nolimits_{t \in \tau}{\bf{ETC_{pp,p,t}}+\bf{ETC_{setup,p,t}}} \:\: p \in \mu$$
#
# An important caveat is that the sum of only those tasks of which exist across all platforms are used to do this relative ranking.
#
# From a technical point of view, the proportional partitioning function only requires the sum of the setup and pp latency matrices, but I've kept the interface consistent for the later solvers which require the separate matrices.

# %%
def proportional_partition(setup_costs,pp_costs):
    #selecting the tasks that will be used to build the proportional schedule
    temp_latencies = numpy.sum(setup_costs + pp_costs,axis=0) #finding the task totals across all platforms
    selection = numpy.logical_not(numpy.isinf(temp_latencies)) #only selecting those tasks which have values across all platforms

    latencies = numpy.sum(setup_costs[:,selection] + pp_costs[:,selection],axis=1)
    allocation = numpy.linalg.norm(latencies)/latencies/numpy.sum(numpy.linalg.norm(latencies)/latencies) #numpy.sum(latencies)/latencies/numpy.sum(numpy.sum(latencies)/latencies)
    
    return allocation

# %%
proportional_allocations = []
for accuracy_target,(setup_cost_matrix,pp_cost_matrix) in zip(accuracy_range,cost_matrices):
    proportional_allocations += [proportional_partition(setup_cost_matrix,pp_cost_matrix).reshape(len(platforms),1)]

# %% [markdown]
# Heatmap representation of proportional partitioner. Only using a single value on y axis as the same allocation is used across all tasks. *Note* The heatmap is absolute
#
# First row seems a bit fishy - should be allocating bulk of work to local platform, but seems to be sharing everything across all platforms. The partitioner is defintely working - the latencies are close in value
#
# Later rows make sense - bulk of work getting allocated to GPUs and FPGAs. The Phi is maybe under utilised due to the lack of benchmarking data.

# %%
plot_number = 5
step_size = 1
fig, axes = plt.subplots(plot_number,sharex=True,sharey=True)
imgs = []

for i,ax in enumerate(axes):
    index = step_size*i
    ax.set_title("$%.4f"%accuracy_range[index])
    imgs += [ax.imshow(proportional_allocations[index].T,interpolation='nearest',cmap='hot',vmin=0,vmax=1)]
    print("$%.4f: "%accuracy_range[index],proportional_allocations[index].T)
    #print(numpy.sum(cost_matrices[index][0]+cost_matrices[index][1],axis=1)) #sanity test

axes[-1].set_yticks([])
axes[-1].set_xticks(range(len(platforms)))
axes[-1].set_xticklabels([(platform,platform_types) for platform,platform_types in platforms],rotation=90)

cax,kw = matplotlib.colorbar.make_axes([ax for ax in axes.flat])
fig.colorbar(imgs[0], cax=cax, **kw)

fig.set_size_inches(18.5,10.5)
# Out:
# ('$10.0000: ', array([[ 0.65404834,  0.01894171,  0.00901651,  0.00273456,  0.03541047,
#          0.02670783,  0.02451251,  0.01441757,  0.01373607,  0.02386483,
#          0.01392316,  0.02333704,  0.0363456 ,  0.01767653,  0.0450593 ,
#          0.04026799]]))
# ('$1.0000: ', array([[ 0.25154599,  0.0474055 ,  0.02170421,  0.00664274,  0.08851228,
#          0.05333081,  0.06148074,  0.03165143,  0.03446486,  0.05402556,
#          0.03314009,  0.05843128,  0.08609035,  0.00156847,  0.06992693,
#          0.10007876]]))
# ('$0.1000: ', array([[  9.18487041e-03,   1.12452279e-01,   1.32512855e-02,
#           4.89319532e-03,   1.92006371e-01,   7.77202454e-03,
#           1.74461063e-01,   7.30200297e-03,   1.01243124e-01,
#           1.56014732e-02,   1.67290866e-02,   1.43349388e-01,
#           4.04544521e-02,   5.03463784e-05,   5.58238909e-03,
#           1.55666649e-01]]))
# ('$0.0100: ', array([[  1.75321449e-03,   8.51108010e-02,   3.09896346e-03,
#           1.20387018e-03,   1.15559774e-01,   1.53728640e-03,
#           3.22828440e-01,   1.48621397e-03,   2.71565478e-01,
#           3.23968399e-03,   3.75647403e-03,   1.20958945e-01,
#           8.96611362e-03,   9.59658747e-06,   1.08055681e-03,
#           5.78445888e-02]]))
# ('$0.0010: ', array([[  1.62083061e-03,   8.10926967e-02,   2.87143968e-03,
#           1.11619721e-03,   1.09188794e-01,   1.42172313e-03,
#           3.26923279e-01,   1.37490413e-03,   2.88821297e-01,
#           2.99769633e-03,   3.47897202e-03,   1.15792925e-01,
#           8.30248862e-03,   8.87183112e-06,   9.99105549e-04,
#           5.39887792e-02]]))

# %% [markdown]
# ### Numerical Optimiser-based Partitioner

# %%
class SumValueError(Exception):
    def __init__(self, value):
        self.value = value
    

class BoundValueError(Exception):
    def __init__(self, value):
        self.value = value

# %%
def constrain_solution(x,platforms,tasks):
    x_new = numpy.copy(numpy.abs(x))

    for t in range(tasks):
        x_new[:,t] = numpy.copy(x_new[:,t])/numpy.sum(x_new[:,t])
        if(numpy.any(0.0>=numpy.sum(x_new[:,t])>=1.0)): raise BoundValueError(t)
        if(numpy.abs((numpy.sum(x_new[:,t])-1))>0.0001): raise SumValueError(t)
            
    return x_new

# %%
def numerical_optimiser_partitioner(setup_costs,pp_costs,platforms,tasks,timeout=10):
    #platforms = setup_costs.shape[0]
    #tasks = setup_costs.shape[1]
    
    def objective_function(x,setup_costs,pp_costs):
        #platforms,tasks = pp_costs.shape

        if(x.size!=(len(platforms)*len(tasks))): x = x[0]
            
        x = x.reshape(len(platforms),len(tasks))
        try: x = constrain_solution(x,len(platforms),len(tasks))
        except BoundValueError as e:
            print(int(e.value))
            for index,j in enumerate(x[:,int(e.value)]):
                if(0>j>1.0): print(j)
            #sys.exit(1)
                    
        except SumError as e:
            print(int(e.value))
            print(numpy.sum(x[:,e.value]))
            #sys.exit(1)
        
        return allocation_cost(x,pp_costs,setup_costs)
    
    #Starts off using the proportional allocation as a guess
    platform_allocation = proportional_partition(setup_costs,pp_costs).reshape(len(platforms),1)
    #platform_allocation = numpy.ones(len(platforms))*1.0/len(platforms)
    #print("initial allocation total: ",numpy.sum(platform_allocation.T))
    
    initial_allocation = numpy.ones(setup_costs.shape)
    for p in range(len(platforms)):
        initial_allocation[p,:] = platform_allocation[p]
        
    #print(initial_allocation)
    #initial_allocation_value = allocation_cost(initial_allocation,pp_costs,setup_costs)
        
    sa_maxiters = 10
    nm_maxiters = 100
    sa_nm_ratio = 0.9
    
    flag = True
    duration = 0.0
    T0 = 100*len(platforms)*len(tasks)
    while(flag):
        flag = False
        
        sa_start_time = time.time()
        sa_res = scipy.optimize.minimize(objective_function,initial_allocation.reshape(len(platforms)*len(tasks),1),method='Anneal',args=(setup_costs,pp_costs,),options={"maxiter":sa_maxiters,'lower':0.0,'upper':1.0,'T0':T0}) #Simulated Annealing
        #sa_res = scipy.optimize.basinhopping(objective_function,initial_allocation.reshape(platforms*tasks,1),niter=sa_maxiters,minimizer_kwargs={"args":(setup_costs,pp_costs,)},stepsize=0.1,disp=True)
        sa_end_time = time.time()
        
        #print(sa_res)
        
        T0 = sa_res.T
        sa_duration = sa_end_time-sa_start_time
        if(sa_res.x.size != len(platforms)*len(tasks)): sa_res.x = sa_res.x[0]
        output_allocation = sa_res.x.reshape(len(platforms),len(tasks)) #constrain_solution(,platforms,tasks)

        duration += sa_duration
        initial_allocation = numpy.copy(output_allocation)
        
        if(duration<timeout*sa_nm_ratio and not sa_res.success): flag = True # or not nm_res.success
        #if(flag): print("loop repeat: sa=",sa_res.success," sa_maxiters=",sa_maxiters," sa_duration=",sa_duration," duration=",duration) #," nm=",nm_res.success," nm_maxiters=",nm_maxiters, " nm_duration=",nm_duration
        #else: print("loop exit: sa=",sa_res.success," sa_maxiters=",sa_maxiters," sa_duration=",sa_duration,"sa_result=",sa_res.fun," duration=",duration) #," nm=",nm_res.success," nm_maxiters=",nm_maxiters, " nm_duration=",nm_duration
        
    #print(output_allocation)
    initial_allocation = constrain_solution(numpy.copy(output_allocation),len(platforms),len(tasks))
    #print(initial_allocation)
    
    #"Polishing" using the Simplex algorithm
    flag = True
    while(flag):
        flag = False
        nm_start_time = time.time()
        nm_res = scipy.optimize.minimize(objective_function,initial_allocation.reshape(len(platforms)*len(tasks),1),method='Nelder-Mead',args=(setup_costs,pp_costs,),options={"maxiter":nm_maxiters}) 
        nm_end_time = time.time()
        
        #print(nm_res)
        
        nm_duration = nm_end_time-nm_start_time
    
        duration += nm_duration
        initial_allocation = numpy.copy(nm_res.x.reshape(len(platforms),len(tasks)))
        
        if(duration<timeout and not nm_res.success): flag = True
            
    output_allocation = constrain_solution(initial_allocation.reshape(len(platforms),len(tasks)),len(platforms),len(tasks))
    output_allocation_value = allocation_cost(output_allocation,pp_costs,setup_costs)
    
    print("Time: ",duration)
    
    temp_proportional_allocation = proportional_partition(setup_costs,pp_costs).reshape(len(platforms),1)
    
    proportional_allocation = numpy.ones(setup_costs.shape)
    for p in range(len(platforms)): proportional_allocation[p,:] = temp_proportional_allocation[p]
        
    proportional_allocation_value = allocation_cost(proportional_allocation,pp_costs,setup_costs)
    
    print("Projected Improvement",proportional_allocation_value/output_allocation_value)
    
    return output_allocation

# %%
numerical_optimiser_allocations = []
for accuracy_target,(setup_cost_matrix,pp_cost_matrix) in zip(accuracy_range[:],cost_matrices[:]):
    numerical_optimiser_allocations += [numerical_optimiser_partitioner(setup_cost_matrix,pp_cost_matrix,platforms,tasks,300)]
    #print(numerical_optimiser_allocations[-1])
    print(numerical_optimiser_allocations[-1].shape)
# Out:
# ('Time: ', 303.8190608024597)
# ('Projected Improvement', 1.0000004624458048)
# (16, 128)
# ('Time: ', 311.8992533683777)
# ('Projected Improvement', 1.0001152396569271)
# (16, 128)
# ('Time: ', 311.6905553340912)
# ('Projected Improvement', 1.0070073525208738)
# (16, 128)
# ('Time: ', 300.99924516677856)
# ('Projected Improvement', 1.0818002579609269)
# (16, 128)
# ('Time: ', 300.8033905029297)
# ('Projected Improvement', 1.0866726673471756)
# (16, 128)

# %%
platform_task_allocations(numerical_optimiser_allocations,accuracy_range,platforms,tasks)
# Out:
# [('', 'multicore_cpu'), ('ee-snowball2', 'opencl_alterafpga'), ('phi', 'multicore_cpu'), ('phi', 'opencl_gpu'), ('ee-snowball0', 'opencl_gpu'), ('amazon-gpu-0', 'multicore_cpu'), ('amazon-gpu-0', 'opencl_gpu'), ('amazon-gpu-1', 'multicore_cpu'), ('amazon-gpu-1', 'opencl_gpu'), ('amazon-cpu-0', 'multicore_cpu'), ('amazon-cpu-1', 'multicore_cpu'), ('ee-snowball1', 'opencl_gpu'), ('ee-benjamin', 'multicore_cpu'), ('pi', 'multicore_cpu'), ('ee-mollie', 'multicore_cpu'), ('ee-mollie', 'maxeler_fpga')]
# ('$10.0000: ', 127.99999999999845)
# [ 0.6541132   0.01894359  0.00891824  0.00273483  0.03541398  0.02671048
#   0.02451494  0.014419    0.01373743  0.0238672   0.01392454  0.02333935
#   0.03634921  0.01767828  0.04506377  0.04027198]
# ('$1.0000: ', 128.00000000000034)
# [ 0.25160842  0.04741726  0.02146141  0.00664439  0.08853425  0.05334405
#   0.061496    0.03165929  0.03447342  0.05403896  0.03314832  0.05844578
#   0.08611171  0.00156886  0.06994428  0.1001036 ]
# ('$0.1000: ', 127.99999999999957)
# [  9.18632729e-03   1.12470116e-01   1.30947707e-02   4.89397147e-03
#    1.92036827e-01   7.77325731e-03   1.74488735e-01   7.30316119e-03
#    1.01259182e-01   1.56039479e-02   1.67317401e-02   1.43372126e-01
#    4.04608688e-02   5.03543641e-05   5.58327455e-03   1.55691340e-01]
# ('$0.0100: ', 127.99999999999993)
# [  1.75328307e-03   8.51141306e-02   3.05996447e-03   1.20391727e-03
#    1.15564295e-01   1.53734653e-03   3.22841069e-01   1.48627211e-03
#    2.71576102e-01   3.23981073e-03   3.75662098e-03   1.20963677e-01
#    8.96646438e-03   9.59696289e-06   1.08059908e-03   5.78468516e-02]
# ('$0.0010: ', 127.99999999999893)
# [  1.61852171e-03   8.09771785e-02   2.86734925e-03   1.11460716e-03
#    1.09033252e-01   1.41969786e-03   3.27919644e-01   1.37294555e-03
#    2.88409865e-01   2.99034540e-03   3.47401615e-03   1.15627975e-01
#    8.25618930e-03   8.85919301e-06   9.97682302e-04   5.39118711e-02]

# %% [markdown]
# ### SCIP-based Partitioner

# %%
import subprocess32 as subprocess
import os

def scip_partitioner(setup_costs,pp_costs,platforms,tasks,timeout=10,acc_id=None):
    #platforms = setup_costs.shape[0]
    #tasks = setup_costs.shape[1]
    
    if(acc_id==None): acc_id = time.time()
    filename_suffix = "%d_%d_%d_%f"%(len(platforms),len(tasks),timeout,acc_id)
    filename_suffix = filename_suffix.replace('.','-')
    
    platform_filename = "platforms_%s.txt"%filename_suffix
    task_filename = "tasks_%s.txt"%filename_suffix
    setup_filename = "latency_setup_%s.txt"%filename_suffix
    pp_filename = "latency_pp_%s.txt"%filename_suffix
    settings_filename = "settings_%s.set"%filename_suffix
    zimpl_output_string = "platform_schedule_%s"%filename_suffix
    
    #Writing Parameters to datafile for SCIP
    platform_file = open(platform_filename,"w")
    for tp in range(len(platforms)): platform_file.write("%s\n"%tp)
    platform_file.close()

    task_file = open(task_filename,"w")
    for tt in range(len(tasks)): task_file.write("%s\n"%tt)
    task_file.close()

    
    latencysetup_file = open(setup_filename,"w")
    latencypp_file = open(pp_filename,"w")
    
    selection = numpy.logical_not(numpy.isinf(pp_costs))
    platform_max = numpy.sum(setup_costs[selection]+pp_costs[selection])
    print("setup max:",platform_max)
    for tp in range(len(platforms)):
        for tt in range(len(tasks)):
            if (numpy.isinf(setup_costs[tp,tt]) or numpy.isinf(pp_costs[tp,tt]) or setup_costs[tp,tt]<0 or pp_costs[tp,tt]<0):
                latencysetup_file.write("%s %s %f\n"%(tp,tt,0.0)) #Setting any tasks with infinite coefficients to take longer than all of the setup times added together
                latencypp_file.write("%s %s %f\n"%(tp,tt,platform_max))
            else:
                latencysetup_file.write("%s %s %s\n"%(tp,tt,setup_costs[tp,tt])) #Just need the latency setup time which is constant
                latencypp_file.write("%s %s %s\n"%(tp,tt,pp_costs[tp,tt]))

    latencypp_file.close()
    latencysetup_file.close()

    #Creating LP description problem using ZIMPL
    zimpl_output = subprocess.check_output(["zimpl","-o",zimpl_output_string,"-D","PLATFORM_FILE=%s"%platform_filename,"-D","TASK_FILE=%s"%task_filename,"-D","LATENCY_PP_FILE=%s"%pp_filename,"-D","LATENCY_SETUP_FILE=%s"%setup_filename,"platform_schedule.zpl"])

    #Setting paramters for SCIP
    settings_file = open(settings_filename,"w")
    settings_file.write("limits/time = %f\n"%timeout)
    settings_file.close()

    #Running SCIP
    start_time = time.time()
    scip_output = subprocess.check_output(["scip","-f","%s.lp"%zimpl_output_string,"-s","%s"%settings_filename])
    end_time = time.time()

    #Parsing SCIP results
    gap_found = False
    value_found = False
    #print(scip_output)
    
    allocation = numpy.zeros((len(platforms),len(tasks)))
    #print scip_output
    for so in scip_output.split("\n"):
        if("Gap" in so and not gap_found):
            gap = so.split(":")[1].strip(' ').strip("%")
            if("infinite" in gap.lower()): gap = numpy.inf
            else: gap = float(gap)
            gap_found = True
        elif("task_max " in so and not value_found):
            value = so.split(":")[0].split('(')[0].split(' ')[-2]
            value_found = True
        elif("A$" in so and "task_max" not in so):
            temp_list = so.split(" ")
            try: a_value = float(temp_list[-2])
            except ValueError: 
                print("Error caused by:",temp_list[-2])
                a_value = 0.0
            dummy,platform,task = temp_list[0].split("$")
            #except: print("Error caused by: ",temp_list[0])
            allocation[int(platform),int(task)] = a_value
            
    print("gap:",gap)
    
    temp_proportional_allocation = proportional_partition(setup_costs,pp_costs).reshape(len(platforms),1)
    
    proportional_allocation = numpy.ones(setup_costs.shape)
    for p in range(len(platforms)): proportional_allocation[p,:] = temp_proportional_allocation[p]
        
    proportional_allocation_value = allocation_cost(proportional_allocation,pp_costs,setup_costs)
    
    print("Projected Improvement",proportional_allocation_value/float(value))
    
    os.remove(platform_filename)
    os.remove(task_filename)
    os.remove(setup_filename)
    os.remove(pp_filename)
    os.remove("%s.lp"%zimpl_output_string)
    os.remove("%s.tbl"%zimpl_output_string)
    os.remove(settings_filename)
    
    return allocation

# %% [markdown]
# Commands for cleaning up current working directory

# %%
# !rm *.tbl
# !rm *.txt
# !rm *.lp
# !rm *.set
# Out:
# rm: cannot remove ‘*.tbl’: No such file or directory
# rm: cannot remove ‘*.txt’: No such file or directory
# rm: cannot remove ‘*.lp’: No such file or directory
# rm: cannot remove ‘*.set’: No such file or directory

# %%
scip_allocations = []
for accuracy_target,(setup_cost_matrix,pp_cost_matrix) in zip(accuracy_range,cost_matrices):
    scip_allocations += [scip_partitioner(setup_cost_matrix[:,:],pp_cost_matrix[:,:],platforms,tasks[:],300,accuracy_target)]
    #print(numerical_optimiser_allocations[-1])
    print(numpy.sum(scip_allocations[-1]))
# Out:
# ('setup max:', 404.287481693026)
# ('gap:', 5.3)
# ('Projected Improvement', 123.20518013157373)
# 128.0
# ('setup max:', 1040.7296927283271)
# ('gap:', 4.33)
# ('Projected Improvement', 85.101391256778939)
# 128.0
# ('setup max:', 64684.950796258454)
# ('gap:', 3.72)
# ('Projected Improvement', 30.783095043641659)
# 128.000006243
# ('setup max:', 6429107.0611492749)
# ('gap:', 0.0)
# ('Projected Improvement', 2.9594193139633913)
# 128.418707451
# ('setup max:', 642871318.09645092)
# ('gap:', 0.0)
# ('Projected Improvement', 2.0081039679653037)
# 128.0

# %%
platform_task_allocations(scip_allocations,accuracy_range,platforms,tasks[:])
# Out:
# [('', 'multicore_cpu'), ('ee-snowball2', 'opencl_alterafpga'), ('phi', 'multicore_cpu'), ('phi', 'opencl_gpu'), ('ee-snowball0', 'opencl_gpu'), ('amazon-gpu-0', 'multicore_cpu'), ('amazon-gpu-0', 'opencl_gpu'), ('amazon-gpu-1', 'multicore_cpu'), ('amazon-gpu-1', 'opencl_gpu'), ('amazon-cpu-0', 'multicore_cpu'), ('amazon-cpu-1', 'multicore_cpu'), ('ee-snowball1', 'opencl_gpu'), ('ee-benjamin', 'multicore_cpu'), ('pi', 'multicore_cpu'), ('ee-mollie', 'multicore_cpu'), ('ee-mollie', 'maxeler_fpga')]
# ('$10.0000: ', 127.99999999999999)
# [  7.03114818e-01   1.56250000e-02   7.81250000e-03   7.17188876e-06
#    3.12505054e-02   2.34375000e-02   1.56250000e-02   7.81250000e-03
#    7.81250000e-03   1.56250000e-02   7.81250000e-03   1.56271841e-02
#    3.12500000e-02   2.34375162e-02   4.68750000e-02   4.68753045e-02]
# ('$1.0000: ', 128.0)
# [  5.85932152e-01   2.34375000e-02   7.81250000e-03   4.03734241e-06
#    4.68750859e-02   3.00073707e-02   3.12500000e-02   1.56250000e-02
#    1.56250000e-02   2.34375000e-02   1.56250000e-02   3.12501071e-02
#    4.68750000e-02   2.34382525e-02   4.03051293e-02   6.25003652e-02]
# ('$0.1000: ', 128.00000624260349)
# [  2.68152176e-01   5.46875000e-02   1.56250000e-02   4.87703397e-08
#    1.09375000e-01   3.12500000e-02   7.03125000e-02   1.56250000e-02
#    3.90625000e-02   3.90625000e-02   2.34375000e-02   6.25000082e-02
#    6.25000000e-02   5.45566654e-02   4.44786454e-02   1.09375005e-01]
# ('$0.0100: ', 128.41870745072234)
# [ 0.14755471  0.05015618  0.01889615  0.01215843  0.1524391   0.0234375
#   0.06872222  0.00189653  0.12657004  0.02927327  0.02255666  0.08166545
#   0.03268711  0.03125     0.0399453   0.1640625 ]
# ('$0.0010: ', 128.00000000000006)
# [ 0.01872541  0.10819095  0.01335794  0.01215192  0.17845019  0.00961662
#   0.08856603  0.00180541  0.19984441  0.01782588  0.00696212  0.09253744
#   0.00078175  0.01566585  0.09184748  0.14367061]

# %% [markdown]
# ## Comparing Partitions

# %%
scip_cost = []
num_opt_cost = []
prop_cost = []

for accuracy_target,(setup_cost_matrix,pp_cost_matrix),scip,num_opt,prop in zip(accuracy_range,cost_matrices,scip_allocations,numerical_optimiser_allocations,proportional_allocations):
    scip_cost_matrix = numpy.zeros(setup_cost_matrix.shape)
    num_opt_cost_matrix = numpy.zeros(setup_cost_matrix.shape)
    prop_cost_matrix = numpy.zeros(setup_cost_matrix.shape)
    for p in range(len(platforms)):
        for t in range(len(tasks)):
            selection = numpy.logical_not(numpy.isinf(setup_cost_matrix))
            if(selection[p,t]):
                scip_cost_matrix[p,t] = setup_cost_matrix[p,t] + pp_cost_matrix[p,t]*scip[p,t]
                num_opt_cost_matrix[p,t] = setup_cost_matrix[p,t] + pp_cost_matrix[p,t]*num_opt[p,t]
                prop_cost_matrix[p,t] = setup_cost_matrix[p,t] + pp_cost_matrix[p,t]*prop[p]
    
    scip_cost += [numpy.max(numpy.sum(scip_cost_matrix,axis=0))]
    num_opt_cost += [numpy.max(numpy.sum(num_opt_cost_matrix,axis=0))]
    prop_cost += [numpy.max(numpy.sum(prop_cost_matrix,axis=0))]
    
scip_cost = numpy.array(scip_cost)
num_opt_cost = numpy.array(num_opt_cost)
prop_cost = numpy.array(prop_cost)
    
plt.plot(accuracy_range,prop_cost/scip_cost,"-x",label="SCIP Partitioner")
plt.plot(accuracy_range,prop_cost/num_opt_cost,"-o",label="Number Optimiser Partitioner")
#plt.plot(accuracy_range,prop_cost,"-.",label="Proportional Partitioner")

plt.legend()

ax = plt.gca()
#ax.set_ylim([0,1000])
ax.set_xscale('log')
#ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %%
print(prop_cost)
print(num_opt_cost)
print(scip_cost)
# Out:
# [  3.88933702e+00   3.88948569e+00   6.32762474e+00   1.01902607e+02
#    9.39162694e+03]
# [  3.88933702e+00   3.88948569e+00   6.18867262e+00   1.00007164e+02
#    8.94375722e+03]
# [  3.88933447e+00   3.88956817e+00   3.99882734e+00   4.27512511e+01
#    7.25453993e+03]

# %% [markdown]
# ## Executing Partitions

# %% [markdown]
# ### Setup

# %%
import csv

options = []
with open('valid_seeds_file.csv','r') as valid_seeds_file:
    csvreader = csv.DictReader(valid_seeds_file,delimiter=',')
    options = [row for row in csvreader]

# %%
import ForwardFinancialFramework.bin.option_generator as option_generator

option_tasks = [option_generator.generate_option(int(o['seed']),underlying_type=o['underlying'],option_type=o['option']) for o in options]

# %% [markdown]
# Platform setup:

# %%
from ForwardFinancialFramework.Platforms.MulticoreCPU import MulticoreCPU_MonteCarlo, MulticoreCPU
from ForwardFinancialFramework.Platforms.OpenCLGPU import OpenCLGPU_MonteCarlo,OpenCLGPU
from ForwardFinancialFramework.Platforms.OpenCLAlteraFPGA import OpenCLAlteraFPGA_MonteCarlo,OpenCLAlteraFPGA
from ForwardFinancialFramework.Platforms.MaxelerFPGA import MaxelerFPGA_MonteCarlo,MaxelerFPGA

# %%
execution_platforms = [MulticoreCPU.MulticoreCPU(threads=7)] #0
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="ee-benjamin")] #1
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="pi")] #2
execution_platforms += [MulticoreCPU.MulticoreCPU(threads=7,remote=True,ssh_alias="ee-mollie")] #3
execution_platforms += [MulticoreCPU.MulticoreCPU(threads=31,remote=True,ssh_alias="phi")] #4
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball0")] #5
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball1")] #6
execution_platforms += [MaxelerFPGA.MaxelerFPGA(remote=True,ssh_alias="ee-mollie")] #7
execution_platforms += [OpenCLAlteraFPGA.OpenCLAlteraFPGA(remote=True,ssh_alias="ee-snowball2")] #8
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="phi")] #9
execution_platforms[-1].device_type=8
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-cpu-0")] #10
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-cpu-1")] #11
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-gpu-0",threads=7)] #12
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-gpu-1",threads=7)] #13
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="amazon-gpu-0")] #14
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="amazon-gpu-1")] #15

# %% [markdown]
# ### Calculating the paths manifests for the different partitions

# %%
scip_manifest = numpy.zeros((len(platforms),len(accuracy_range),len(tasks)))
no_manifest = numpy.zeros((len(platforms),len(accuracy_range),len(tasks)))
prop_manifest = numpy.zeros((len(platforms),len(accuracy_range),len(tasks)))

# %%
for i,accuracy_target,(setup_cost_matrix,pp_cost_matrix) in zip(range(len(accuracy_range)),accuracy_range,cost_matrices):
    for j,(platform,platform_type) in enumerate(platforms):
        for k,task in enumerate(tasks):
            accuracy_coefficient,dummy1,dummy2 = select_coefficients(data,platform,platform_type,task)
            if not(numpy.isinf(accuracy_coefficient)):
                task_paths = paths_accuracy(accuracy_target,accuracy_coefficient)
                scip_manifest[j][i][k] = numpy.ceil(task_paths*scip_allocations[i][j][k])
                no_manifest[j][i][k] = numpy.ceil(task_paths*numerical_optimiser_allocations[i][j][k])
                prop_manifest[j][i][k] = numpy.ceil(task_paths*proportional_allocations[i][j])

# %% [markdown]
# ### Running Partition Manifests

# %% [markdown]
# Rounding off the number of paths seems to be a significant issue - implementations should be made more robust in handling this, particularly the Xeon Phi.
#
# Snowball2 seems to have a particular issue when large numbers of work items (100Ms).

# %%
def platform_execute(platform,option_tasks,platform_paths,accuracy_targets,queue,output_queue,error_queue,):
    import subprocess32 as subprocess
    for i,o in enumerate(option_tasks):
        results = []
        
        for target_accuracy,paths in zip(accuracy_targets,platform_paths[:,i]):
            retries = 3
            while(retries):
                if(paths):
                    if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #rounding up the number of paths
                        paths = int(numpy.ceil(1.0*paths/1000)*1000)
                    else:
                        paths = int(numpy.ceil(1.0*paths/10)*10)
                    
                    if(isinstance(platform,MulticoreCPU.MulticoreCPU)): 
                        mc_solver = MulticoreCPU_MonteCarlo.MulticoreCPU_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,OpenCLGPU.OpenCLGPU)): 
                        mc_solver = OpenCLGPU_MonteCarlo.OpenCLGPU_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,OpenCLAlteraFPGA.OpenCLAlteraFPGA)): 
                        mc_solver = OpenCLAlteraFPGA_MonteCarlo.OpenCLAlteraFPGA_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                        if("heston" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=8)
                        elif("black_scholes" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=16)
                    
                    if(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                        mc_solver.dummy_run()
                        mc_solver.execute()
              
                    try:
                        result = mc_solver.execute()
                        if(numpy.isnan(float(result[1])) or float(result[1])==0): raise ValueError()
                            
                        retries = 0
                        results.append((paths,result[-1]/10e6,target_accuracy,float(result[1])))
                        output_queue.put_nowait((platform.ssh_alias,platform.name,(paths,result[-1]/10e6,target_accuracy,float(result[1]))))
                    
                    #print((platform.ssh_alias,platform.name,(paths,result[-1]/10e6,float(result[1]))))
            
                    except subprocess.CalledProcessError as e:
                        output_queue.put_nowait("Command Error!\nCommand:" + str(e.cmd) + "\nReturn: " + str(e.output) + "\nReturncode: " + str(e.returncode))
                        retries -= 1
                        
                        if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #increasing the number of paths
                            paths += 1000
                        else:
                            paths += 10
                        
                        if not(retries): error_queue.put_nowait((platform.ssh_alias,platform.name,paths,i,target_accuracy))
                    
                    except ValueError:
                        output_queue.put_nowait("Value Error!\nPlatform:" + platform.ssh_alias + "\nPlatform Type:" + platform.name + "\nTask: " + str(i) + "\nValue: " + result[1])
                        retries -= 1
                        
                        if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #increasing the number of paths
                            paths += 1000
                        else:
                            paths += 100
                        
                        if not(retries): error_queue.put_nowait((platform.ssh_alias,platform.name,paths,i,target_accuracy))
                else:
                    retries = 0
                
            if(results):
                #print(str(i) + " on " + platform.ssh_alias + "("+platform.name+")" + ": " + str(results) + "\n")
                output_queue.put_nowait(str(i) + " on " + platform.ssh_alias + "("+platform.name+")" + ": " + str(results) + "\n")
                queue.put_nowait((platform.ssh_alias,platform.name,i,results))

# %%
import multiprocessing

queue = multiprocessing.Queue(len(platforms)*len(option_tasks)*2)
output_queue = multiprocessing.Queue()
error_queue = multiprocessing.Queue(len(platforms)*len(option_tasks))

# %%
def run_manifest(path_manifest,platforms,execution_platforms,option_tasks,accuracy_range,queue,output_queue,error_queue,parallel=True):
    results = []
    if(parallel):
        try:
            pool = [multiprocessing.Process(target=platform_execute,args=(p,option_tasks,path_manifest[platforms.index((p.ssh_alias,p.name))],accuracy_range,queue,output_queue,error_queue,)) for j,p in enumerate(execution_platforms)]
    
            for p in pool: p.start()
        
            while(True):
                while not(output_queue.empty()): print(output_queue.get())
                while not(queue.empty()): results += [queue.get()]
        
                flag = True
                for p in pool: 
                    if(p.is_alive() and flag): flag = False
                if(flag): break
            
                time.sleep(1)
            
            for p in pool: 
                p.join()
                del p
        except KeyboardInterrupt:
            for p in pool: 
                p.terminate()
                del p
    
    else: 
        for j,p in enumerate(execution_platforms): platform_execute(p,option_tasks,path_manifest[platforms.index((p.ssh_alias,p.name))],accuracy_range,queue,output_queue,error_queue,)
            
    return results
        
#print(scip_manifest[j].shape)
#print(accuracy_range)
        
#for p in execution_platforms: platform_execute(p,option_tasks,scip_manifest[j],accuracy_range,queue,output_queue,)

# %%
scip_manifest_results = run_manifest(scip_manifest[:,:,:],platforms,execution_platforms,option_tasks,accuracy_range[:],queue,output_queue,error_queue,parallel=True)
# Out:
# ('', 'multicore_cpu', (30, 0.0033378124237060545, 1.0, 0.828193))
# 0 on (multicore_cpu): [(30, 0.0033378124237060545, 1.0, 0.828193)]
#
# ('', 'multicore_cpu', (2630, 0.019161701202392578, 0.10000000000000001, 0.078343))
# 0 on (multicore_cpu): [(30, 0.0033378124237060545, 1.0, 0.828193), (2630, 0.019161701202392578, 0.10000000000000001, 0.078343)]
#
# 0 on (multicore_cpu): [(30, 0.0033378124237060545, 1.0, 0.828193), (2630, 0.019161701202392578, 0.10000000000000001, 0.078343)]
#
# 0 on (multicore_cpu): [(30, 0.0033378124237060545, 1.0, 0.828193), (2630, 0.019161701202392578, 0.10000000000000001, 0.078343)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0015874862670898437, 10.0, 0.295014))
# 1 on (multicore_cpu): [(110, 0.0015874862670898437, 10.0, 0.295014)]
#
# ('', 'multicore_cpu', (20, 0.001287698745727539, 1.0, 0.600035))
# 1 on (multicore_cpu): [(110, 0.0015874862670898437, 10.0, 0.295014), (20, 0.001287698745727539, 1.0, 0.600035)]
#
# ('', 'multicore_cpu', (1330, 0.00707089900970459, 0.10000000000000001, 0.070357))
# 1 on (multicore_cpu): [(110, 0.0015874862670898437, 10.0, 0.295014), (20, 0.001287698745727539, 1.0, 0.600035), (1330, 0.00707089900970459, 0.10000000000000001, 0.070357)]
#
# 1 on (multicore_cpu): [(110, 0.0015874862670898437, 10.0, 0.295014), (20, 0.001287698745727539, 1.0, 0.600035), (1330, 0.00707089900970459, 0.10000000000000001, 0.070357)]
#
# 1 on (multicore_cpu): [(110, 0.0015874862670898437, 10.0, 0.295014), (20, 0.001287698745727539, 1.0, 0.600035), (1330, 0.00707089900970459, 0.10000000000000001, 0.070357)]
#
# ('', 'multicore_cpu', (10, 0.000964212417602539, 10.0, 0.903319))
# 2 on (multicore_cpu): [(10, 0.000964212417602539, 10.0, 0.903319)]
#
# ('', 'multicore_cpu', (20, 0.001282978057861328, 1.0, 0.258121))
# 2 on (multicore_cpu): [(10, 0.000964212417602539, 10.0, 0.903319), (20, 0.001282978057861328, 1.0, 0.258121)]
#
# ('', 'multicore_cpu', (1370, 0.0068531036376953125, 0.10000000000000001, 0.117836))
# 2 on (multicore_cpu): [(10, 0.000964212417602539, 10.0, 0.903319), (20, 0.001282978057861328, 1.0, 0.258121), (1370, 0.0068531036376953125, 0.10000000000000001, 0.117836)]
#
# ('ee-benjamin', 'multicore_cpu', (41950, 0.12333500385284424, 0.01, 0.018003))
# 0 on ee-benjamin(multicore_cpu): [(41950, 0.12333500385284424, 0.01, 0.018003)]
#
# 0 on ee-benjamin(multicore_cpu): [(41950, 0.12333500385284424, 0.01, 0.018003)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Value Error!
# Platform:amazon-gpu-0
# Platform Type:multicore_cpu
# Task: 16
# Value: 0.000000
# ('amazon-gpu-0', 'opencl_gpu', (1000, 0.15354490280151367, 10.0, 0.296991))
# 18 on amazon-gpu-0(opencl_gpu): [(1000, 0.15354490280151367, 10.0, 0.296991)]
#
# 18 on amazon-gpu-0(opencl_gpu): [(1000, 0.15354490280151367, 10.0, 0.296991)]
#
# 18 on amazon-gpu-0(opencl_gpu): [(1000, 0.15354490280151367, 10.0, 0.296991)]
#
# 18 on amazon-gpu-0(opencl_gpu): [(1000, 0.15354490280151367, 10.0, 0.296991)]
#
# 18 on amazon-gpu-0(opencl_gpu): [(1000, 0.15354490280151367, 10.0, 0.296991)]
#
# ('ee-mollie', 'multicore_cpu', (15410, 0.24075570106506347, 0.01, 0.032651))
# 2 on ee-mollie(multicore_cpu): [(15410, 0.24075570106506347, 0.01, 0.032651)]
#
# 2 on ee-mollie(multicore_cpu): [(15410, 0.24075570106506347, 0.01, 0.032651)]
#
# Value Error!
# Platform:amazon-gpu-1
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('amazon-gpu-0', 'multicore_cpu', (110, 0.12793028354644775, 10.0, 0.022886))
# 16 on amazon-gpu-0(multicore_cpu): [(110, 0.12793028354644775, 10.0, 0.022886)]
#
# 16 on amazon-gpu-0(multicore_cpu): [(110, 0.12793028354644775, 10.0, 0.022886)]
#
# 16 on amazon-gpu-0(multicore_cpu): [(110, 0.12793028354644775, 10.0, 0.022886)]
#
# 16 on amazon-gpu-0(multicore_cpu): [(110, 0.12793028354644775, 10.0, 0.022886)]
#
# 16 on amazon-gpu-0(multicore_cpu): [(110, 0.12793028354644775, 10.0, 0.022886)]
#
# ('ee-snowball1', 'opencl_gpu', (1675000, 0.31874589920043944, 0.001, 0.002853))
# 0 on ee-snowball1(opencl_gpu): [(1675000, 0.31874589920043944, 0.001, 0.002853)]
#
# ('pi', 'multicore_cpu', (110, 0.18405790328979493, 10.0, 0.44504))
# 0 on pi(multicore_cpu): [(110, 0.18405790328979493, 10.0, 0.44504)]
#
# 0 on pi(multicore_cpu): [(110, 0.18405790328979493, 10.0, 0.44504)]
#
# 0 on pi(multicore_cpu): [(110, 0.18405790328979493, 10.0, 0.44504)]
#
# 0 on pi(multicore_cpu): [(110, 0.18405790328979493, 10.0, 0.44504)]
#
# 0 on pi(multicore_cpu): [(110, 0.18405790328979493, 10.0, 0.44504)]
#
# ('ee-mollie', 'maxeler_fpga', (207000, 0.07888879776000976, 0.001, 0.006276))
# 1 on ee-mollie(maxeler_fpga): [(207000, 0.07888879776000976, 0.001, 0.006276)]
#
# ('amazon-gpu-1', 'multicore_cpu', (110, 0.21470401287078858, 10.0, 0.338248))
# 3 on amazon-gpu-1(multicore_cpu): [(110, 0.21470401287078858, 10.0, 0.338248)]
#
# 3 on amazon-gpu-1(multicore_cpu): [(110, 0.21470401287078858, 10.0, 0.338248)]
#
# 3 on amazon-gpu-1(multicore_cpu): [(110, 0.21470401287078858, 10.0, 0.338248)]
#
# 3 on amazon-gpu-1(multicore_cpu): [(110, 0.21470401287078858, 10.0, 0.338248)]
#
# 3 on amazon-gpu-1(multicore_cpu): [(110, 0.21470401287078858, 10.0, 0.338248)]
#
# ('', 'multicore_cpu', (120970, 0.4609683036804199, 0.01, 0.011911))
# 2 on (multicore_cpu): [(10, 0.000964212417602539, 10.0, 0.903319), (20, 0.001282978057861328, 1.0, 0.258121), (1370, 0.0068531036376953125, 0.10000000000000001, 0.117836), (120970, 0.4609683036804199, 0.01, 0.011911)]
#
# 2 on (multicore_cpu): [(10, 0.000964212417602539, 10.0, 0.903319), (20, 0.001282978057861328, 1.0, 0.258121), (1370, 0.0068531036376953125, 0.10000000000000001, 0.117836), (120970, 0.4609683036804199, 0.01, 0.011911)]
#
# ('', 'multicore_cpu', (20, 0.001287984848022461, 1.0, 0.168522))
# 3 on (multicore_cpu): [(20, 0.001287984848022461, 1.0, 0.168522)]
#
# ('', 'multicore_cpu', (1060, 0.006100893020629883, 0.10000000000000001, 0.116738))
# 3 on (multicore_cpu): [(20, 0.001287984848022461, 1.0, 0.168522), (1060, 0.006100893020629883, 0.10000000000000001, 0.116738)]
#
# ('ee-mollie', 'multicore_cpu', (42440, 0.27224249839782716, 0.10000000000000001, 0.097876))
# 5 on ee-mollie(multicore_cpu): [(42440, 0.27224249839782716, 0.10000000000000001, 0.097876)]
#
# 5 on ee-mollie(multicore_cpu): [(42440, 0.27224249839782716, 0.10000000000000001, 0.097876)]
#
# 5 on ee-mollie(multicore_cpu): [(42440, 0.27224249839782716, 0.10000000000000001, 0.097876)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.03582048416137695, 10.0, 3.848157))
# 9 on ee-mollie(multicore_cpu): [(10, 0.03582048416137695, 10.0, 3.848157)]
#
# 9 on ee-mollie(multicore_cpu): [(10, 0.03582048416137695, 10.0, 3.848157)]
#
# 9 on ee-mollie(multicore_cpu): [(10, 0.03582048416137695, 10.0, 3.848157)]
#
# ('ee-snowball1', 'opencl_gpu', (1592000, 0.28975989818573, 0.001, 0.003258))
# 2 on ee-snowball1(opencl_gpu): [(1592000, 0.28975989818573, 0.001, 0.003258)]
#
# ('ee-snowball0', 'opencl_gpu', (8581000, 0.6786389827728272, 0.001, 0.001256))
# 4 on ee-snowball0(opencl_gpu): [(8581000, 0.6786389827728272, 0.001, 0.001256)]
#
# ('amazon-cpu-0', 'multicore_cpu', (332950, 0.7462647914886474, 0.01, 0.010759))
# 6 on amazon-cpu-0(multicore_cpu): [(332950, 0.7462647914886474, 0.01, 0.010759)]
#
# 6 on amazon-cpu-0(multicore_cpu): [(332950, 0.7462647914886474, 0.01, 0.010759)]
#
# ('amazon-gpu-0', 'multicore_cpu', (76880, 0.4974117040634155, 0.01, 0.012327))
# 28 on amazon-gpu-0(multicore_cpu): [(76880, 0.4974117040634155, 0.01, 0.012327)]
#
# 28 on amazon-gpu-0(multicore_cpu): [(76880, 0.4974117040634155, 0.01, 0.012327)]
#
# ('amazon-cpu-1', 'multicore_cpu', (296960, 0.8996253967285156, 0.01, 0.012632))
# 26 on amazon-cpu-1(multicore_cpu): [(296960, 0.8996253967285156, 0.01, 0.012632)]
#
# 26 on amazon-cpu-1(multicore_cpu): [(296960, 0.8996253967285156, 0.01, 0.012632)]
#
# Value Error!
# Platform:amazon-gpu-0
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# ('', 'multicore_cpu', (105780, 0.40862891674041746, 0.01, 0.011875))
# 3 on (multicore_cpu): [(20, 0.001287984848022461, 1.0, 0.168522), (1060, 0.006100893020629883, 0.10000000000000001, 0.116738), (105780, 0.40862891674041746, 0.01, 0.011875)]
#
# 3 on (multicore_cpu): [(20, 0.001287984848022461, 1.0, 0.168522), (1060, 0.006100893020629883, 0.10000000000000001, 0.116738), (105780, 0.40862891674041746, 0.01, 0.011875)]
#
# ('', 'multicore_cpu', (10, 0.0011276960372924804, 10.0, 0.195067))
# 4 on (multicore_cpu): [(10, 0.0011276960372924804, 10.0, 0.195067)]
#
# ('', 'multicore_cpu', (20, 0.0013842105865478516, 1.0, 0.901483))
# 4 on (multicore_cpu): [(10, 0.0011276960372924804, 10.0, 0.195067), (20, 0.0013842105865478516, 1.0, 0.901483)]
#
# ('', 'multicore_cpu', (1100, 0.005930709838867188, 0.10000000000000001, 0.116704))
# 4 on (multicore_cpu): [(10, 0.0011276960372924804, 10.0, 0.195067), (20, 0.0013842105865478516, 1.0, 0.901483), (1100, 0.005930709838867188, 0.10000000000000001, 0.116704)]
#
# Value Error!
# Platform:amazon-gpu-0
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:amazon-gpu-0
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# ('amazon-gpu-1', 'multicore_cpu', (53770, 0.844878101348877, 0.10000000000000001, 0.103898))
# 51 on amazon-gpu-1(multicore_cpu): [(53770, 0.844878101348877, 0.10000000000000001, 0.103898)]
#
# 51 on amazon-gpu-1(multicore_cpu): [(53770, 0.844878101348877, 0.10000000000000001, 0.103898)]
#
# 51 on amazon-gpu-1(multicore_cpu): [(53770, 0.844878101348877, 0.10000000000000001, 0.103898)]
#
# ('', 'multicore_cpu', (109940, 0.41953489780426023, 0.01, 0.011243))
# 4 on (multicore_cpu): [(10, 0.0011276960372924804, 10.0, 0.195067), (20, 0.0013842105865478516, 1.0, 0.901483), (1100, 0.005930709838867188, 0.10000000000000001, 0.116704), (109940, 0.41953489780426023, 0.01, 0.011243)]
#
# 4 on (multicore_cpu): [(10, 0.0011276960372924804, 10.0, 0.195067), (20, 0.0013842105865478516, 1.0, 0.901483), (1100, 0.005930709838867188, 0.10000000000000001, 0.116704), (109940, 0.41953489780426023, 0.01, 0.011243)]
#
# ('', 'multicore_cpu', (430, 0.0031774044036865234, 1.0, 0.952603))
# 5 on (multicore_cpu): [(430, 0.0031774044036865234, 1.0, 0.952603)]
#
# 5 on (multicore_cpu): [(430, 0.0031774044036865234, 1.0, 0.952603)]
#
# 5 on (multicore_cpu): [(430, 0.0031774044036865234, 1.0, 0.952603)]
#
# 5 on (multicore_cpu): [(430, 0.0031774044036865234, 1.0, 0.952603)]
#
# ('', 'multicore_cpu', (10, 0.0011715888977050781, 10.0, 1.115431))
# 6 on (multicore_cpu): [(10, 0.0011715888977050781, 10.0, 1.115431)]
#
# ('', 'multicore_cpu', (50, 0.0017086029052734374, 1.0, 1.087278))
# 6 on (multicore_cpu): [(10, 0.0011715888977050781, 10.0, 1.115431), (50, 0.0017086029052734374, 1.0, 1.087278)]
#
# ('', 'multicore_cpu', (4040, 0.017256498336791992, 0.10000000000000001, 0.100281))
# 6 on (multicore_cpu): [(10, 0.0011715888977050781, 10.0, 1.115431), (50, 0.0017086029052734374, 1.0, 1.087278), (4040, 0.017256498336791992, 0.10000000000000001, 0.100281)]
#
# 6 on (multicore_cpu): [(10, 0.0011715888977050781, 10.0, 1.115431), (50, 0.0017086029052734374, 1.0, 1.087278), (4040, 0.017256498336791992, 0.10000000000000001, 0.100281)]
#
# 6 on (multicore_cpu): [(10, 0.0011715888977050781, 10.0, 1.115431), (50, 0.0017086029052734374, 1.0, 1.087278), (4040, 0.017256498336791992, 0.10000000000000001, 0.100281)]
#
# ('', 'multicore_cpu', (10, 0.0010075092315673829, 10.0, 2.446208))
# 7 on (multicore_cpu): [(10, 0.0010075092315673829, 10.0, 2.446208)]
#
# ('amazon-cpu-1', 'multicore_cpu', (54250, 0.4666033983230591, 0.10000000000000001, 0.103637))
# 38 on amazon-cpu-1(multicore_cpu): [(54250, 0.4666033983230591, 0.10000000000000001, 0.103637)]
#
# 38 on amazon-cpu-1(multicore_cpu): [(54250, 0.4666033983230591, 0.10000000000000001, 0.103637)]
#
# 38 on amazon-cpu-1(multicore_cpu): [(54250, 0.4666033983230591, 0.10000000000000001, 0.103637)]
#
# ('', 'multicore_cpu', (190, 0.0023728132247924803, 1.0, 0.927299))
# 7 on (multicore_cpu): [(10, 0.0010075092315673829, 10.0, 2.446208), (190, 0.0023728132247924803, 1.0, 0.927299)]
#
# ('', 'multicore_cpu', (18750, 0.07777299880981445, 0.10000000000000001, 0.095948))
# 7 on (multicore_cpu): [(10, 0.0010075092315673829, 10.0, 2.446208), (190, 0.0023728132247924803, 1.0, 0.927299), (18750, 0.07777299880981445, 0.10000000000000001, 0.095948)]
#
# ('ee-mollie', 'maxeler_fpga', (3062000, 0.48761069774627686, 0.01, 0.011541))
# 5 on ee-mollie(maxeler_fpga): [(3062000, 0.48761069774627686, 0.01, 0.011541)]
#
# 5 on ee-mollie(maxeler_fpga): [(3062000, 0.48761069774627686, 0.01, 0.011541)]
#
# ('amazon-gpu-0', 'multicore_cpu', (84070, 0.5274075031280517, 0.01, 0.017893))
# 32 on amazon-gpu-0(multicore_cpu): [(84070, 0.5274075031280517, 0.01, 0.017893)]
#
# 32 on amazon-gpu-0(multicore_cpu): [(84070, 0.5274075031280517, 0.01, 0.017893)]
#
# ('amazon-cpu-1', 'multicore_cpu', (50270, 0.4288753032684326, 0.10000000000000001, 0.107882))
# 63 on amazon-cpu-1(multicore_cpu): [(50270, 0.4288753032684326, 0.10000000000000001, 0.107882)]
#
# 63 on amazon-cpu-1(multicore_cpu): [(50270, 0.4288753032684326, 0.10000000000000001, 0.107882)]
#
# 63 on amazon-cpu-1(multicore_cpu): [(50270, 0.4288753032684326, 0.10000000000000001, 0.107882)]
#
# ('amazon-gpu-1', 'multicore_cpu', (89980, 0.5523380994796753, 0.10000000000000001, 0.107798))
# 77 on amazon-gpu-1(multicore_cpu): [(89980, 0.5523380994796753, 0.10000000000000001, 0.107798)]
#
# 77 on amazon-gpu-1(multicore_cpu): [(89980, 0.5523380994796753, 0.10000000000000001, 0.107798)]
#
# 77 on amazon-gpu-1(multicore_cpu): [(89980, 0.5523380994796753, 0.10000000000000001, 0.107798)]
#
# ('amazon-gpu-0', 'multicore_cpu', (32190, 0.49311208724975586, 0.10000000000000001, 0.103321))
# 39 on amazon-gpu-0(multicore_cpu): [(32190, 0.49311208724975586, 0.10000000000000001, 0.103321)]
#
# 39 on amazon-gpu-0(multicore_cpu): [(32190, 0.49311208724975586, 0.10000000000000001, 0.103321)]
#
# 39 on amazon-gpu-0(multicore_cpu): [(32190, 0.49311208724975586, 0.10000000000000001, 0.103321)]
#
# ('amazon-cpu-0', 'multicore_cpu', (952260, 1.5142108917236328, 0.01, 0.0104))
# 18 on amazon-cpu-0(multicore_cpu): [(952260, 1.5142108917236328, 0.01, 0.0104)]
#
# ('amazon-gpu-1', 'opencl_gpu', (43436000, 2.449015808105469, 0.001, 0.00151))
# 34 on amazon-gpu-1(opencl_gpu): [(43436000, 2.449015808105469, 0.001, 0.00151)]
#
# ('ee-mollie', 'maxeler_fpga', (1793000, 0.2927145004272461, 0.01, 0.011114))
# 11 on ee-mollie(maxeler_fpga): [(1793000, 0.2927145004272461, 0.01, 0.011114)]
#
# 11 on ee-mollie(maxeler_fpga): [(1793000, 0.2927145004272461, 0.01, 0.011114)]
#
# ('amazon-gpu-0', 'multicore_cpu', (21900, 0.38542640209198, 0.10000000000000001, 0.113632))
# 57 on amazon-gpu-0(multicore_cpu): [(21900, 0.38542640209198, 0.10000000000000001, 0.113632)]
#
# 57 on amazon-gpu-0(multicore_cpu): [(21900, 0.38542640209198, 0.10000000000000001, 0.113632)]
#
# 57 on amazon-gpu-0(multicore_cpu): [(21900, 0.38542640209198, 0.10000000000000001, 0.113632)]
#
# ('amazon-gpu-0', 'multicore_cpu', (6390, 0.20581350326538086, 0.10000000000000001, 0.109721))
# 60 on amazon-gpu-0(multicore_cpu): [(6390, 0.20581350326538086, 0.10000000000000001, 0.109721)]
#
# 60 on amazon-gpu-0(multicore_cpu): [(6390, 0.20581350326538086, 0.10000000000000001, 0.109721)]
#
# 60 on amazon-gpu-0(multicore_cpu): [(6390, 0.20581350326538086, 0.10000000000000001, 0.109721)]
#
# ('ee-mollie', 'maxeler_fpga', (112000, 0.06845929622650146, 0.10000000000000001, 0.119755))
# 12 on ee-mollie(maxeler_fpga): [(112000, 0.06845929622650146, 0.10000000000000001, 0.119755)]
#
# ('ee-snowball0', 'opencl_gpu', (33571000, 2.3224864959716798, 0.001, 0.001066))
# 6 on ee-snowball0(opencl_gpu): [(33571000, 2.3224864959716798, 0.001, 0.001066)]
#
# ('amazon-cpu-1', 'multicore_cpu', (344050, 1.3147091150283814, 0.01, 0.010965))
# 78 on amazon-cpu-1(multicore_cpu): [(344050, 1.3147091150283814, 0.01, 0.010965)]
#
# 78 on amazon-cpu-1(multicore_cpu): [(344050, 1.3147091150283814, 0.01, 0.010965)]
#
# ('amazon-gpu-0', 'multicore_cpu', (27630, 0.4479417085647583, 0.10000000000000001, 0.137615))
# 68 on amazon-gpu-0(multicore_cpu): [(27630, 0.4479417085647583, 0.10000000000000001, 0.137615)]
#
# ('phi', 'opencl_gpu', (8050000, 3.9911171913146974, 0.01, 0.010124))
# 45 on phi(opencl_gpu): [(8050000, 3.9911171913146974, 0.01, 0.010124)]
#
# ('ee-benjamin', 'multicore_cpu', (5031110, 4.66898090839386, 0.01, 0.012142))
# 31 on ee-benjamin(multicore_cpu): [(5031110, 4.66898090839386, 0.01, 0.012142)]
#
# 31 on ee-benjamin(multicore_cpu): [(5031110, 4.66898090839386, 0.01, 0.012142)]
#
# ('ee-benjamin', 'multicore_cpu', (10, 0.07397251129150391, 10.0, 4.166857))
# 32 on ee-benjamin(multicore_cpu): [(10, 0.07397251129150391, 10.0, 4.166857)]
#
# 32 on ee-benjamin(multicore_cpu): [(10, 0.07397251129150391, 10.0, 4.166857)]
#
# 32 on ee-benjamin(multicore_cpu): [(10, 0.07397251129150391, 10.0, 4.166857)]
#
# 32 on ee-benjamin(multicore_cpu): [(10, 0.07397251129150391, 10.0, 4.166857)]
#
# 32 on ee-benjamin(multicore_cpu): [(10, 0.07397251129150391, 10.0, 4.166857)]
#
# ('ee-benjamin', 'multicore_cpu', (70490, 0.13517701625823975, 0.10000000000000001, 0.126074))
# 33 on ee-benjamin(multicore_cpu): [(70490, 0.13517701625823975, 0.10000000000000001, 0.126074)]
#
# 33 on ee-benjamin(multicore_cpu): [(70490, 0.13517701625823975, 0.10000000000000001, 0.126074)]
#
# 33 on ee-benjamin(multicore_cpu): [(70490, 0.13517701625823975, 0.10000000000000001, 0.126074)]
#
# ('ee-benjamin', 'multicore_cpu', (41940, 0.16785998344421388, 0.10000000000000001, 0.123463))
# 40 on ee-benjamin(multicore_cpu): [(41940, 0.16785998344421388, 0.10000000000000001, 0.123463)]
#
# 40 on ee-benjamin(multicore_cpu): [(41940, 0.16785998344421388, 0.10000000000000001, 0.123463)]
#
# 40 on ee-benjamin(multicore_cpu): [(41940, 0.16785998344421388, 0.10000000000000001, 0.123463)]
#
# ('ee-benjamin', 'multicore_cpu', (5010, 0.08414711952209472, 1.0, 0.773772))
# 44 on ee-benjamin(multicore_cpu): [(5010, 0.08414711952209472, 1.0, 0.773772)]
#
# 44 on ee-benjamin(multicore_cpu): [(5010, 0.08414711952209472, 1.0, 0.773772)]
#
# 44 on ee-benjamin(multicore_cpu): [(5010, 0.08414711952209472, 1.0, 0.773772)]
#
# 44 on ee-benjamin(multicore_cpu): [(5010, 0.08414711952209472, 1.0, 0.773772)]
#
# ('ee-benjamin', 'multicore_cpu', (54890, 0.18887200355529785, 0.10000000000000001, 0.122627))
# 45 on ee-benjamin(multicore_cpu): [(54890, 0.18887200355529785, 0.10000000000000001, 0.122627)]
#
# 45 on ee-benjamin(multicore_cpu): [(54890, 0.18887200355529785, 0.10000000000000001, 0.122627)]
#
# 45 on ee-benjamin(multicore_cpu): [(54890, 0.18887200355529785, 0.10000000000000001, 0.122627)]
#
# ('ee-benjamin', 'multicore_cpu', (37970, 0.15906889438629152, 0.10000000000000001, 0.112661))
# 46 on ee-benjamin(multicore_cpu): [(37970, 0.15906889438629152, 0.10000000000000001, 0.112661)]
#
# 46 on ee-benjamin(multicore_cpu): [(37970, 0.15906889438629152, 0.10000000000000001, 0.112661)]
#
# 46 on ee-benjamin(multicore_cpu): [(37970, 0.15906889438629152, 0.10000000000000001, 0.112661)]
#
# ('ee-benjamin', 'multicore_cpu', (62620, 0.23202168941497803, 0.10000000000000001, 0.119829))
# 49 on ee-benjamin(multicore_cpu): [(62620, 0.23202168941497803, 0.10000000000000001, 0.119829)]
#
# 49 on ee-benjamin(multicore_cpu): [(62620, 0.23202168941497803, 0.10000000000000001, 0.119829)]
#
# 49 on ee-benjamin(multicore_cpu): [(62620, 0.23202168941497803, 0.10000000000000001, 0.119829)]
#
# ('ee-benjamin', 'multicore_cpu', (1980, 0.07978971004486084, 1.0, 1.007044))
# 50 on ee-benjamin(multicore_cpu): [(1980, 0.07978971004486084, 1.0, 1.007044)]
#
# 50 on ee-benjamin(multicore_cpu): [(1980, 0.07978971004486084, 1.0, 1.007044)]
#
# 50 on ee-benjamin(multicore_cpu): [(1980, 0.07978971004486084, 1.0, 1.007044)]
#
# 50 on ee-benjamin(multicore_cpu): [(1980, 0.07978971004486084, 1.0, 1.007044)]
#
# ('ee-benjamin', 'multicore_cpu', (73200, 0.23633937835693358, 0.10000000000000001, 0.129551))
# 59 on ee-benjamin(multicore_cpu): [(73200, 0.23633937835693358, 0.10000000000000001, 0.129551)]
#
# 59 on ee-benjamin(multicore_cpu): [(73200, 0.23633937835693358, 0.10000000000000001, 0.129551)]
#
# 59 on ee-benjamin(multicore_cpu): [(73200, 0.23633937835693358, 0.10000000000000001, 0.129551)]
#
# ('ee-benjamin', 'multicore_cpu', (210, 0.08055610656738281, 10.0, 12.941289))
# 66 on ee-benjamin(multicore_cpu): [(210, 0.08055610656738281, 10.0, 12.941289)]
#
# 66 on ee-benjamin(multicore_cpu): [(210, 0.08055610656738281, 10.0, 12.941289)]
#
# 66 on ee-benjamin(multicore_cpu): [(210, 0.08055610656738281, 10.0, 12.941289)]
#
# 66 on ee-benjamin(multicore_cpu): [(210, 0.08055610656738281, 10.0, 12.941289)]
#
# 66 on ee-benjamin(multicore_cpu): [(210, 0.08055610656738281, 10.0, 12.941289)]
#
# ('ee-mollie', 'maxeler_fpga', (11169000, 1.572711706161499, 0.01, 0.011984))
# 12 on ee-mollie(maxeler_fpga): [(112000, 0.06845929622650146, 0.10000000000000001, 0.119755), (11169000, 1.572711706161499, 0.01, 0.011984)]
#
# ('ee-benjamin', 'multicore_cpu', (10, 0.07800378799438476, 10.0, 13.077193))
# 68 on ee-benjamin(multicore_cpu): [(10, 0.07800378799438476, 10.0, 13.077193)]
#
# 68 on ee-benjamin(multicore_cpu): [(10, 0.07800378799438476, 10.0, 13.077193)]
#
# 68 on ee-benjamin(multicore_cpu): [(10, 0.07800378799438476, 10.0, 13.077193)]
#
# 68 on ee-benjamin(multicore_cpu): [(10, 0.07800378799438476, 10.0, 13.077193)]
#
# 68 on ee-benjamin(multicore_cpu): [(10, 0.07800378799438476, 10.0, 13.077193)]
#
# ('ee-benjamin', 'multicore_cpu', (4070, 0.08594791889190674, 1.0, 1.098762))
# 71 on ee-benjamin(multicore_cpu): [(4070, 0.08594791889190674, 1.0, 1.098762)]
#
# 71 on ee-benjamin(multicore_cpu): [(4070, 0.08594791889190674, 1.0, 1.098762)]
#
# 71 on ee-benjamin(multicore_cpu): [(4070, 0.08594791889190674, 1.0, 1.098762)]
#
# 71 on ee-benjamin(multicore_cpu): [(4070, 0.08594791889190674, 1.0, 1.098762)]
#
# ('ee-benjamin', 'multicore_cpu', (3610, 0.08997800350189208, 1.0, 0.837185))
# 72 on ee-benjamin(multicore_cpu): [(3610, 0.08997800350189208, 1.0, 0.837185)]
#
# 72 on ee-benjamin(multicore_cpu): [(3610, 0.08997800350189208, 1.0, 0.837185)]
#
# 72 on ee-benjamin(multicore_cpu): [(3610, 0.08997800350189208, 1.0, 0.837185)]
#
# 72 on ee-benjamin(multicore_cpu): [(3610, 0.08997800350189208, 1.0, 0.837185)]
#
# ('', 'multicore_cpu', (1874830, 6.985482096672058, 0.01, 0.009619))
# 7 on (multicore_cpu): [(10, 0.0010075092315673829, 10.0, 2.446208), (190, 0.0023728132247924803, 1.0, 0.927299), (18750, 0.07777299880981445, 0.10000000000000001, 0.095948), (1874830, 6.985482096672058, 0.01, 0.009619)]
#
# 7 on (multicore_cpu): [(10, 0.0010075092315673829, 10.0, 2.446208), (190, 0.0023728132247924803, 1.0, 0.927299), (18750, 0.07777299880981445, 0.10000000000000001, 0.095948), (1874830, 6.985482096672058, 0.01, 0.009619)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 8
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0015571117401123047, 10.0, 0.008091))
# 8 on (multicore_cpu): [(110, 0.0015571117401123047, 10.0, 0.008091)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 8
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0028718948364257813, 1.0, 0.040152))
# 8 on (multicore_cpu): [(110, 0.0015571117401123047, 10.0, 0.008091), (110, 0.0028718948364257813, 1.0, 0.040152)]
#
# 8 on (multicore_cpu): [(110, 0.0015571117401123047, 10.0, 0.008091), (110, 0.0028718948364257813, 1.0, 0.040152)]
#
# 8 on (multicore_cpu): [(110, 0.0015571117401123047, 10.0, 0.008091), (110, 0.0028718948364257813, 1.0, 0.040152)]
#
# 8 on (multicore_cpu): [(110, 0.0015571117401123047, 10.0, 0.008091), (110, 0.0028718948364257813, 1.0, 0.040152)]
#
# ('', 'multicore_cpu', (190, 0.002959799766540527, 1.0, 0.962806))
# 9 on (multicore_cpu): [(190, 0.002959799766540527, 1.0, 0.962806)]
#
# ('', 'multicore_cpu', (18070, 0.07353630065917968, 0.10000000000000001, 0.101019))
# 9 on (multicore_cpu): [(190, 0.002959799766540527, 1.0, 0.962806), (18070, 0.07353630065917968, 0.10000000000000001, 0.101019)]
#
# 9 on (multicore_cpu): [(190, 0.002959799766540527, 1.0, 0.962806), (18070, 0.07353630065917968, 0.10000000000000001, 0.101019)]
#
# 9 on (multicore_cpu): [(190, 0.002959799766540527, 1.0, 0.962806), (18070, 0.07353630065917968, 0.10000000000000001, 0.101019)]
#
# ('', 'multicore_cpu', (10, 0.001163482666015625, 10.0, 4.116001))
# 10 on (multicore_cpu): [(10, 0.001163482666015625, 10.0, 4.116001)]
#
# ('', 'multicore_cpu', (190, 0.0018616199493408203, 1.0, 1.108625))
# 10 on (multicore_cpu): [(10, 0.001163482666015625, 10.0, 4.116001), (190, 0.0018616199493408203, 1.0, 1.108625)]
#
# ('', 'multicore_cpu', (18030, 0.07075238227844238, 0.10000000000000001, 0.110789))
# 10 on (multicore_cpu): [(10, 0.001163482666015625, 10.0, 4.116001), (190, 0.0018616199493408203, 1.0, 1.108625), (18030, 0.07075238227844238, 0.10000000000000001, 0.110789)]
#
# ('ee-benjamin', 'multicore_cpu', (1129180, 2.3975101947784423, 0.01, 0.0137))
# 73 on ee-benjamin(multicore_cpu): [(1129180, 2.3975101947784423, 0.01, 0.0137)]
#
# 73 on ee-benjamin(multicore_cpu): [(1129180, 2.3975101947784423, 0.01, 0.0137)]
#
# ('ee-benjamin', 'multicore_cpu', (12420, 0.09908480644226074, 0.10000000000000001, 0.175272))
# 82 on ee-benjamin(multicore_cpu): [(12420, 0.09908480644226074, 0.10000000000000001, 0.175272)]
#
# 82 on ee-benjamin(multicore_cpu): [(12420, 0.09908480644226074, 0.10000000000000001, 0.175272)]
#
# 82 on ee-benjamin(multicore_cpu): [(12420, 0.09908480644226074, 0.10000000000000001, 0.175272)]
#
# ('ee-mollie', 'multicore_cpu', (1806510, 9.550313901901244, 0.01, 0.01012))
# 9 on ee-mollie(multicore_cpu): [(10, 0.03582048416137695, 10.0, 3.848157), (1806510, 9.550313901901244, 0.01, 0.01012)]
#
# 9 on ee-mollie(multicore_cpu): [(10, 0.03582048416137695, 10.0, 3.848157), (1806510, 9.550313901901244, 0.01, 0.01012)]
#
# ('ee-benjamin', 'multicore_cpu', (1410740, 1.8133571147918701, 0.01, 0.033319))
# 84 on ee-benjamin(multicore_cpu): [(1410740, 1.8133571147918701, 0.01, 0.033319)]
#
# 84 on ee-benjamin(multicore_cpu): [(1410740, 1.8133571147918701, 0.01, 0.033319)]
#
# ('ee-benjamin', 'multicore_cpu', (28320, 0.13940031528472902, 0.10000000000000001, 0.124886))
# 85 on ee-benjamin(multicore_cpu): [(28320, 0.13940031528472902, 0.10000000000000001, 0.124886)]
#
# 85 on ee-benjamin(multicore_cpu): [(28320, 0.13940031528472902, 0.10000000000000001, 0.124886)]
#
# 85 on ee-benjamin(multicore_cpu): [(28320, 0.13940031528472902, 0.10000000000000001, 0.124886)]
#
# ('ee-benjamin', 'multicore_cpu', (670280, 1.2622035026550293, 0.01, 0.013525))
# 88 on ee-benjamin(multicore_cpu): [(670280, 1.2622035026550293, 0.01, 0.013525)]
#
# 88 on ee-benjamin(multicore_cpu): [(670280, 1.2622035026550293, 0.01, 0.013525)]
#
# ('ee-benjamin', 'multicore_cpu', (1830, 0.08267638683319092, 1.0, 1.104427))
# 105 on ee-benjamin(multicore_cpu): [(1830, 0.08267638683319092, 1.0, 1.104427)]
#
# 105 on ee-benjamin(multicore_cpu): [(1830, 0.08267638683319092, 1.0, 1.104427)]
#
# 105 on ee-benjamin(multicore_cpu): [(1830, 0.08267638683319092, 1.0, 1.104427)]
#
# 105 on ee-benjamin(multicore_cpu): [(1830, 0.08267638683319092, 1.0, 1.104427)]
#
# ('amazon-gpu-0', 'opencl_gpu', (220327000, 12.418442988395691, 0.001, 0.0017))
# 40 on amazon-gpu-0(opencl_gpu): [(220327000, 12.418442988395691, 0.001, 0.0017)]
#
# ('amazon-gpu-0', 'opencl_gpu', (586000, 0.17561230659484864, 0.10000000000000001, 0.137922))
# 64 on amazon-gpu-0(opencl_gpu): [(586000, 0.17561230659484864, 0.10000000000000001, 0.137922)]
#
# ('amazon-gpu-1', 'opencl_gpu', (185795000, 10.595093297958375, 0.001, 0.001597))
# 36 on amazon-gpu-1(opencl_gpu): [(185795000, 10.595093297958375, 0.001, 0.001597)]
#
# ('amazon-gpu-1', 'opencl_gpu', (9177000, 0.7420073032379151, 0.01, 0.016139))
# 37 on amazon-gpu-1(opencl_gpu): [(9177000, 0.7420073032379151, 0.01, 0.016139)]
#
# ('ee-snowball0', 'opencl_gpu', (165536000, 11.08512020111084, 0.001, 0.001057))
# 9 on ee-snowball0(opencl_gpu): [(165536000, 11.08512020111084, 0.001, 0.001057)]
#
# ('phi', 'multicore_cpu', (7809470, 14.748171186447143, 0.001, 0.001383))
# 3 on phi(multicore_cpu): [(7809470, 14.748171186447143, 0.001, 0.001383)]
#
# ('', 'multicore_cpu', (1802090, 6.8821070194244385, 0.01, 0.010963))
# 10 on (multicore_cpu): [(10, 0.001163482666015625, 10.0, 4.116001), (190, 0.0018616199493408203, 1.0, 1.108625), (18030, 0.07075238227844238, 0.10000000000000001, 0.110789), (1802090, 6.8821070194244385, 0.01, 0.010963)]
#
# 10 on (multicore_cpu): [(10, 0.001163482666015625, 10.0, 4.116001), (190, 0.0018616199493408203, 1.0, 1.108625), (18030, 0.07075238227844238, 0.10000000000000001, 0.110789), (1802090, 6.8821070194244385, 0.01, 0.010963)]
#
# ('', 'multicore_cpu', (10, 0.001258087158203125, 10.0, 3.764447))
# 11 on (multicore_cpu): [(10, 0.001258087158203125, 10.0, 3.764447)]
#
# ('', 'multicore_cpu', (220, 0.0031877994537353516, 1.0, 1.008387))
# 11 on (multicore_cpu): [(10, 0.001258087158203125, 10.0, 3.764447), (220, 0.0031877994537353516, 1.0, 1.008387)]
#
# ('', 'multicore_cpu', (21290, 0.08364160060882568, 0.10000000000000001, 0.102148))
# 11 on (multicore_cpu): [(10, 0.001258087158203125, 10.0, 3.764447), (220, 0.0031877994537353516, 1.0, 1.008387), (21290, 0.08364160060882568, 0.10000000000000001, 0.102148)]
#
# 11 on (multicore_cpu): [(10, 0.001258087158203125, 10.0, 3.764447), (220, 0.0031877994537353516, 1.0, 1.008387), (21290, 0.08364160060882568, 0.10000000000000001, 0.102148)]
#
# 11 on (multicore_cpu): [(10, 0.001258087158203125, 10.0, 3.764447), (220, 0.0031877994537353516, 1.0, 1.008387), (21290, 0.08364160060882568, 0.10000000000000001, 0.102148)]
#
# ('', 'multicore_cpu', (20, 0.0012458086013793946, 10.0, 5.965955))
# 12 on (multicore_cpu): [(20, 0.0012458086013793946, 10.0, 5.965955)]
#
# ('', 'multicore_cpu', (1680, 0.007991600036621093, 1.0, 1.002126))
# 12 on (multicore_cpu): [(20, 0.0012458086013793946, 10.0, 5.965955), (1680, 0.007991600036621093, 1.0, 1.002126)]
#
# 12 on (multicore_cpu): [(20, 0.0012458086013793946, 10.0, 5.965955), (1680, 0.007991600036621093, 1.0, 1.002126)]
#
# 12 on (multicore_cpu): [(20, 0.0012458086013793946, 10.0, 5.965955), (1680, 0.007991600036621093, 1.0, 1.002126)]
#
# 12 on (multicore_cpu): [(20, 0.0012458086013793946, 10.0, 5.965955), (1680, 0.007991600036621093, 1.0, 1.002126)]
#
# ('', 'multicore_cpu', (10, 0.0009487152099609375, 10.0, 3.604856))
# 13 on (multicore_cpu): [(10, 0.0009487152099609375, 10.0, 3.604856)]
#
# ('', 'multicore_cpu', (190, 0.002200198173522949, 1.0, 1.016184))
# 13 on (multicore_cpu): [(10, 0.0009487152099609375, 10.0, 3.604856), (190, 0.002200198173522949, 1.0, 1.016184)]
#
# ('', 'multicore_cpu', (18520, 0.07487568855285645, 0.10000000000000001, 0.1014))
# 13 on (multicore_cpu): [(10, 0.0009487152099609375, 10.0, 3.604856), (190, 0.002200198173522949, 1.0, 1.016184), (18520, 0.07487568855285645, 0.10000000000000001, 0.1014)]
#
# 13 on (multicore_cpu): [(10, 0.0009487152099609375, 10.0, 3.604856), (190, 0.002200198173522949, 1.0, 1.016184), (18520, 0.07487568855285645, 0.10000000000000001, 0.1014)]
#
# 13 on (multicore_cpu): [(10, 0.0009487152099609375, 10.0, 3.604856), (190, 0.002200198173522949, 1.0, 1.016184), (18520, 0.07487568855285645, 0.10000000000000001, 0.1014)]
#
# ('', 'multicore_cpu', (370, 0.002286982536315918, 1.0, 1.080281))
# 14 on (multicore_cpu): [(370, 0.002286982536315918, 1.0, 1.080281)]
#
# ('', 'multicore_cpu', (36150, 0.07323548793792725, 0.10000000000000001, 0.10957))
# 14 on (multicore_cpu): [(370, 0.002286982536315918, 1.0, 1.080281), (36150, 0.07323548793792725, 0.10000000000000001, 0.10957)]
#
# 14 on (multicore_cpu): [(370, 0.002286982536315918, 1.0, 1.080281), (36150, 0.07323548793792725, 0.10000000000000001, 0.10957)]
#
# 14 on (multicore_cpu): [(370, 0.002286982536315918, 1.0, 1.080281), (36150, 0.07323548793792725, 0.10000000000000001, 0.10957)]
#
# ('', 'multicore_cpu', (10, 0.0012246131896972655, 10.0, 4.265821))
# 15 on (multicore_cpu): [(10, 0.0012246131896972655, 10.0, 4.265821)]
#
# ('', 'multicore_cpu', (190, 0.001978302001953125, 1.0, 0.974191))
# 15 on (multicore_cpu): [(10, 0.0012246131896972655, 10.0, 4.265821), (190, 0.001978302001953125, 1.0, 0.974191)]
#
# ('', 'multicore_cpu', (18520, 0.06540391445159913, 0.10000000000000001, 0.099775))
# 15 on (multicore_cpu): [(10, 0.0012246131896972655, 10.0, 4.265821), (190, 0.001978302001953125, 1.0, 0.974191), (18520, 0.06540391445159913, 0.10000000000000001, 0.099775)]
#
# 15 on (multicore_cpu): [(10, 0.0012246131896972655, 10.0, 4.265821), (190, 0.001978302001953125, 1.0, 0.974191), (18520, 0.06540391445159913, 0.10000000000000001, 0.099775)]
#
# 15 on (multicore_cpu): [(10, 0.0012246131896972655, 10.0, 4.265821), (190, 0.001978302001953125, 1.0, 0.974191), (18520, 0.06540391445159913, 0.10000000000000001, 0.099775)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 16
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0015298128128051758, 0.01, 0.074843))
# 16 on (multicore_cpu): [(110, 0.0015298128128051758, 0.01, 0.074843)]
#
# 16 on (multicore_cpu): [(110, 0.0015298128128051758, 0.01, 0.074843)]
#
# ('', 'multicore_cpu', (10, 0.001227998733520508, 10.0, 0.672783))
# 17 on (multicore_cpu): [(10, 0.001227998733520508, 10.0, 0.672783)]
#
# ('', 'multicore_cpu', (180, 0.0022266149520874024, 1.0, 1.062897))
# 17 on (multicore_cpu): [(10, 0.001227998733520508, 10.0, 0.672783), (180, 0.0022266149520874024, 1.0, 1.062897)]
#
# ('', 'multicore_cpu', (17240, 0.0752932071685791, 0.10000000000000001, 0.103597))
# 17 on (multicore_cpu): [(10, 0.001227998733520508, 10.0, 0.672783), (180, 0.0022266149520874024, 1.0, 1.062897), (17240, 0.0752932071685791, 0.10000000000000001, 0.103597)]
#
# ('amazon-gpu-0', 'opencl_gpu', (58579000, 3.4651844024658205, 0.01, 0.01385))
# 64 on amazon-gpu-0(opencl_gpu): [(586000, 0.17561230659484864, 0.10000000000000001, 0.137922), (58579000, 3.4651844024658205, 0.01, 0.01385)]
#
# ('phi', 'multicore_cpu', (1912960, 4.102987790107727, 0.01, 0.010001))
# 13 on phi(multicore_cpu): [(1912960, 4.102987790107727, 0.01, 0.010001)]
#
# 13 on phi(multicore_cpu): [(1912960, 4.102987790107727, 0.01, 0.010001)]
#
# ('phi', 'multicore_cpu', (38000, 0.429283595085144, 0.01, 0.027681))
# 25 on phi(multicore_cpu): [(38000, 0.429283595085144, 0.01, 0.027681)]
#
# 25 on phi(multicore_cpu): [(38000, 0.429283595085144, 0.01, 0.027681)]
#
# ('phi', 'multicore_cpu', (37860, 0.6346515893936158, 0.10000000000000001, 0.157425))
# 61 on phi(multicore_cpu): [(37860, 0.6346515893936158, 0.10000000000000001, 0.157425)]
#
# 61 on phi(multicore_cpu): [(37860, 0.6346515893936158, 0.10000000000000001, 0.157425)]
#
# 61 on phi(multicore_cpu): [(37860, 0.6346515893936158, 0.10000000000000001, 0.157425)]
#
# ('', 'multicore_cpu', (1723600, 6.65713849067688, 0.01, 0.010462))
# 17 on (multicore_cpu): [(10, 0.001227998733520508, 10.0, 0.672783), (180, 0.0022266149520874024, 1.0, 1.062897), (17240, 0.0752932071685791, 0.10000000000000001, 0.103597), (1723600, 6.65713849067688, 0.01, 0.010462)]
#
# 17 on (multicore_cpu): [(10, 0.001227998733520508, 10.0, 0.672783), (180, 0.0022266149520874024, 1.0, 1.062897), (17240, 0.0752932071685791, 0.10000000000000001, 0.103597), (1723600, 6.65713849067688, 0.01, 0.010462)]
#
# ('', 'multicore_cpu', (10, 0.0012099027633666992, 10.0, 2.678444))
# 19 on (multicore_cpu): [(10, 0.0012099027633666992, 10.0, 2.678444)]
#
# ('', 'multicore_cpu', (150, 0.0018581151962280273, 1.0, 0.930233))
# 19 on (multicore_cpu): [(10, 0.0012099027633666992, 10.0, 2.678444), (150, 0.0018581151962280273, 1.0, 0.930233)]
#
# ('', 'multicore_cpu', (14010, 0.05586340427398682, 0.10000000000000001, 0.099512))
# 19 on (multicore_cpu): [(10, 0.0012099027633666992, 10.0, 2.678444), (150, 0.0018581151962280273, 1.0, 0.930233), (14010, 0.05586340427398682, 0.10000000000000001, 0.099512)]
#
# 19 on (multicore_cpu): [(10, 0.0012099027633666992, 10.0, 2.678444), (150, 0.0018581151962280273, 1.0, 0.930233), (14010, 0.05586340427398682, 0.10000000000000001, 0.099512)]
#
# 19 on (multicore_cpu): [(10, 0.0012099027633666992, 10.0, 2.678444), (150, 0.0018581151962280273, 1.0, 0.930233), (14010, 0.05586340427398682, 0.10000000000000001, 0.099512)]
#
# ('', 'multicore_cpu', (10, 0.0012345075607299804, 10.0, 0.133441))
# 20 on (multicore_cpu): [(10, 0.0012345075607299804, 10.0, 0.133441)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 20
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0021754980087280275, 1.0, 0.043295))
# 20 on (multicore_cpu): [(10, 0.0012345075607299804, 10.0, 0.133441), (110, 0.0021754980087280275, 1.0, 0.043295)]
#
# 20 on (multicore_cpu): [(10, 0.0012345075607299804, 10.0, 0.133441), (110, 0.0021754980087280275, 1.0, 0.043295)]
#
# ('', 'multicore_cpu', (1030, 0.006345796585083008, 0.01, 0.010021))
# 20 on (multicore_cpu): [(10, 0.0012345075607299804, 10.0, 0.133441), (110, 0.0021754980087280275, 1.0, 0.043295), (1030, 0.006345796585083008, 0.01, 0.010021)]
#
# 20 on (multicore_cpu): [(10, 0.0012345075607299804, 10.0, 0.133441), (110, 0.0021754980087280275, 1.0, 0.043295), (1030, 0.006345796585083008, 0.01, 0.010021)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 21
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.001776909828186035, 10.0, 0.022667))
# 21 on (multicore_cpu): [(110, 0.001776909828186035, 10.0, 0.022667)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 21
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002562689781188965, 1.0, 0.022667))
# 21 on (multicore_cpu): [(110, 0.001776909828186035, 10.0, 0.022667), (110, 0.002562689781188965, 1.0, 0.022667)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 21
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0024736881256103515, 0.10000000000000001, 0.027633))
# 21 on (multicore_cpu): [(110, 0.001776909828186035, 10.0, 0.022667), (110, 0.002562689781188965, 1.0, 0.022667), (110, 0.0024736881256103515, 0.10000000000000001, 0.027633)]
#
# ('', 'multicore_cpu', (540, 0.004229307174682617, 0.01, 0.010817))
# 21 on (multicore_cpu): [(110, 0.001776909828186035, 10.0, 0.022667), (110, 0.002562689781188965, 1.0, 0.022667), (110, 0.0024736881256103515, 0.10000000000000001, 0.027633), (540, 0.004229307174682617, 0.01, 0.010817)]
#
# 21 on (multicore_cpu): [(110, 0.001776909828186035, 10.0, 0.022667), (110, 0.002562689781188965, 1.0, 0.022667), (110, 0.0024736881256103515, 0.10000000000000001, 0.027633), (540, 0.004229307174682617, 0.01, 0.010817)]
#
# ('', 'multicore_cpu', (10, 0.0009921073913574218, 10.0, 0.281761))
# 22 on (multicore_cpu): [(10, 0.0009921073913574218, 10.0, 0.281761)]
#
# ('', 'multicore_cpu', (10, 0.0011549949645996093, 1.0, 0.172543))
# 22 on (multicore_cpu): [(10, 0.0009921073913574218, 10.0, 0.281761), (10, 0.0011549949645996093, 1.0, 0.172543)]
#
# ('', 'multicore_cpu', (80, 0.002126908302307129, 0.10000000000000001, 0.093184))
# 22 on (multicore_cpu): [(10, 0.0009921073913574218, 10.0, 0.281761), (10, 0.0011549949645996093, 1.0, 0.172543), (80, 0.002126908302307129, 0.10000000000000001, 0.093184)]
#
# ('', 'multicore_cpu', (7050, 0.031542205810546876, 0.01, 0.010432))
# 22 on (multicore_cpu): [(10, 0.0009921073913574218, 10.0, 0.281761), (10, 0.0011549949645996093, 1.0, 0.172543), (80, 0.002126908302307129, 0.10000000000000001, 0.093184), (7050, 0.031542205810546876, 0.01, 0.010432)]
#
# 22 on (multicore_cpu): [(10, 0.0009921073913574218, 10.0, 0.281761), (10, 0.0011549949645996093, 1.0, 0.172543), (80, 0.002126908302307129, 0.10000000000000001, 0.093184), (7050, 0.031542205810546876, 0.01, 0.010432)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 23
# Value: 0.000000
# ('', 'multicore_cpu', (10, 0.0009785890579223633, 10.0, 0.18055))
# 24 on (multicore_cpu): [(10, 0.0009785890579223633, 10.0, 0.18055)]
#
# ('', 'multicore_cpu', (10, 0.0009244918823242187, 1.0, 0.18055))
# 24 on (multicore_cpu): [(10, 0.0009785890579223633, 10.0, 0.18055), (10, 0.0009244918823242187, 1.0, 0.18055)]
#
# ('', 'multicore_cpu', (60, 0.0013897180557250976, 0.10000000000000001, 0.101221))
# 24 on (multicore_cpu): [(10, 0.0009785890579223633, 10.0, 0.18055), (10, 0.0009244918823242187, 1.0, 0.18055), (60, 0.0013897180557250976, 0.10000000000000001, 0.101221)]
#
# ('', 'multicore_cpu', (5910, 0.02748739719390869, 0.01, 0.010257))
# 24 on (multicore_cpu): [(10, 0.0009785890579223633, 10.0, 0.18055), (10, 0.0009244918823242187, 1.0, 0.18055), (60, 0.0013897180557250976, 0.10000000000000001, 0.101221), (5910, 0.02748739719390869, 0.01, 0.010257)]
#
# 24 on (multicore_cpu): [(10, 0.0009785890579223633, 10.0, 0.18055), (10, 0.0009244918823242187, 1.0, 0.18055), (60, 0.0013897180557250976, 0.10000000000000001, 0.101221), (5910, 0.02748739719390869, 0.01, 0.010257)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 25
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002066302299499512, 10.0, 0.4916))
# 25 on (multicore_cpu): [(110, 0.002066302299499512, 10.0, 0.4916)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 25
# Value: 0.000000
# ('', 'multicore_cpu', (140, 0.0021028995513916017, 1.0, 0.481257))
# 25 on (multicore_cpu): [(110, 0.002066302299499512, 10.0, 0.4916), (140, 0.0021028995513916017, 1.0, 0.481257)]
#
# 25 on (multicore_cpu): [(110, 0.002066302299499512, 10.0, 0.4916), (140, 0.0021028995513916017, 1.0, 0.481257)]
#
# 25 on (multicore_cpu): [(110, 0.002066302299499512, 10.0, 0.4916), (140, 0.0021028995513916017, 1.0, 0.481257)]
#
# 25 on (multicore_cpu): [(110, 0.002066302299499512, 10.0, 0.4916), (140, 0.0021028995513916017, 1.0, 0.481257)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 26
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0019835948944091795, 10.0, 0.703528))
# 26 on (multicore_cpu): [(110, 0.0019835948944091795, 10.0, 0.703528)]
#
# ('', 'multicore_cpu', (60, 0.0013569116592407227, 1.0, 0.879325))
# 26 on (multicore_cpu): [(110, 0.0019835948944091795, 10.0, 0.703528), (60, 0.0013569116592407227, 1.0, 0.879325)]
#
# ('', 'multicore_cpu', (5540, 0.0245074987411499, 0.10000000000000001, 0.090894))
# 26 on (multicore_cpu): [(110, 0.0019835948944091795, 10.0, 0.703528), (60, 0.0013569116592407227, 1.0, 0.879325), (5540, 0.0245074987411499, 0.10000000000000001, 0.090894)]
#
# 26 on (multicore_cpu): [(110, 0.0019835948944091795, 10.0, 0.703528), (60, 0.0013569116592407227, 1.0, 0.879325), (5540, 0.0245074987411499, 0.10000000000000001, 0.090894)]
#
# 26 on (multicore_cpu): [(110, 0.0019835948944091795, 10.0, 0.703528), (60, 0.0013569116592407227, 1.0, 0.879325), (5540, 0.0245074987411499, 0.10000000000000001, 0.090894)]
#
# ('', 'multicore_cpu', (10, 0.0011836051940917968, 10.0, 5.779397))
# 27 on (multicore_cpu): [(10, 0.0011836051940917968, 10.0, 5.779397)]
#
# ('', 'multicore_cpu', (760, 0.004823112487792968, 1.0, 0.983242))
# 27 on (multicore_cpu): [(10, 0.0011836051940917968, 10.0, 5.779397), (760, 0.004823112487792968, 1.0, 0.983242)]
#
# 27 on (multicore_cpu): [(10, 0.0011836051940917968, 10.0, 5.779397), (760, 0.004823112487792968, 1.0, 0.983242)]
#
# 27 on (multicore_cpu): [(10, 0.0011836051940917968, 10.0, 5.779397), (760, 0.004823112487792968, 1.0, 0.983242)]
#
# 27 on (multicore_cpu): [(10, 0.0011836051940917968, 10.0, 5.779397), (760, 0.004823112487792968, 1.0, 0.983242)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 28
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002112603187561035, 10.0, 0.304443))
# 28 on (multicore_cpu): [(110, 0.002112603187561035, 10.0, 0.304443)]
#
# ('', 'multicore_cpu', (20, 0.0013957023620605469, 1.0, 1.112289))
# 28 on (multicore_cpu): [(110, 0.002112603187561035, 10.0, 0.304443), (20, 0.0013957023620605469, 1.0, 1.112289)]
#
# ('', 'multicore_cpu', (1610, 0.008105993270874023, 0.10000000000000001, 0.092407))
# 28 on (multicore_cpu): [(110, 0.002112603187561035, 10.0, 0.304443), (20, 0.0013957023620605469, 1.0, 1.112289), (1610, 0.008105993270874023, 0.10000000000000001, 0.092407)]
#
# 28 on (multicore_cpu): [(110, 0.002112603187561035, 10.0, 0.304443), (20, 0.0013957023620605469, 1.0, 1.112289), (1610, 0.008105993270874023, 0.10000000000000001, 0.092407)]
#
# 28 on (multicore_cpu): [(110, 0.002112603187561035, 10.0, 0.304443), (20, 0.0013957023620605469, 1.0, 1.112289), (1610, 0.008105993270874023, 0.10000000000000001, 0.092407)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002665400505065918, 1.0, 0.557004))
# 29 on (multicore_cpu): [(110, 0.002665400505065918, 1.0, 0.557004)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# 29 on (multicore_cpu): [(110, 0.002665400505065918, 1.0, 0.557004)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 29
# Value: 0.000000
# 29 on (multicore_cpu): [(110, 0.002665400505065918, 1.0, 0.557004)]
#
# 29 on (multicore_cpu): [(110, 0.002665400505065918, 1.0, 0.557004)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 30
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 31
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0019787073135375975, 10.0, 2.447378))
# 31 on (multicore_cpu): [(110, 0.0019787073135375975, 10.0, 2.447378)]
#
# ('', 'multicore_cpu', (650, 0.0046875, 1.0, 1.004244))
# 31 on (multicore_cpu): [(110, 0.0019787073135375975, 10.0, 2.447378), (650, 0.0046875, 1.0, 1.004244)]
#
# ('', 'multicore_cpu', (64780, 0.26598830223083497, 0.10000000000000001, 0.107426))
# 31 on (multicore_cpu): [(110, 0.0019787073135375975, 10.0, 2.447378), (650, 0.0046875, 1.0, 1.004244), (64780, 0.26598830223083497, 0.10000000000000001, 0.107426)]
#
# 31 on (multicore_cpu): [(110, 0.0019787073135375975, 10.0, 2.447378), (650, 0.0046875, 1.0, 1.004244), (64780, 0.26598830223083497, 0.10000000000000001, 0.107426)]
#
# 31 on (multicore_cpu): [(110, 0.0019787073135375975, 10.0, 2.447378), (650, 0.0046875, 1.0, 1.004244), (64780, 0.26598830223083497, 0.10000000000000001, 0.107426)]
#
# ('', 'multicore_cpu', (2480, 0.011443209648132325, 0.10000000000000001, 0.091364))
# 32 on (multicore_cpu): [(2480, 0.011443209648132325, 0.10000000000000001, 0.091364)]
#
# 32 on (multicore_cpu): [(2480, 0.011443209648132325, 0.10000000000000001, 0.091364)]
#
# 32 on (multicore_cpu): [(2480, 0.011443209648132325, 0.10000000000000001, 0.091364)]
#
# ('', 'multicore_cpu', (20, 0.0011430025100708009, 10.0, 3.743913))
# 33 on (multicore_cpu): [(20, 0.0011430025100708009, 10.0, 3.743913)]
#
# ('', 'multicore_cpu', (1060, 0.006072020530700684, 1.0, 1.081108))
# ...
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'amazon-cpu-1', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_4_1_he_1_ba_1', '4096', '1266990620', '2180032017', '16', '0.0744256133752', '100', '0.0856768609859', '0.624422896033', '-0.337658881615', '2.67918234613', '0.166103301092', '1.0', '-0.337658881615', '0.0', '0.941268548113', '4', '0', '102', '4096', '148', '1', '0']
# Return:
# Returncode: 143
# 84 on amazon-cpu-1(multicore_cpu): [(12614480, 34.78499529361725, 0.01, 0.011133)]
#
# ('amazon-cpu-1', 'multicore_cpu', (134280, 1.2119735956192017, 0.10000000000000001, 0.099809))
# 86 on amazon-cpu-1(multicore_cpu): [(134280, 1.2119735956192017, 0.10000000000000001, 0.099809)]
#
# 86 on amazon-cpu-1(multicore_cpu): [(134280, 1.2119735956192017, 0.10000000000000001, 0.099809)]
#
# 86 on amazon-cpu-1(multicore_cpu): [(134280, 1.2119735956192017, 0.10000000000000001, 0.099809)]
#
# ('amazon-cpu-1', 'multicore_cpu', (4420, 0.30754029750823975, 1.0, 1.130286))
# 100 on amazon-cpu-1(multicore_cpu): [(4420, 0.30754029750823975, 1.0, 1.130286)]
#
# 100 on amazon-cpu-1(multicore_cpu): [(4420, 0.30754029750823975, 1.0, 1.130286)]
#
# 100 on amazon-cpu-1(multicore_cpu): [(4420, 0.30754029750823975, 1.0, 1.130286)]
#
# 100 on amazon-cpu-1(multicore_cpu): [(4420, 0.30754029750823975, 1.0, 1.130286)]
#
# ('amazon-cpu-1', 'multicore_cpu', (130, 0.245284104347229, 10.0, 12.900904))
# 111 on amazon-cpu-1(multicore_cpu): [(130, 0.245284104347229, 10.0, 12.900904)]
#
# 111 on amazon-cpu-1(multicore_cpu): [(130, 0.245284104347229, 10.0, 12.900904)]
#
# 111 on amazon-cpu-1(multicore_cpu): [(130, 0.245284104347229, 10.0, 12.900904)]
#
# 111 on amazon-cpu-1(multicore_cpu): [(130, 0.245284104347229, 10.0, 12.900904)]
#
# 111 on amazon-cpu-1(multicore_cpu): [(130, 0.245284104347229, 10.0, 12.900904)]
#
# ('amazon-cpu-1', 'multicore_cpu', (2220, 0.270978307723999, 1.0, 1.02733))
# 115 on amazon-cpu-1(multicore_cpu): [(2220, 0.270978307723999, 1.0, 1.02733)]
#
# 115 on amazon-cpu-1(multicore_cpu): [(2220, 0.270978307723999, 1.0, 1.02733)]
#
# 115 on amazon-cpu-1(multicore_cpu): [(2220, 0.270978307723999, 1.0, 1.02733)]
#
# 115 on amazon-cpu-1(multicore_cpu): [(2220, 0.270978307723999, 1.0, 1.02733)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_he_1_ba_1', '4096', '1319306840', '2045505822', '16', '0.056519979988', '100', '0.0866310046241', '0.588040987171', '-0.0192916902888', '1.65795950318', '0.171438267862', '1.0', '-0.0192916902888', '0.0', '0.999813898026', '2', '0', '103', '4096', '121', '1', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_he_1_ba_1', '4096', '1319306850', '601383410', '16', '0.056519979988', '100', '0.0866310046241', '0.588040987171', '-0.0192916902888', '1.65795950318', '0.171438267862', '1.0', '-0.0192916902888', '0.0', '0.999813898026', '2', '0', '103', '4096', '121', '1', '0']
# Return:
# Returncode: 143
# ('amazon-cpu-0', 'multicore_cpu', (3140, 0.18641209602355957, 1.0, 0.999586))
# 87 on amazon-cpu-0(multicore_cpu): [(3140, 0.18641209602355957, 1.0, 0.999586)]
#
# 87 on amazon-cpu-0(multicore_cpu): [(3140, 0.18641209602355957, 1.0, 0.999586)]
#
# 87 on amazon-cpu-0(multicore_cpu): [(3140, 0.18641209602355957, 1.0, 0.999586)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_he_1_ba_1', '4096', '129244900', '1656217954', '16', '0.0271054363122', '100', '0.0589489994063', '0.55927613342', '-0.387842309715', '2.58585464221', '0.260828710661', '1.0', '-0.387842309715', '0.0', '0.921725741636', '3', '0', '107', '4096', '125', '1', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_he_1_ba_1', '4096', '129244910', '532034218', '16', '0.0271054363122', '100', '0.0589489994063', '0.55927613342', '-0.387842309715', '2.58585464221', '0.260828710661', '1.0', '-0.387842309715', '0.0', '0.921725741636', '3', '0', '107', '4096', '125', '1', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_he_1_ba_1', '4096', '129244920', '2217909398', '16', '0.0271054363122', '100', '0.0589489994063', '0.55927613342', '-0.387842309715', '2.58585464221', '0.260828710661', '1.0', '-0.387842309715', '0.0', '0.921725741636', '3', '0', '107', '4096', '125', '1', '0']
# Return:
# Returncode: 143
# 87 on amazon-cpu-0(multicore_cpu): [(3140, 0.18641209602355957, 1.0, 0.999586)]
#
# ('amazon-cpu-0', 'multicore_cpu', (637340, 17.7697625875473, 0.001, 0.001032))
# 91 on amazon-cpu-0(multicore_cpu): [(637340, 17.7697625875473, 0.001, 0.001032)]
#
# ('amazon-cpu-0', 'multicore_cpu', (20, 0.15152959823608397, 10.0, 3.930707))
# 98 on amazon-cpu-0(multicore_cpu): [(20, 0.15152959823608397, 10.0, 3.930707)]
#
# 98 on amazon-cpu-0(multicore_cpu): [(20, 0.15152959823608397, 10.0, 3.930707)]
#
# 98 on amazon-cpu-0(multicore_cpu): [(20, 0.15152959823608397, 10.0, 3.930707)]
#
# 98 on amazon-cpu-0(multicore_cpu): [(20, 0.15152959823608397, 10.0, 3.930707)]
#
# 98 on amazon-cpu-0(multicore_cpu): [(20, 0.15152959823608397, 10.0, 3.930707)]
#
# ('amazon-cpu-0', 'multicore_cpu', (70, 0.15663502216339112, 10.0, 11.075392))
# 100 on amazon-cpu-0(multicore_cpu): [(70, 0.15663502216339112, 10.0, 11.075392)]
#
# 100 on amazon-cpu-0(multicore_cpu): [(70, 0.15663502216339112, 10.0, 11.075392)]
#
# 100 on amazon-cpu-0(multicore_cpu): [(70, 0.15663502216339112, 10.0, 11.075392)]
#
# 100 on amazon-cpu-0(multicore_cpu): [(70, 0.15663502216339112, 10.0, 11.075392)]
#
# 100 on amazon-cpu-0(multicore_cpu): [(70, 0.15663502216339112, 10.0, 11.075392)]
#
# ('amazon-cpu-0', 'multicore_cpu', (6040, 0.21797730922698974, 1.0, 1.257192))
# 117 on amazon-cpu-0(multicore_cpu): [(6040, 0.21797730922698974, 1.0, 1.257192)]
#
# 117 on amazon-cpu-0(multicore_cpu): [(6040, 0.21797730922698974, 1.0, 1.257192)]
#
# 117 on amazon-cpu-0(multicore_cpu): [(6040, 0.21797730922698974, 1.0, 1.257192)]
#
# 117 on amazon-cpu-0(multicore_cpu): [(6040, 0.21797730922698974, 1.0, 1.257192)]
#
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '704515300', '1', '1', '4096', '7045153000', '37680411', '1', '1', '0.0619320258014', '100', '0.0389527767108', '0.712176918782', '-0.448010442989', '2.53227971082', '0.235451567111', '1.0', '-0.448010442989', '0.0', '0.894028323362', '4', '1', '116', '4096', '139', '0', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '704515400', '1', '1', '4096', '7045154000', '580401159', '1', '1', '0.0619320258014', '100', '0.0389527767108', '0.712176918782', '-0.448010442989', '2.53227971082', '0.235451567111', '1.0', '-0.448010442989', '0.0', '0.894028323362', '4', '1', '116', '4096', '139', '0', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '704515500', '1', '1', '4096', '7045155000', '334940478', '1', '1', '0.0619320258014', '100', '0.0389527767108', '0.712176918782', '-0.448010442989', '2.53227971082', '0.235451567111', '1.0', '-0.448010442989', '0.0', '0.894028323362', '4', '1', '116', '4096', '139', '0', '0']
# Return:
# Returncode: 143
# 66 on ee-snowball2(opencl_alterafpga): [(12000, 0.16949141025543213, 1.0, 1.499662), (115464000, 16.530100798606874, 0.01, 0.015825)]
#
# ('ee-snowball2', 'opencl_alterafpga', (876000, 0.29610309600830076, 0.10000000000000001, 0.153319))
# 69 on ee-snowball2(opencl_alterafpga): [(876000, 0.29610309600830076, 0.10000000000000001, 0.153319)]
#
# ('ee-snowball2', 'opencl_alterafpga', (87551000, 12.554592490196228, 0.01, 0.015428))
# 69 on ee-snowball2(opencl_alterafpga): [(876000, 0.29610309600830076, 0.10000000000000001, 0.153319), (87551000, 12.554592490196228, 0.01, 0.015428)]
#
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '875501200', '1', '1', '4096', '8755012000', '1379291218', '1', '1', '0.0467985069198', '100', '0.0412186183598', '0.743781988687', '-0.260062480721', '2.65049207373', '0.221369328045', '1.0', '-0.260062480721', '0.0', '0.965591790624', '3', '1', '93', '4096', '134', '0', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '875501300', '1', '1', '4096', '8755013000', '2533313876', '1', '1', '0.0467985069198', '100', '0.0412186183598', '0.743781988687', '-0.260062480721', '2.65049207373', '0.221369328045', '1.0', '-0.260062480721', '0.0', '0.965591790624', '3', '1', '93', '4096', '134', '0', '0']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_ba_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '875501400', '1', '1', '4096', '8755014000', '2074568046', '1', '1', '0.0467985069198', '100', '0.0412186183598', '0.743781988687', '-0.260062480721', '2.65049207373', '0.221369328045', '1.0', '-0.260062480721', '0.0', '0.965591790624', '3', '1', '93', '4096', '134', '0', '0']
# Return:
# Returncode: 143
# 69 on ee-snowball2(opencl_alterafpga): [(876000, 0.29610309600830076, 0.10000000000000001, 0.153319), (87551000, 12.554592490196228, 0.01, 0.015428)]
#
# ('ee-snowball2', 'opencl_alterafpga', (393000, 0.21609249114990234, 0.10000000000000001, 0.112133))
# 71 on ee-snowball2(opencl_alterafpga): [(393000, 0.21609249114990234, 0.10000000000000001, 0.112133)]
#
# 71 on ee-snowball2(opencl_alterafpga): [(393000, 0.21609249114990234, 0.10000000000000001, 0.112133)]
#
# 71 on ee-snowball2(opencl_alterafpga): [(393000, 0.21609249114990234, 0.10000000000000001, 0.112133)]
#
# ('ee-snowball2', 'opencl_alterafpga', (249000, 0.23665318489074708, 0.10000000000000001, 0.102993))
# 72 on ee-snowball2(opencl_alterafpga): [(249000, 0.23665318489074708, 0.10000000000000001, 0.102993)]
#
# 72 on ee-snowball2(opencl_alterafpga): [(249000, 0.23665318489074708, 0.10000000000000001, 0.102993)]
#
# 72 on ee-snowball2(opencl_alterafpga): [(249000, 0.23665318489074708, 0.10000000000000001, 0.102993)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.20585339069366454, 10.0, 5.673619))
# 75 on ee-snowball2(opencl_alterafpga): [(1000, 0.20585339069366454, 10.0, 5.673619)]
#
# 75 on ee-snowball2(opencl_alterafpga): [(1000, 0.20585339069366454, 10.0, 5.673619)]
#
# 75 on ee-snowball2(opencl_alterafpga): [(1000, 0.20585339069366454, 10.0, 5.673619)]
#
# 75 on ee-snowball2(opencl_alterafpga): [(1000, 0.20585339069366454, 10.0, 5.673619)]
#
# 75 on ee-snowball2(opencl_alterafpga): [(1000, 0.20585339069366454, 10.0, 5.673619)]
#
# ('ee-snowball2', 'opencl_alterafpga', (11620000, 1.7931602001190186, 0.01, 0.010555))
# 86 on ee-snowball2(opencl_alterafpga): [(11620000, 1.7931602001190186, 0.01, 0.010555)]
#
# 86 on ee-snowball2(opencl_alterafpga): [(11620000, 1.7931602001190186, 0.01, 0.010555)]
#
# ('ee-snowball2', 'opencl_alterafpga', (278000, 0.22275390625, 0.10000000000000001, 0.106533))
# 87 on ee-snowball2(opencl_alterafpga): [(278000, 0.22275390625, 0.10000000000000001, 0.106533)]
#
# 87 on ee-snowball2(opencl_alterafpga): [(278000, 0.22275390625, 0.10000000000000001, 0.106533)]
#
# 87 on ee-snowball2(opencl_alterafpga): [(278000, 0.22275390625, 0.10000000000000001, 0.106533)]
#
# ('ee-snowball2', 'opencl_alterafpga', (3000, 0.2014822006225586, 1.0, 0.968666))
# 95 on ee-snowball2(opencl_alterafpga): [(3000, 0.2014822006225586, 1.0, 0.968666)]
#
# ('ee-snowball2', 'opencl_alterafpga', (270000, 0.20166149139404296, 0.10000000000000001, 0.100327))
# 95 on ee-snowball2(opencl_alterafpga): [(3000, 0.2014822006225586, 1.0, 0.968666), (270000, 0.20166149139404296, 0.10000000000000001, 0.100327)]
#
# 95 on ee-snowball2(opencl_alterafpga): [(3000, 0.2014822006225586, 1.0, 0.968666), (270000, 0.20166149139404296, 0.10000000000000001, 0.100327)]
#
# 95 on ee-snowball2(opencl_alterafpga): [(3000, 0.2014822006225586, 1.0, 0.968666), (270000, 0.20166149139404296, 0.10000000000000001, 0.100327)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.15155768394470215, 10.0, 4.671517))
# 103 on ee-snowball2(opencl_alterafpga): [(1000, 0.15155768394470215, 10.0, 4.671517)]
#
# 103 on ee-snowball2(opencl_alterafpga): [(1000, 0.15155768394470215, 10.0, 4.671517)]
#
# 103 on ee-snowball2(opencl_alterafpga): [(1000, 0.15155768394470215, 10.0, 4.671517)]
#
# 103 on ee-snowball2(opencl_alterafpga): [(1000, 0.15155768394470215, 10.0, 4.671517)]
#
# 103 on ee-snowball2(opencl_alterafpga): [(1000, 0.15155768394470215, 10.0, 4.671517)]
#
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_do_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '346358500', '1', '1', '4096', '3463585000', '537200824', '1', '1', '0.0411249501478', '100', '0.0900135852221', '0.833256564739', '-0.235613881362', '1.31109794804', '0.340818451109', '1.0', '-0.235613881362', '0.0', '0.971846746617', '3', '1', '97', '4096', '81', '0', '1.0', '114']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_do_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '346358600', '1', '1', '4096', '3463586000', '666277386', '1', '1', '0.0411249501478', '100', '0.0900135852221', '0.833256564739', '-0.235613881362', '1.31109794804', '0.340818451109', '1.0', '-0.235613881362', '0.0', '0.971846746617', '3', '1', '97', '4096', '81', '0', '1.0', '114']
# Return:
# Returncode: 143
# Command Error!
# Command:['ssh', 'ee-snowball2', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_do_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '346358700', '1', '1', '4096', '3463587000', '1382409176', '1', '1', '0.0411249501478', '100', '0.0900135852221', '0.833256564739', '-0.235613881362', '1.31109794804', '0.340818451109', '1.0', '-0.235613881362', '0.0', '0.971846746617', '3', '1', '97', '4096', '81', '0', '1.0', '114']
# Return:
# Returncode: 143

# %%
no_manifest_results = run_manifest(no_manifest[:,:,:],platforms,execution_platforms,option_tasks,accuracy_range[:],queue,output_queue,error_queue,parallel=True)
# Out:
# ('', 'multicore_cpu', (10, 0.0018896818161010741, 10.0, 1.075525))
# 0 on (multicore_cpu): [(10, 0.0018896818161010741, 10.0, 1.075525)]
#
# ('', 'multicore_cpu', (10, 0.0027595996856689454, 1.0, 0.524598))
# 0 on (multicore_cpu): [(10, 0.0018896818161010741, 10.0, 1.075525), (10, 0.0027595996856689454, 1.0, 0.524598)]
#
# ('', 'multicore_cpu', (30, 0.0029209136962890627, 0.10000000000000001, 0.750358))
# 0 on (multicore_cpu): [(10, 0.0018896818161010741, 10.0, 1.075525), (10, 0.0027595996856689454, 1.0, 0.524598), (30, 0.0029209136962890627, 0.10000000000000001, 0.750358)]
#
# ('', 'multicore_cpu', (460, 0.005020308494567871, 0.01, 0.142217))
# 0 on (multicore_cpu): [(10, 0.0018896818161010741, 10.0, 1.075525), (10, 0.0027595996856689454, 1.0, 0.524598), (30, 0.0029209136962890627, 0.10000000000000001, 0.750358), (460, 0.005020308494567871, 0.01, 0.142217)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '2023387183', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '4207432373', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '667505662', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '2034914356', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (1000, 0.1620008945465088, 10.0, 0.130084))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.1620008945465088, 10.0, 0.130084)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.16629328727722167, 10.0, 0.136354))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.16629328727722167, 10.0, 0.136354)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.17851691246032714, 10.0, 1.075525))
# 0 on ee-mollie(multicore_cpu): [(10, 0.17851691246032714, 10.0, 1.075525)]
#
# ('', 'multicore_cpu', (42480, 0.17149679660797118, 0.001, 0.017931))
# 0 on (multicore_cpu): [(10, 0.0018896818161010741, 10.0, 1.075525), (10, 0.0027595996856689454, 1.0, 0.524598), (30, 0.0029209136962890627, 0.10000000000000001, 0.750358), (460, 0.005020308494567871, 0.01, 0.142217), (42480, 0.17149679660797118, 0.001, 0.017931)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0018820047378540039, 10.0, 0.270442))
# 1 on (multicore_cpu): [(110, 0.0018820047378540039, 10.0, 0.270442)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('ee-snowball1', 'opencl_gpu', (1000, 0.18542399406433105, 10.0, 0.125684))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.18542399406433105, 10.0, 0.125684)]
#
# ('', 'multicore_cpu', (110, 0.002251005172729492, 1.0, 0.339765))
# 1 on (multicore_cpu): [(110, 0.0018820047378540039, 10.0, 0.270442), (110, 0.002251005172729492, 1.0, 0.339765)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (120, 0.002184605598449707, 0.10000000000000001, 0.408329))
# 1 on (multicore_cpu): [(110, 0.0018820047378540039, 10.0, 0.270442), (110, 0.002251005172729492, 1.0, 0.339765), (120, 0.002184605598449707, 0.10000000000000001, 0.408329)]
#
# ('', 'multicore_cpu', (240, 0.0028821945190429686, 0.01, 0.158719))
# 1 on (multicore_cpu): [(110, 0.0018820047378540039, 10.0, 0.270442), (110, 0.002251005172729492, 1.0, 0.339765), (120, 0.002184605598449707, 0.10000000000000001, 0.408329), (240, 0.0028821945190429686, 0.01, 0.158719)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.018427181243896484, 1.0, 0.524598))
# 0 on ee-mollie(multicore_cpu): [(10, 0.17851691246032714, 10.0, 1.075525), (10, 0.018427181243896484, 1.0, 0.524598)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '4071356870', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (110, 0.07347660064697266, 10.0, 0.357836))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.07347660064697266, 10.0, 0.357836)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06226470470428467, 1.0, 0.121101))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.1620008945465088, 10.0, 0.130084), (1000, 0.06226470470428467, 1.0, 0.121101)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '2566586890', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (20, 0.04113938808441162, 0.10000000000000001, 1.529325))
# 0 on ee-mollie(multicore_cpu): [(10, 0.17851691246032714, 10.0, 1.075525), (10, 0.018427181243896484, 1.0, 0.524598), (20, 0.04113938808441162, 0.10000000000000001, 1.529325)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '930619681', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (21460, 0.08416249752044677, 0.001, 0.018856))
# 1 on (multicore_cpu): [(110, 0.0018820047378540039, 10.0, 0.270442), (110, 0.002251005172729492, 1.0, 0.339765), (120, 0.002184605598449707, 0.10000000000000001, 0.408329), (240, 0.0028821945190429686, 0.01, 0.158719), (21460, 0.08416249752044677, 0.001, 0.018856)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0019457817077636718, 10.0, 0.426315))
# 2 on (multicore_cpu): [(110, 0.0019457817077636718, 10.0, 0.426315)]
#
# ('', 'multicore_cpu', (10, 0.0014808893203735352, 1.0, 0.909022))
# 2 on (multicore_cpu): [(110, 0.0019457817077636718, 10.0, 0.426315), (10, 0.0014808893203735352, 1.0, 0.909022)]
#
# ('', 'multicore_cpu', (20, 0.0012809038162231445, 0.10000000000000001, 0.252708))
# 2 on (multicore_cpu): [(110, 0.0019457817077636718, 10.0, 0.426315), (10, 0.0014808893203735352, 1.0, 0.909022), (20, 0.0012809038162231445, 0.10000000000000001, 0.252708)]
#
# ('', 'multicore_cpu', (240, 0.002295994758605957, 0.01, 0.227592))
# 2 on (multicore_cpu): [(110, 0.0019457817077636718, 10.0, 0.426315), (10, 0.0014808893203735352, 1.0, 0.909022), (20, 0.0012809038162231445, 0.10000000000000001, 0.252708), (240, 0.002295994758605957, 0.01, 0.227592)]
#
# ('ee-mollie', 'multicore_cpu', (290, 0.06126759052276611, 0.01, 0.12868))
# 0 on ee-mollie(multicore_cpu): [(10, 0.17851691246032714, 10.0, 1.075525), (10, 0.018427181243896484, 1.0, 0.524598), (20, 0.04113938808441162, 0.10000000000000001, 1.529325), (290, 0.06126759052276611, 0.01, 0.12868)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.07487339973449707, 0.10000000000000001, 0.103415))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.1620008945465088, 10.0, 0.130084), (1000, 0.06226470470428467, 1.0, 0.121101), (1000, 0.07487339973449707, 0.10000000000000001, 0.103415)]
#
# ('ee-snowball1', 'opencl_gpu', (1000, 0.11480119228363037, 1.0, 0.098756))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.18542399406433105, 10.0, 0.125684), (1000, 0.11480119228363037, 1.0, 0.098756)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '40', '2180032017', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (110, 0.058913803100585936, 1.0, 0.345208))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.07347660064697266, 10.0, 0.357836), (110, 0.058913803100585936, 1.0, 0.345208)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.16757731437683104, 1.0, 0.096507))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.16629328727722167, 10.0, 0.136354), (1000, 0.16757731437683104, 1.0, 0.096507)]
#
# ('pi', 'multicore_cpu', (110, 0.19614109992980958, 10.0, 0.44504))
# 0 on pi(multicore_cpu): [(110, 0.19614109992980958, 10.0, 0.44504)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '50', '232646468', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('', 'multicore_cpu', (22110, 0.0895317792892456, 0.001, 0.027715))
# 2 on (multicore_cpu): [(110, 0.0019457817077636718, 10.0, 0.426315), (10, 0.0014808893203735352, 1.0, 0.909022), (20, 0.0012809038162231445, 0.10000000000000001, 0.252708), (240, 0.002295994758605957, 0.01, 0.227592), (22110, 0.0895317792892456, 0.001, 0.027715)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0019297122955322266, 10.0, 0.446558))
# 3 on (multicore_cpu): [(110, 0.0019297122955322266, 10.0, 0.446558)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0019211053848266601, 1.0, 0.342985))
# 3 on (multicore_cpu): [(110, 0.0019297122955322266, 10.0, 0.446558), (110, 0.0019211053848266601, 1.0, 0.342985)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002071094512939453, 0.10000000000000001, 0.383386))
# 3 on (multicore_cpu): [(110, 0.0019297122955322266, 10.0, 0.446558), (110, 0.0019211053848266601, 1.0, 0.342985), (110, 0.002071094512939453, 0.10000000000000001, 0.383386)]
#
# ('ee-snowball0', 'opencl_gpu', (8000, 0.08829550743103028, 0.01, 0.043026))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.1620008945465088, 10.0, 0.130084), (1000, 0.06226470470428467, 1.0, 0.121101), (1000, 0.07487339973449707, 0.10000000000000001, 0.103415), (8000, 0.08829550743103028, 0.01, 0.043026)]
#
# ('', 'multicore_cpu', (190, 0.0030669927597045898, 0.01, 0.300583))
# 3 on (multicore_cpu): [(110, 0.0019297122955322266, 10.0, 0.446558), (110, 0.0019211053848266601, 1.0, 0.342985), (110, 0.002071094512939453, 0.10000000000000001, 0.383386), (190, 0.0030669927597045898, 0.01, 0.300583)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '470', '3559544912', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (20, 0.0584414005279541, 0.10000000000000001, 0.611478))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.07347660064697266, 10.0, 0.357836), (110, 0.058913803100585936, 1.0, 0.345208), (20, 0.0584414005279541, 0.10000000000000001, 0.611478)]

# %%
prop_manifest_results = run_manifest(prop_manifest[:,:,:],platforms,execution_platforms,option_tasks,accuracy_range[:],queue,output_queue,error_queue,parallel=True)
# Out:
# ('ee-snowball1', 'opencl_gpu', (1000, 0.11359620094299316, 0.10000000000000001, 0.127585))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.18542399406433105, 10.0, 0.125684), (1000, 0.11480119228363037, 1.0, 0.098756), (1000, 0.11359620094299316, 0.10000000000000001, 0.127585)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '480', '3436245174', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'maxeler_fpga', (1000, 0.026001596450805665, 10.0, 0.090796))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.026001596450805665, 10.0, 0.090796)]
#
# ('ee-benjamin', 'multicore_cpu', (380, 0.06148130893707275, 0.01, 0.198248))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.07347660064697266, 10.0, 0.357836), (110, 0.058913803100585936, 1.0, 0.345208), (20, 0.0584414005279541, 0.10000000000000001, 0.611478), (380, 0.06148130893707275, 0.01, 0.198248)]
#
# Value Error!
# Platform:phi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (17150, 0.07033069133758545, 0.001, 0.02931))
# 3 on (multicore_cpu): [(110, 0.0019297122955322266, 10.0, 0.446558), (110, 0.0019211053848266601, 1.0, 0.342985), (110, 0.002071094512939453, 0.10000000000000001, 0.383386), (190, 0.0030669927597045898, 0.01, 0.300583), (17150, 0.07033069133758545, 0.001, 0.02931)]
#
# ('', 'multicore_cpu', (10, 0.0011748790740966797, 10.0, 0.655731))
# 4 on (multicore_cpu): [(10, 0.0011748790740966797, 10.0, 0.655731)]
#
# ('', 'multicore_cpu', (10, 0.0009164094924926757, 1.0, 0.05651))
# 4 on (multicore_cpu): [(10, 0.0011748790740966797, 10.0, 0.655731), (10, 0.0009164094924926757, 1.0, 0.05651)]
#
# ('', 'multicore_cpu', (20, 0.00112459659576416, 0.10000000000000001, 1.030544))
# 4 on (multicore_cpu): [(10, 0.0011748790740966797, 10.0, 0.655731), (10, 0.0009164094924926757, 1.0, 0.05651), (20, 0.00112459659576416, 0.10000000000000001, 1.030544)]
#
# ('', 'multicore_cpu', (200, 0.002509284019470215, 0.01, 0.254193))
# 4 on (multicore_cpu): [(10, 0.0011748790740966797, 10.0, 0.655731), (10, 0.0009164094924926757, 1.0, 0.05651), (20, 0.00112459659576416, 0.10000000000000001, 1.030544), (200, 0.002509284019470215, 0.01, 0.254193)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '490', '3728501031', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (26190, 0.1738288164138794, 0.001, 0.022467))
# 0 on ee-mollie(multicore_cpu): [(10, 0.17851691246032714, 10.0, 1.075525), (10, 0.018427181243896484, 1.0, 0.524598), (20, 0.04113938808441162, 0.10000000000000001, 1.529325), (290, 0.06126759052276611, 0.01, 0.12868), (26190, 0.1738288164138794, 0.001, 0.022467)]
#
# ('', 'multicore_cpu', (10, 0.004279088973999023, 10.0, 1.075525))
# 0 on (multicore_cpu): [(10, 0.004279088973999023, 10.0, 1.075525)]
#
# ('', 'multicore_cpu', (10, 0.005545401573181152, 1.0, 0.524598))
# 0 on (multicore_cpu): [(10, 0.004279088973999023, 10.0, 1.075525), (10, 0.005545401573181152, 1.0, 0.524598)]
#
# ('', 'multicore_cpu', (30, 0.0044878959655761715, 0.10000000000000001, 0.750358))
# 0 on (multicore_cpu): [(10, 0.004279088973999023, 10.0, 1.075525), (10, 0.005545401573181152, 1.0, 0.524598), (30, 0.0044878959655761715, 0.10000000000000001, 0.750358)]
#
# ('', 'multicore_cpu', (460, 0.009283089637756347, 0.01, 0.142217))
# 0 on (multicore_cpu): [(10, 0.004279088973999023, 10.0, 1.075525), (10, 0.005545401573181152, 1.0, 0.524598), (30, 0.0044878959655761715, 0.10000000000000001, 0.750358), (460, 0.009283089637756347, 0.01, 0.142217)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.045264482498168945, 10.0, 1.075525))
# 0 on ee-mollie(multicore_cpu): [(10, 0.045264482498168945, 10.0, 1.075525)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '2023387183', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06634371280670166, 10.0, 0.130084))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.06634371280670166, 10.0, 0.130084)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.020986294746398924, 1.0, 0.524598))
# 0 on ee-mollie(multicore_cpu): [(10, 0.045264482498168945, 10.0, 1.075525), (10, 0.020986294746398924, 1.0, 0.524598)]
#
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('ee-mollie', 'multicore_cpu', (20, 0.021785688400268555, 0.10000000000000001, 1.529325))
# 0 on ee-mollie(multicore_cpu): [(10, 0.045264482498168945, 10.0, 1.075525), (10, 0.020986294746398924, 1.0, 0.524598), (20, 0.021785688400268555, 0.10000000000000001, 1.529325)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '4207432373', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (290, 0.02431201934814453, 0.01, 0.12868))
# 0 on ee-mollie(multicore_cpu): [(10, 0.045264482498168945, 10.0, 1.075525), (10, 0.020986294746398924, 1.0, 0.524598), (20, 0.021785688400268555, 0.10000000000000001, 1.529325), (290, 0.02431201934814453, 0.01, 0.12868)]
#
# ('ee-benjamin', 'multicore_cpu', (110, 0.05396718978881836, 10.0, 0.357836))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.05396718978881836, 10.0, 0.357836)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '667505662', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball1', 'opencl_gpu', (1000, 0.13756470680236815, 10.0, 0.125684))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.13756470680236815, 10.0, 0.125684)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '2034914356', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.18385860919952393, 10.0, 0.136354))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.18385860919952393, 10.0, 0.136354)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (42480, 0.1737760066986084, 0.001, 0.017931))
# 0 on (multicore_cpu): [(10, 0.004279088973999023, 10.0, 1.075525), (10, 0.005545401573181152, 1.0, 0.524598), (30, 0.0044878959655761715, 0.10000000000000001, 0.750358), (460, 0.009283089637756347, 0.01, 0.142217), (42480, 0.1737760066986084, 0.001, 0.017931)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('ee-snowball0', 'opencl_gpu', (1000, 0.13146400451660156, 1.0, 0.121101))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.06634371280670166, 10.0, 0.130084), (1000, 0.13146400451660156, 1.0, 0.121101)]
#
# ('', 'multicore_cpu', (110, 0.00203249454498291, 10.0, 0.270442))
# 1 on (multicore_cpu): [(110, 0.00203249454498291, 10.0, 0.270442)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0018558025360107422, 1.0, 0.339765))
# 1 on (multicore_cpu): [(110, 0.00203249454498291, 10.0, 0.270442), (110, 0.0018558025360107422, 1.0, 0.339765)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (120, 0.0017358064651489258, 0.10000000000000001, 0.408329))
# 1 on (multicore_cpu): [(110, 0.00203249454498291, 10.0, 0.270442), (110, 0.0018558025360107422, 1.0, 0.339765), (120, 0.0017358064651489258, 0.10000000000000001, 0.408329)]
#
# ('', 'multicore_cpu', (240, 0.0026569128036499023, 0.01, 0.158719))
# 1 on (multicore_cpu): [(110, 0.00203249454498291, 10.0, 0.270442), (110, 0.0018558025360107422, 1.0, 0.339765), (120, 0.0017358064651489258, 0.10000000000000001, 0.408329), (240, 0.0026569128036499023, 0.01, 0.158719)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '4071356870', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('ee-mollie', 'maxeler_fpga', (1000, 0.05698678493499756, 10.0, 0.090796))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.05698678493499756, 10.0, 0.090796)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '2566586890', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball1', 'opencl_gpu', (1000, 0.12083349227905274, 1.0, 0.098756))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.13756470680236815, 10.0, 0.125684), (1000, 0.12083349227905274, 1.0, 0.098756)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06540088653564453, 0.10000000000000001, 0.103415))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.06634371280670166, 10.0, 0.130084), (1000, 0.13146400451660156, 1.0, 0.121101), (1000, 0.06540088653564453, 0.10000000000000001, 0.103415)]
#
# ('ee-mollie', 'multicore_cpu', (26190, 0.1651731014251709, 0.001, 0.022467))
# 0 on ee-mollie(multicore_cpu): [(10, 0.045264482498168945, 10.0, 1.075525), (10, 0.020986294746398924, 1.0, 0.524598), (20, 0.021785688400268555, 0.10000000000000001, 1.529325), (290, 0.02431201934814453, 0.01, 0.12868), (26190, 0.1651731014251709, 0.001, 0.022467)]
#
# ('ee-benjamin', 'multicore_cpu', (110, 0.07728009223937989, 1.0, 0.345208))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.05396718978881836, 10.0, 0.357836), (110, 0.07728009223937989, 1.0, 0.345208)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '930619681', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('', 'multicore_cpu', (21460, 0.08786568641662598, 0.001, 0.018856))
# 1 on (multicore_cpu): [(110, 0.00203249454498291, 10.0, 0.270442), (110, 0.0018558025360107422, 1.0, 0.339765), (120, 0.0017358064651489258, 0.10000000000000001, 0.408329), (240, 0.0026569128036499023, 0.01, 0.158719), (21460, 0.08786568641662598, 0.001, 0.018856)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002090191841125488, 10.0, 0.426315))
# 2 on (multicore_cpu): [(110, 0.002090191841125488, 10.0, 0.426315)]
#
# ('', 'multicore_cpu', (10, 0.0011535167694091796, 1.0, 0.909022))
# 2 on (multicore_cpu): [(110, 0.002090191841125488, 10.0, 0.426315), (10, 0.0011535167694091796, 1.0, 0.909022)]
#
# ('', 'multicore_cpu', (20, 0.0015718936920166016, 0.10000000000000001, 0.252708))
# 2 on (multicore_cpu): [(110, 0.002090191841125488, 10.0, 0.426315), (10, 0.0011535167694091796, 1.0, 0.909022), (20, 0.0015718936920166016, 0.10000000000000001, 0.252708)]
#
# ('', 'multicore_cpu', (240, 0.0030731916427612304, 0.01, 0.227592))
# 2 on (multicore_cpu): [(110, 0.002090191841125488, 10.0, 0.426315), (10, 0.0011535167694091796, 1.0, 0.909022), (20, 0.0015718936920166016, 0.10000000000000001, 0.252708), (240, 0.0030731916427612304, 0.01, 0.227592)]
#
# ('ee-mollie', 'multicore_cpu', (110, 0.020302295684814453, 10.0, 0.270442))
# 1 on ee-mollie(multicore_cpu): [(110, 0.020302295684814453, 10.0, 0.270442)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '40', '2180032017', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (8000, 0.07182469367980956, 0.01, 0.043026))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.06634371280670166, 10.0, 0.130084), (1000, 0.13146400451660156, 1.0, 0.121101), (1000, 0.06540088653564453, 0.10000000000000001, 0.103415), (8000, 0.07182469367980956, 0.01, 0.043026)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# Value Error!
# Platform:phi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.15956170558929444, 1.0, 0.096507))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.18385860919952393, 10.0, 0.136354), (1000, 0.15956170558929444, 1.0, 0.096507)]
#
# ('ee-benjamin', 'multicore_cpu', (20, 0.07122070789337158, 0.10000000000000001, 0.611478))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.05396718978881836, 10.0, 0.357836), (110, 0.07728009223937989, 1.0, 0.345208), (20, 0.07122070789337158, 0.10000000000000001, 0.611478)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '50', '232646468', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('pi', 'multicore_cpu', (110, 0.18994178771972656, 10.0, 0.44504))
# 0 on pi(multicore_cpu): [(110, 0.18994178771972656, 10.0, 0.44504)]
#
# ('ee-mollie', 'multicore_cpu', (110, 0.050380706787109375, 1.0, 0.339765))
# 1 on ee-mollie(multicore_cpu): [(110, 0.020302295684814453, 10.0, 0.270442), (110, 0.050380706787109375, 1.0, 0.339765)]
#
# ('ee-snowball1', 'opencl_gpu', (1000, 0.12805161476135254, 0.10000000000000001, 0.127585))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.13756470680236815, 10.0, 0.125684), (1000, 0.12083349227905274, 1.0, 0.098756), (1000, 0.12805161476135254, 0.10000000000000001, 0.127585)]
#
# ('', 'multicore_cpu', (22110, 0.08785381317138671, 0.001, 0.027715))
# 2 on (multicore_cpu): [(110, 0.002090191841125488, 10.0, 0.426315), (10, 0.0011535167694091796, 1.0, 0.909022), (20, 0.0015718936920166016, 0.10000000000000001, 0.252708), (240, 0.0030731916427612304, 0.01, 0.227592), (22110, 0.08785381317138671, 0.001, 0.027715)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002600884437561035, 10.0, 0.446558))
# 3 on (multicore_cpu): [(110, 0.002600884437561035, 10.0, 0.446558)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.002247786521911621, 1.0, 0.342985))
# 3 on (multicore_cpu): [(110, 0.002600884437561035, 10.0, 0.446558), (110, 0.002247786521911621, 1.0, 0.342985)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('', 'multicore_cpu', (110, 0.0020828962326049803, 0.10000000000000001, 0.383386))
# 3 on (multicore_cpu): [(110, 0.002600884437561035, 10.0, 0.446558), (110, 0.002247786521911621, 1.0, 0.342985), (110, 0.0020828962326049803, 0.10000000000000001, 0.383386)]
#
# ('', 'multicore_cpu', (190, 0.0028992891311645508, 0.01, 0.300583))
# 3 on (multicore_cpu): [(110, 0.002600884437561035, 10.0, 0.446558), (110, 0.002247786521911621, 1.0, 0.342985), (110, 0.0020828962326049803, 0.10000000000000001, 0.383386), (190, 0.0028992891311645508, 0.01, 0.300583)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '470', '3559544912', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (380, 0.05502808094024658, 0.01, 0.198248))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.05396718978881836, 10.0, 0.357836), (110, 0.07728009223937989, 1.0, 0.345208), (20, 0.07122070789337158, 0.10000000000000001, 0.611478), (380, 0.05502808094024658, 0.01, 0.198248)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '480', '3436245174', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('', 'multicore_cpu', (17150, 0.07088570594787598, 0.001, 0.02931))
# 3 on (multicore_cpu): [(110, 0.002600884437561035, 10.0, 0.446558), (110, 0.002247786521911621, 1.0, 0.342985), (110, 0.0020828962326049803, 0.10000000000000001, 0.383386), (190, 0.0028992891311645508, 0.01, 0.300583), (17150, 0.07088570594787598, 0.001, 0.02931)]
#
# ('', 'multicore_cpu', (10, 0.0010595083236694335, 10.0, 0.655731))
# 4 on (multicore_cpu): [(10, 0.0010595083236694335, 10.0, 0.655731)]
#
# ('', 'multicore_cpu', (10, 0.0012151956558227538, 1.0, 0.05651))
# 4 on (multicore_cpu): [(10, 0.0010595083236694335, 10.0, 0.655731), (10, 0.0012151956558227538, 1.0, 0.05651)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.13398430347442628, 0.10000000000000001, 0.120113))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.18385860919952393, 10.0, 0.136354), (1000, 0.15956170558929444, 1.0, 0.096507), (1000, 0.13398430347442628, 0.10000000000000001, 0.120113)]
#
# ('', 'multicore_cpu', (20, 0.0012748003005981444, 0.10000000000000001, 1.030544))
# 4 on (multicore_cpu): [(10, 0.0010595083236694335, 10.0, 0.655731), (10, 0.0012151956558227538, 1.0, 0.05651), (20, 0.0012748003005981444, 0.10000000000000001, 1.030544)]
#
# ('ee-mollie', 'multicore_cpu', (110, 0.05150880813598633, 0.10000000000000001, 0.291858))
# 1 on ee-mollie(multicore_cpu): [(110, 0.020302295684814453, 10.0, 0.270442), (110, 0.050380706787109375, 1.0, 0.339765), (110, 0.05150880813598633, 0.10000000000000001, 0.291858)]
#
# ('', 'multicore_cpu', (200, 0.0028294086456298827, 0.01, 0.254193))
# 4 on (multicore_cpu): [(10, 0.0010595083236694335, 10.0, 0.655731), (10, 0.0012151956558227538, 1.0, 0.05651), (20, 0.0012748003005981444, 0.10000000000000001, 1.030544), (200, 0.0028294086456298827, 0.01, 0.254193)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '490', '3728501031', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (756000, 0.1558100938796997, 0.001, 0.004251))
# 0 on ee-snowball0(opencl_gpu): [(1000, 0.06634371280670166, 10.0, 0.130084), (1000, 0.13146400451660156, 1.0, 0.121101), (1000, 0.06540088653564453, 0.10000000000000001, 0.103415), (8000, 0.07182469367980956, 0.01, 0.043026), (756000, 0.1558100938796997, 0.001, 0.004251)]
#
# ('ee-snowball1', 'opencl_gpu', (3000, 0.11362679004669189, 0.01, 0.061553))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.13756470680236815, 10.0, 0.125684), (1000, 0.12083349227905274, 1.0, 0.098756), (1000, 0.12805161476135254, 0.10000000000000001, 0.127585), (3000, 0.11362679004669189, 0.01, 0.061553)]
#
# ('ee-benjamin', 'multicore_cpu', (34830, 0.09301149845123291, 0.001, 0.019976))
# 0 on ee-benjamin(multicore_cpu): [(110, 0.05396718978881836, 10.0, 0.357836), (110, 0.07728009223937989, 1.0, 0.345208), (20, 0.07122070789337158, 0.10000000000000001, 0.611478), (380, 0.05502808094024658, 0.01, 0.198248), (34830, 0.09301149845123291, 0.001, 0.019976)]
#
# ('ee-mollie', 'multicore_cpu', (150, 0.030113792419433592, 0.01, 0.187863))
# 1 on ee-mollie(multicore_cpu): [(110, 0.020302295684814453, 10.0, 0.270442), (110, 0.050380706787109375, 1.0, 0.339765), (110, 0.05150880813598633, 0.10000000000000001, 0.291858), (150, 0.030113792419433592, 0.01, 0.187863)]
#
# ('ee-mollie', 'maxeler_fpga', (1000, 0.04423589706420898, 1.0, 0.155513))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.05698678493499756, 10.0, 0.090796), (1000, 0.04423589706420898, 1.0, 0.155513)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '42790', '2045505822', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (17820, 0.07256100177764893, 0.001, 0.027727))
# 4 on (multicore_cpu): [(10, 0.0010595083236694335, 10.0, 0.655731), (10, 0.0012151956558227538, 1.0, 0.05651), (20, 0.0012748003005981444, 0.10000000000000001, 1.030544), (200, 0.0028294086456298827, 0.01, 0.254193), (17820, 0.07256100177764893, 0.001, 0.027727)]
#
# ('', 'multicore_cpu', (10, 0.0009524106979370117, 10.0, 5.060177))
# 5 on (multicore_cpu): [(10, 0.0009524106979370117, 10.0, 5.060177)]
#
# ('', 'multicore_cpu', (110, 0.002084684371948242, 1.0, 1.897053))
# 5 on (multicore_cpu): [(10, 0.0009524106979370117, 10.0, 5.060177), (110, 0.002084684371948242, 1.0, 1.897053)]
#
# ('', 'multicore_cpu', (390, 0.0030661106109619142, 0.10000000000000001, 1.020513))
# 5 on (multicore_cpu): [(10, 0.0009524106979370117, 10.0, 5.060177), (110, 0.002084684371948242, 1.0, 1.897053), (390, 0.0030661106109619142, 0.10000000000000001, 1.020513)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '42800', '601383410', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (1000, 0.08621740341186523, 10.0, 0.083066))
# 1 on ee-snowball0(opencl_gpu): [(1000, 0.08621740341186523, 10.0, 0.083066)]
#
# ('ee-benjamin', 'multicore_cpu', (10, 0.0720107078552246, 10.0, 0.89113))
# 1 on ee-benjamin(multicore_cpu): [(10, 0.0720107078552246, 10.0, 0.89113)]
#
# ('', 'multicore_cpu', (7440, 0.03001260757446289, 0.01, 0.235344))
# 5 on (multicore_cpu): [(10, 0.0009524106979370117, 10.0, 5.060177), (110, 0.002084684371948242, 1.0, 1.897053), (390, 0.0030661106109619142, 0.10000000000000001, 1.020513), (7440, 0.03001260757446289, 0.01, 0.235344)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '42810', '2495331683', '16', '0.0191519450379', '100', '0.129670770029', '1', '1', '110', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (13230, 0.0939500093460083, 0.001, 0.023584))
# 1 on ee-mollie(multicore_cpu): [(110, 0.020302295684814453, 10.0, 0.270442), (110, 0.050380706787109375, 1.0, 0.339765), (110, 0.05150880813598633, 0.10000000000000001, 0.291858), (150, 0.030113792419433592, 0.01, 0.187863), (13230, 0.0939500093460083, 0.001, 0.023584)]
#
# ('ee-snowball2', 'opencl_alterafpga', (10000, 0.13599669933319092, 0.01, 0.039096))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.18385860919952393, 10.0, 0.136354), (1000, 0.15956170558929444, 1.0, 0.096507), (1000, 0.13398430347442628, 0.10000000000000001, 0.120113), (10000, 0.13599669933319092, 0.01, 0.039096)]
#
# ('ee-snowball1', 'opencl_gpu', (194000, 0.12498409748077392, 0.001, 0.008507))
# 0 on ee-snowball1(opencl_gpu): [(1000, 0.13756470680236815, 10.0, 0.125684), (1000, 0.12083349227905274, 1.0, 0.098756), (1000, 0.12805161476135254, 0.10000000000000001, 0.127585), (3000, 0.11362679004669189, 0.01, 0.061553), (194000, 0.12498409748077392, 0.001, 0.008507)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '1656217954', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (110, 0.022548389434814454, 10.0, 0.426315))
# 2 on ee-mollie(multicore_cpu): [(110, 0.022548389434814454, 10.0, 0.426315)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.10076861381530762, 1.0, 0.088192))
# 1 on ee-snowball0(opencl_gpu): [(1000, 0.08621740341186523, 10.0, 0.083066), (1000, 0.10076861381530762, 1.0, 0.088192)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '532034218', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (110, 0.05158510208129883, 1.0, 0.216942))
# 1 on ee-benjamin(multicore_cpu): [(10, 0.0720107078552246, 10.0, 0.89113), (110, 0.05158510208129883, 1.0, 0.216942)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.04325559139251709, 1.0, 0.909022))
# 2 on ee-mollie(multicore_cpu): [(110, 0.022548389434814454, 10.0, 0.426315), (10, 0.04325559139251709, 1.0, 0.909022)]
#
# ('phi', 'multicore_cpu', (110, 0.36249029636383057, 10.0, 0.370015))
# 0 on phi(multicore_cpu): [(110, 0.36249029636383057, 10.0, 0.370015)]
#
# ('pi', 'multicore_cpu', (110, 0.19266657829284667, 1.0, 0.310272))
# 0 on pi(multicore_cpu): [(110, 0.18994178771972656, 10.0, 0.44504), (110, 0.19266657829284667, 1.0, 0.310272)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '2217909398', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# ('ee-snowball1', 'opencl_gpu', (1000, 0.11176021099090576, 10.0, 0.100494))
# 1 on ee-snowball1(opencl_gpu): [(1000, 0.11176021099090576, 10.0, 0.100494)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.07911031246185303, 0.10000000000000001, 0.077712))
# 1 on ee-snowball0(opencl_gpu): [(1000, 0.08621740341186523, 10.0, 0.083066), (1000, 0.10076861381530762, 1.0, 0.088192), (1000, 0.07911031246185303, 0.10000000000000001, 0.077712)]
#
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '3352637455', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (110, 0.06728971004486084, 0.10000000000000001, 0.382418))
# 2 on ee-mollie(multicore_cpu): [(110, 0.022548389434814454, 10.0, 0.426315), (10, 0.04325559139251709, 1.0, 0.909022), (110, 0.06728971004486084, 0.10000000000000001, 0.382418)]
#
# ('ee-mollie', 'maxeler_fpga', (1000, 0.031113696098327637, 0.10000000000000001, 0.095146))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.05698678493499756, 10.0, 0.090796), (1000, 0.04423589706420898, 1.0, 0.155513), (1000, 0.031113696098327637, 0.10000000000000001, 0.095146)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '1124513536', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (8000, 0.06359388828277587, 0.01, 0.03306))
# 1 on ee-snowball0(opencl_gpu): [(1000, 0.08621740341186523, 10.0, 0.083066), (1000, 0.10076861381530762, 1.0, 0.088192), (1000, 0.07911031246185303, 0.10000000000000001, 0.077712), (8000, 0.06359388828277587, 0.01, 0.03306)]
#
# ('ee-benjamin', 'multicore_cpu', (120, 0.05777292251586914, 0.10000000000000001, 0.179375))
# 1 on ee-benjamin(multicore_cpu): [(10, 0.0720107078552246, 10.0, 0.89113), (110, 0.05158510208129883, 1.0, 0.216942), (120, 0.05777292251586914, 0.10000000000000001, 0.179375)]
#
# ('ee-snowball2', 'opencl_alterafpga', (873000, 0.20932819843292236, 0.001, 0.003853))
# 0 on ee-snowball2(opencl_alterafpga): [(1000, 0.18385860919952393, 10.0, 0.136354), (1000, 0.15956170558929444, 1.0, 0.096507), (1000, 0.13398430347442628, 0.10000000000000001, 0.120113), (10000, 0.13599669933319092, 0.01, 0.039096), (873000, 0.20932819843292236, 0.001, 0.003853)]
#
# ('ee-mollie', 'multicore_cpu', (150, 0.044025111198425296, 0.01, 0.220152))
# 2 on ee-mollie(multicore_cpu): [(110, 0.022548389434814454, 10.0, 0.426315), (10, 0.04325559139251709, 1.0, 0.909022), (110, 0.06728971004486084, 0.10000000000000001, 0.382418), (150, 0.044025111198425296, 0.01, 0.220152)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '3384608612', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '37680411', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-snowball1', 'opencl_gpu', (1000, 0.1401289939880371, 1.0, 0.083589))
# 1 on ee-snowball1(opencl_gpu): [(1000, 0.11176021099090576, 10.0, 0.100494), (1000, 0.1401289939880371, 1.0, 0.083589)]
#
# ('ee-benjamin', 'multicore_cpu', (340, 0.07732481956481933, 0.01, 0.141462))
# 1 on ee-benjamin(multicore_cpu): [(10, 0.0720107078552246, 10.0, 0.89113), (110, 0.05158510208129883, 1.0, 0.216942), (120, 0.05777292251586914, 0.10000000000000001, 0.179375), (340, 0.07732481956481933, 0.01, 0.141462)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '580401159', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (684000, 0.12073330879211426, 0.001, 0.003406))
# 1 on ee-snowball0(opencl_gpu): [(1000, 0.08621740341186523, 10.0, 0.083066), (1000, 0.10076861381530762, 1.0, 0.088192), (1000, 0.07911031246185303, 0.10000000000000001, 0.077712), (8000, 0.06359388828277587, 0.01, 0.03306), (684000, 0.12073330879211426, 0.001, 0.003406)]
#
# ('ee-mollie', 'multicore_cpu', (13630, 0.11269600391387939, 0.001, 0.035846))
# 2 on ee-mollie(multicore_cpu): [(110, 0.022548389434814454, 10.0, 0.426315), (10, 0.04325559139251709, 1.0, 0.909022), (110, 0.06728971004486084, 0.10000000000000001, 0.382418), (150, 0.044025111198425296, 0.01, 0.220152), (13630, 0.11269600391387939, 0.001, 0.035846)]
#
# ('phi', 'opencl_gpu', (1000, 0.9595580101013184, 10.0, 0.130089))
# 0 on phi(opencl_gpu): [(1000, 0.9595580101013184, 10.0, 0.130089)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '334940478', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.16247899532318116, 10.0, 0.100661))
# 1 on ee-snowball2(opencl_alterafpga): [(1000, 0.16247899532318116, 10.0, 0.100661)]
#
# ('ee-benjamin', 'multicore_cpu', (30830, 0.10029690265655518, 0.001, 0.016215))
# 1 on ee-benjamin(multicore_cpu): [(10, 0.0720107078552246, 10.0, 0.89113), (110, 0.05158510208129883, 1.0, 0.216942), (120, 0.05777292251586914, 0.10000000000000001, 0.179375), (340, 0.07732481956481933, 0.01, 0.141462), (30830, 0.10029690265655518, 0.001, 0.016215)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06005339622497559, 10.0, 0.113429))
# 2 on ee-snowball0(opencl_gpu): [(1000, 0.06005339622497559, 10.0, 0.113429)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '210', '3947079692', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('ee-snowball1', 'opencl_gpu', (1000, 0.13601088523864746, 0.10000000000000001, 0.076532))
# 1 on ee-snowball1(opencl_gpu): [(1000, 0.11176021099090576, 10.0, 0.100494), (1000, 0.1401289939880371, 1.0, 0.083589), (1000, 0.13601088523864746, 0.10000000000000001, 0.076532)]
#
# ('ee-mollie', 'multicore_cpu', (110, 0.027116799354553224, 10.0, 0.295404))
# 3 on ee-mollie(multicore_cpu): [(110, 0.027116799354553224, 10.0, 0.295404)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '220', '60866605', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('pi', 'multicore_cpu', (110, 0.19298770427703857, 0.10000000000000001, 0.44504))
# 0 on pi(multicore_cpu): [(110, 0.18994178771972656, 10.0, 0.44504), (110, 0.19266657829284667, 1.0, 0.310272), (110, 0.19298770427703857, 0.10000000000000001, 0.44504)]
#
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# Value Error!
# Platform:phi
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Value Error!
# Platform:ee-mollie
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06916959285736084, 1.0, 0.14554))
# 2 on ee-snowball0(opencl_gpu): [(1000, 0.06005339622497559, 10.0, 0.113429), (1000, 0.06916959285736084, 1.0, 0.14554)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '230', '1379291218', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (110, 0.03554279804229736, 1.0, 0.364102))
# 3 on ee-mollie(multicore_cpu): [(110, 0.027116799354553224, 10.0, 0.295404), (110, 0.03554279804229736, 1.0, 0.364102)]
#
# ('ee-mollie', 'maxeler_fpga', (3000, 0.025885701179504395, 0.01, 0.080106))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.05698678493499756, 10.0, 0.090796), (1000, 0.04423589706420898, 1.0, 0.155513), (1000, 0.031113696098327637, 0.10000000000000001, 0.095146), (3000, 0.025885701179504395, 0.01, 0.080106)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.021090888977050783, 0.10000000000000001, 0.397702))
# 3 on ee-mollie(multicore_cpu): [(110, 0.027116799354553224, 10.0, 0.295404), (110, 0.03554279804229736, 1.0, 0.364102), (10, 0.021090888977050783, 0.10000000000000001, 0.397702)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '19010', '2533313876', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (110, 0.06945300102233887, 10.0, 0.676023))
# 2 on ee-benjamin(multicore_cpu): [(110, 0.06945300102233887, 10.0, 0.676023)]
#
# ('ee-snowball1', 'opencl_gpu', (2000, 0.12492749691009522, 0.01, 0.058654))
# 1 on ee-snowball1(opencl_gpu): [(1000, 0.11176021099090576, 10.0, 0.100494), (1000, 0.1401289939880371, 1.0, 0.083589), (1000, 0.13601088523864746, 0.10000000000000001, 0.076532), (2000, 0.12492749691009522, 0.01, 0.058654)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.07874228954315185, 0.10000000000000001, 0.121807))
# 2 on ee-snowball0(opencl_gpu): [(1000, 0.06005339622497559, 10.0, 0.113429), (1000, 0.06916959285736084, 1.0, 0.14554), (1000, 0.07874228954315185, 0.10000000000000001, 0.121807)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '19020', '2074568046', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (120, 0.0473236083984375, 0.01, 0.417813))
# 3 on ee-mollie(multicore_cpu): [(110, 0.027116799354553224, 10.0, 0.295404), (110, 0.03554279804229736, 1.0, 0.364102), (10, 0.021090888977050783, 0.10000000000000001, 0.397702), (120, 0.0473236083984375, 0.01, 0.417813)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.18387792110443116, 1.0, 0.107318))
# 1 on ee-snowball2(opencl_alterafpga): [(1000, 0.16247899532318116, 10.0, 0.100661), (1000, 0.18387792110443116, 1.0, 0.107318)]
#
# ('pi', 'multicore_cpu', (10, 0.14240679740905762, 0.01, 0.531131))
# 0 on pi(multicore_cpu): [(110, 0.18994178771972656, 10.0, 0.44504), (110, 0.19266657829284667, 1.0, 0.310272), (110, 0.19298770427703857, 0.10000000000000001, 0.44504), (10, 0.14240679740905762, 0.01, 0.531131)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '19030', '3356107185', '16', '0.0953762582252', '100', '0.126676817819', '4', '0', '97', '4096']
# Return:
# Returncode: 255
# Value Error!
# Platform:ee-benjamin
# Platform Type:multicore_cpu
# Task: 2
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '2268384390', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (10570, 0.08716390132904053, 0.001, 0.03675))
# 3 on ee-mollie(multicore_cpu): [(110, 0.027116799354553224, 10.0, 0.295404), (110, 0.03554279804229736, 1.0, 0.364102), (10, 0.021090888977050783, 0.10000000000000001, 0.397702), (120, 0.0473236083984375, 0.01, 0.417813), (10570, 0.08716390132904053, 0.001, 0.03675)]
#
# ('ee-snowball0', 'opencl_gpu', (17000, 0.10125260353088379, 0.01, 0.032129))
# 2 on ee-snowball0(opencl_gpu): [(1000, 0.06005339622497559, 10.0, 0.113429), (1000, 0.06916959285736084, 1.0, 0.14554), (1000, 0.07874228954315185, 0.10000000000000001, 0.121807), (17000, 0.10125260353088379, 0.01, 0.032129)]
#
# ('ee-snowball1', 'opencl_gpu', (147000, 0.11764509677886963, 0.001, 0.007004))
# 1 on ee-snowball1(opencl_gpu): [(1000, 0.11176021099090576, 10.0, 0.100494), (1000, 0.1401289939880371, 1.0, 0.083589), (1000, 0.13601088523864746, 0.10000000000000001, 0.076532), (2000, 0.12492749691009522, 0.01, 0.058654), (147000, 0.11764509677886963, 0.001, 0.007004)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.020174288749694826, 10.0, 0.655731))
# 4 on ee-mollie(multicore_cpu): [(10, 0.020174288749694826, 10.0, 0.655731)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '2782524519', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-benjamin', 'multicore_cpu', (110, 0.08196940422058105, 1.0, 0.267403))
# 2 on ee-benjamin(multicore_cpu): [(110, 0.06945300102233887, 10.0, 0.676023), (110, 0.08196940422058105, 1.0, 0.267403)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '3556373603', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-snowball2', 'opencl_alterafpga', (1000, 0.16277940273284913, 0.10000000000000001, 0.105378))
# 1 on ee-snowball2(opencl_alterafpga): [(1000, 0.16247899532318116, 10.0, 0.100661), (1000, 0.18387792110443116, 1.0, 0.107318), (1000, 0.16277940273284913, 0.10000000000000001, 0.105378)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.07998762130737305, 1.0, 0.05651))
# 4 on ee-mollie(multicore_cpu): [(10, 0.020174288749694826, 10.0, 0.655731), (10, 0.07998762130737305, 1.0, 0.05651)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '10', '331412547', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-snowball1', 'opencl_gpu', (1000, 0.11227240562438964, 10.0, 0.138746))
# 2 on ee-snowball1(opencl_gpu): [(1000, 0.11227240562438964, 10.0, 0.138746)]
#
# ('ee-benjamin', 'multicore_cpu', (60, 0.08728859424591065, 0.10000000000000001, 0.323429))
# 2 on ee-benjamin(multicore_cpu): [(110, 0.06945300102233887, 10.0, 0.676023), (110, 0.08196940422058105, 1.0, 0.267403), (60, 0.08728859424591065, 0.10000000000000001, 0.323429)]
#
# ('ee-mollie', 'multicore_cpu', (10, 0.04475910663604736, 0.10000000000000001, 0.241011))
# 4 on ee-mollie(multicore_cpu): [(10, 0.020174288749694826, 10.0, 0.655731), (10, 0.07998762130737305, 1.0, 0.05651), (10, 0.04475910663604736, 0.10000000000000001, 0.241011)]
#
# ('pi', 'multicore_cpu', (160, 0.2108538866043091, 0.001, 0.246132))
# 0 on pi(multicore_cpu): [(110, 0.18994178771972656, 10.0, 0.44504), (110, 0.19266657829284667, 1.0, 0.310272), (110, 0.19298770427703857, 0.10000000000000001, 0.44504), (10, 0.14240679740905762, 0.01, 0.531131), (160, 0.2108538866043091, 0.001, 0.246132)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '20', '1479260767', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (120, 0.027832388877868652, 0.01, 0.413728))
# 4 on ee-mollie(multicore_cpu): [(10, 0.020174288749694826, 10.0, 0.655731), (10, 0.07998762130737305, 1.0, 0.05651), (10, 0.04475910663604736, 0.10000000000000001, 0.241011), (120, 0.027832388877868652, 0.01, 0.413728)]
#
# ('ee-benjamin', 'multicore_cpu', (1130, 0.057657718658447266, 0.01, 0.128268))
# 2 on ee-benjamin(multicore_cpu): [(110, 0.06945300102233887, 10.0, 0.676023), (110, 0.08196940422058105, 1.0, 0.267403), (60, 0.08728859424591065, 0.10000000000000001, 0.323429), (1130, 0.057657718658447266, 0.01, 0.128268)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '857076720', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-snowball0', 'opencl_gpu', (1605000, 0.19813809394836426, 0.001, 0.003245))
# 2 on ee-snowball0(opencl_gpu): [(1000, 0.06005339622497559, 10.0, 0.113429), (1000, 0.06916959285736084, 1.0, 0.14554), (1000, 0.07874228954315185, 0.10000000000000001, 0.121807), (17000, 0.10125260353088379, 0.01, 0.032129), (1605000, 0.19813809394836426, 0.001, 0.003245)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '30', '499473686', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-snowball1', 'opencl_gpu', (1000, 0.1298907995223999, 1.0, 0.163469))
# 2 on ee-snowball1(opencl_gpu): [(1000, 0.11227240562438964, 10.0, 0.138746), (1000, 0.1298907995223999, 1.0, 0.163469)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.05885260105133057, 10.0, 0.129031))
# 3 on ee-snowball0(opencl_gpu): [(1000, 0.05885260105133057, 10.0, 0.129031)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '40', '537200824', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-snowball2', 'opencl_alterafpga', (5000, 0.1830821990966797, 0.01, 0.037442))
# 1 on ee-snowball2(opencl_alterafpga): [(1000, 0.16247899532318116, 10.0, 0.100661), (1000, 0.18387792110443116, 1.0, 0.107318), (1000, 0.16277940273284913, 0.10000000000000001, 0.105378), (5000, 0.1830821990966797, 0.01, 0.037442)]
#
# ('ee-mollie', 'multicore_cpu', (10990, 0.1146420955657959, 0.001, 0.035683))
# 4 on ee-mollie(multicore_cpu): [(10, 0.020174288749694826, 10.0, 0.655731), (10, 0.07998762130737305, 1.0, 0.05651), (10, 0.04475910663604736, 0.10000000000000001, 0.241011), (120, 0.027832388877868652, 0.01, 0.413728), (10990, 0.1146420955657959, 0.001, 0.035683)]
#
# ('ee-mollie', 'maxeler_fpga', (279000, 0.06729681491851806, 0.001, 0.006803))
# 0 on ee-mollie(maxeler_fpga): [(1000, 0.05698678493499756, 10.0, 0.090796), (1000, 0.04423589706420898, 1.0, 0.155513), (1000, 0.031113696098327637, 0.10000000000000001, 0.095146), (3000, 0.025885701179504395, 0.01, 0.080106), (279000, 0.06729681491851806, 0.001, 0.006803)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 1
# Value: 0.000000
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '50', '666277386', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('ee-mollie', 'multicore_cpu', (10, 0.022690606117248536, 10.0, 5.060177))
# 5 on ee-mollie(multicore_cpu): [(10, 0.022690606117248536, 10.0, 5.060177)]
#
# ('ee-snowball0', 'opencl_gpu', (1000, 0.06452071666717529, 1.0, 0.12029))
# 3 on ee-snowball0(opencl_gpu): [(1000, 0.05885260105133057, 10.0, 0.129031), (1000, 0.06452071666717529, 1.0, 0.12029)]
#
# ('ee-mollie', 'multicore_cpu', (30, 0.02481870651245117, 1.0, 3.743141))
# 5 on ee-mollie(multicore_cpu): [(10, 0.022690606117248536, 10.0, 5.060177), (30, 0.02481870651245117, 1.0, 3.743141)]
#
# ('ee-benjamin', 'multicore_cpu', (104300, 0.16300220489501954, 0.001, 0.012838))
# 2 on ee-benjamin(multicore_cpu): [(110, 0.06945300102233887, 10.0, 0.676023), (110, 0.08196940422058105, 1.0, 0.267403), (60, 0.08728859424591065, 0.10000000000000001, 0.323429), (1130, 0.057657718658447266, 0.01, 0.128268), (104300, 0.16300220489501954, 0.001, 0.012838)]
#
# Command Error!
# Command:['ssh', 'amazon-cpu-0', 'source', '/etc/profile;', '/home/ubuntu/workspace/ForwardFinancialFramework/Platforms/MulticoreCPU/multicore_c_code/mc_solver_multicore_cpu_ip_172_31_8_17_bl_1_as_1', '4096', '440', '1382409176', '16', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 255
# ('phi', 'multicore_cpu', (110, 0.5461905002593994, 1.0, 0.299224))
# 0 on phi(multicore_cpu): [(110, 0.36249029636383057, 10.0, 0.370015), (110, 0.5461905002593994, 1.0, 0.299224)]

# %% [markdown]
# ### Collating Results

# %%
#verification_results[accuracy_range][task] = [[paths][latency][accuracy]]
def process_results(manifest_result_set,accuracy_range,tasks,platforms):
    verification_accuracy_results = [[[] for t in tasks] for target_accuracy in accuracy_range]
    verification_latency_results = [[[] for p in platforms] for target_accuracy in accuracy_range]
    
    for result in manifest_result_set:
        platform,platform_type,task,results = result
        
        platform_index = platforms.index((platform,platform_type))
        for r in results:
            paths,latency,target_accuracy,accuracy = r
            
            accuracy_index = numpy.argmin(numpy.abs(accuracy_range-target_accuracy))
            verification_accuracy_results[accuracy_index][task] += [(paths,accuracy)]
            
            verification_latency_results[accuracy_index][platform_index] += [latency]
            
            
    return verification_accuracy_results,verification_latency_results

# %%
scip_verification_results = process_results(scip_manifest_results,accuracy_range[:],option_tasks,platforms)

# %%
prop_verification_results = process_results(prop_manifest_results,accuracy_range[:],option_tasks,platforms)

# %%
no_verification_results = process_results(no_manifest_results,accuracy_range[:1],option_tasks,platforms)

# %%
def generate_verification_data(verification_results,accuracy_range,tasks,platforms):
    accuracy_results,latency_results = verification_results
    verification_accuracies = numpy.zeros((len(accuracy_range),len(tasks)))
    verification_latencies = numpy.zeros(((len(accuracy_range),len(platforms))))
    
    #Find the Accuracy for each task
    for i,accuracy_set in enumerate(accuracy_results):
        print("Accuracy Level:",accuracy_range[i])
        for j,task_set in enumerate(accuracy_set):
            if(task_set):
                temp_paths_total = 0
                for acc_tuple in task_set:
                    verification_accuracies[i,j] += (acc_tuple[1]/1.96*acc_tuple[0]**0.5)**2 #summing the variences
                    temp_paths_total += acc_tuple[0] #summing the paths
            
                verification_accuracies[i,j] = 1.96*(verification_accuracies[i,j]/len(task_set)/temp_paths_total)**0.5 #taking the square root of the mean variance
            else:
                print("Task ",j,"missing")
    
    #Finding the Latency for each platform
    for i,latency_set in enumerate(latency_results):
        for j,platform_set in enumerate(latency_set):
            verification_latencies[i,j] = numpy.sum(platform_set)
            
    return verification_latencies,verification_accuracies
            
    #for target_accuracy in accuracy_range:
    #    for i,t in enumerate(tasks):

# %%
def calculate_verfication_stats(verification_latencies,verification_accuracies):
    latency_results = []
    accuracy_results = []
    for vl,va in zip(verification_latencies,verification_accuracies):
        selection = numpy.logical_not(va==0)
        
        accuracy_mean = numpy.mean(va[selection])
        accuracy_std = numpy.std(va[selection])
        accuracy_max = numpy.max(va[selection])
        accuracy_min = numpy.min(va[selection])
        accuracy_results += [(accuracy_min,accuracy_mean,accuracy_std,accuracy_max)]
        
        selection = numpy.logical_not(vl==0)
        latency_mean = numpy.mean(vl[selection])
        latency_std = numpy.std(vl[selection])
        latency_max = numpy.max(vl[selection])
        latency_min = numpy.min(vl[selection])
        latency_results += [(latency_min,latency_mean,latency_std,latency_max)]
        
    return numpy.array(latency_results),numpy.array(accuracy_results)

# %%
scip_verification_latencies,scip_verification_accuracies = generate_verification_data(scip_verification_results,accuracy_range[:],option_tasks,platforms)
scip_latency_results,scip_accuracy_results = calculate_verfication_stats(scip_verification_latencies,scip_verification_accuracies)
# Out:
# ('Accuracy Level:', 10.0)
# ('Task ', 23, 'missing')
# ('Task ', 29, 'missing')
# ('Task ', 30, 'missing')
# ('Accuracy Level:', 1.0)
# ('Task ', 23, 'missing')
# ('Task ', 30, 'missing')
# ('Accuracy Level:', 0.10000000000000001)
# ('Task ', 8, 'missing')
# ('Task ', 16, 'missing')
# ('Task ', 23, 'missing')
# ('Task ', 29, 'missing')
# ('Task ', 30, 'missing')
# ('Accuracy Level:', 0.01)
# ('Task ', 23, 'missing')
# ('Task ', 29, 'missing')
# ('Task ', 30, 'missing')
# ('Accuracy Level:', 0.001)
# ('Task ', 23, 'missing')
# ('Task ', 29, 'missing')
# ('Task ', 30, 'missing')
# ('Task ', 58, 'missing')
# ('Task ', 66, 'missing')
# ('Task ', 69, 'missing')
# ('Task ', 71, 'missing')
# ('Task ', 72, 'missing')
# ('Task ', 75, 'missing')
# ('Task ', 94, 'missing')
# ('Task ', 99, 'missing')
# ('Task ', 100, 'missing')
# ('Task ', 101, 'missing')
# ('Task ', 102, 'missing')
# ('Task ', 103, 'missing')
# ('Task ', 104, 'missing')
# ('Task ', 105, 'missing')
# ('Task ', 110, 'missing')
# ('Task ', 111, 'missing')
# ('Task ', 113, 'missing')
# ('Task ', 117, 'missing')
# ('Task ', 119, 'missing')
# ('Task ', 120, 'missing')
# ('Task ', 121, 'missing')
# ('Task ', 123, 'missing')
# ('Task ', 124, 'missing')
# ('Task ', 127, 'missing')

# %%
prop_verification_latencies,prop_verification_accuracies = generate_verification_data(prop_verification_results,accuracy_range[:],option_tasks,platforms)
calculate_verfication_stats(prop_verification_latencies,prop_verification_accuracies)
# Out:
# (0.0015242047106606119, 2.7874743863209499, 9.7313369367369074)
# (0.0, 0.85274031758308411, 1.7820536613464355)
# (0.00053315851301465695, 0.65330714288994574, 1.2152033085556093)
# (0.0, 0.90323990285396594, 1.1209755897521974)
# (0.0059459999999999999, 0.11619292354502989, 0.219888)
# (0.0, 1.3748503327369688, 1.6253758907318114)

# %%
no_verification_latencies,no_verification_accuracies = generate_verification_data(no_verification_results,accuracy_range[:],option_tasks,platforms)
calculate_verfication_stats(no_verification_latencies,no_verification_accuracies)
# Out:
# ('Task ', 30, 'missing')
# (0.00091075353416827346, 0.47861590177769692, 2.3530305477751821)
# (0.23795642852783203, 22.722773286700246, 104.83621697425841)

# %% [markdown]
# ### Checking Results

# %%
plt.plot(accuracy_range[:],scip_cost[:],"--o",label="SCIP Model")
plt.plot(accuracy_range[:],prop_cost[:],"--o",label="Proportional Model")
plt.plot(accuracy_range[:],num_opt_cost[:],"--o",label="Numerical Optimiser Model")

#plt.plot(scip_accuracy_results[1:-1,0],scip_latency_results[1:-1,0],"--",label="SCIP Verification Min")
plt.plot(scip_accuracy_results[1:-1,1]-scip_accuracy_results[1:-1,2],scip_latency_results[1:-1,1]-scip_latency_results[1:-1,2],"-x",label="SCIP Lower Std Dev")
plt.plot(scip_accuracy_results[1:-1,1],scip_latency_results[1:-1,1],"-x",label="SCIP Verification Mean")
plt.plot(scip_accuracy_results[1:-1,1]+scip_accuracy_results[1:-1,2],scip_latency_results[1:-1,1]+scip_latency_results[1:-1,2],"-x",label="SCIP Upper Std Dev")
#plt.plot(scip_accuracy_results[1:-1,3],scip_latency_results[1:-1,3],"--",label="SCIP Verification Max")

ax = plt.gca()
ax.set_xscale('log')
ax.set_yscale('log')

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.legend()
