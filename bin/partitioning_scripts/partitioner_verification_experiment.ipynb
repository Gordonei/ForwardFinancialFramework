# %% [markdown]
# # Partitioner Data Generation

# %% [markdown]
# Aim:
# * Use the predictive models to produce latency projections for a reasonable accuracy region (\$10,\$1,\$0.1,\$0.01)
# * Use these latency projections to generate three partitions:
#  * Simple inverse arithmetic (proportional)
#  * Machine learning-based (simulated annealling with Nelder-Mead polishing)
#  * SCIP-based
# * Run these partitions on the set of platforms

# %% [markdown]
# ## Setup

# %% [markdown]
# Importing necessary libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import scipy,scipy.stats
import csv,time

# %% [markdown]
# ## Method

# %% [markdown]
# Model Verification Procedure:
# 1. Create $$Path(Accuracy)$$ and $$Latency(Accuracy)$$ models for each task upon each platform
# 2. Generate Task Partitions for the accuracy range of interest for all tasks using all of the platforms

# %% [markdown]
# ## Generating Models

# %% [markdown]
# ### Reading in Model Coefficients

# %% [markdown]
# Reading model coefficient data

# %%
with open('model_coefficients_seed4_complete13000_2.csv','r') as coefficients_file:
    csvreader = csv.reader(coefficients_file,delimiter=',')
    
    headings = csvreader.next()
    heading_tuples = [(h,"a30") for h in headings if h in ["Platform","Type"]]
    heading_tuples += [(h,"f8") for h in headings if h not in ["Platform","Type"]]
    
    data = []
    for row in csvreader: data.append(tuple(row))
            
    data = numpy.array(data,dtype=heading_tuples)

# %% [markdown]
# Generating the list of platforms

# %%
platforms_set = set(data["Platform"])
platform_types_set = set(data["Type"])

platforms = []
for platform in platforms_set:
    for platform_type in platform_types_set:
        selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
        if(numpy.any(selection)): platforms.append((platform,platform_type))
            
platforms = [(platform,platform_type) for platform,platform_type in platforms] #if not(platform=="phi" and platform_type=="opencl_gpu")

for platform in platforms: print(platform)
# Out:
# ('', 'multicore_cpu')
# ('ee-snowball2', 'opencl_alterafpga')
# ('phi', 'multicore_cpu')
# ('phi', 'opencl_gpu')
# ('ee-snowball0', 'opencl_gpu')
# ('amazon-gpu-0', 'multicore_cpu')
# ('amazon-gpu-0', 'opencl_gpu')
# ('amazon-gpu-1', 'multicore_cpu')
# ('amazon-gpu-1', 'opencl_gpu')
# ('amazon-cpu-0', 'multicore_cpu')
# ('amazon-cpu-1', 'multicore_cpu')
# ('ee-snowball1', 'opencl_gpu')
# ('google-cpu-0', 'multicore_cpu')
# ('ee-benjamin', 'multicore_cpu')
# ('pi', 'multicore_cpu')
# ('ee-mollie', 'maxeler_fpga')

# %% [markdown]
# list of task identifiers:

# %%
tasks = sorted(list(set(data["Task"])))

# %% [markdown]
# ## Reading in Partitions

# %%
with open('partition_output_seed4_complete13000_2.csv','r') as partition_file:
    csvreader = csv.reader(partition_file,delimiter=',')
    
    headings = csvreader.next()
    heading_tuples = [(h,"a30") for h in headings if h in ["Partitioner","Platform","Type"]]
    heading_tuples += [(h,"f8") for h in headings if h not in ["Partitioner","Platform","Type"]]
    
    data2 = []
    for row in csvreader: data2.append(tuple(row))
            
    data2 = numpy.array(data2,dtype=heading_tuples)

# %%
accuracy_range = sorted(list(set(data2["Target Accuracy"])))
accuracy_range.reverse()
accuracy_range = accuracy_range[:]
print(accuracy_range)
# Out:
# [10.0, 5.0, 1.0, 0.5, 0.10000000000000001, 0.050000000000000003, 0.01, 0.0050000000000000001, 0.001, 0.00050000000000000001, 0.0001]

# %%
scip_allocations = numpy.zeros((len(accuracy_range),len(platforms),len(tasks)))
proportional_allocations = numpy.zeros(scip_allocations.shape)
numerical_optimiser_allocations = numpy.zeros(proportional_allocations.shape)

for d in data2:
    partitioner,platform,platform_type,task,target_accuracy,allocation = d
    accuracy_index = numpy.argmin(numpy.abs(target_accuracy-accuracy_range))
    platform_index = platforms.index((platform,platform_type))
    if(partitioner=="SCIP"): scip_allocations[accuracy_index,platform_index,task] = allocation
    elif(partitioner=="Numerical Optimiser"): numerical_optimiser_allocations[accuracy_index,platform_index,task] = allocation
    elif(partitioner=="Proportional"): proportional_allocations[accuracy_index,platform_index,task] = allocation

# %% [markdown]
# ### Model Functions

# %% [markdown]
# #### Paths(Accuracy) Model

# %% [markdown]
# $$ A = \frac{\alpha}{\sqrt{N}} $$
# $$ \therefore N = (\frac{\alpha}{A})^2 $$

# %%
def paths_accuracy(A,accuracy_coefficient):
    return (accuracy_coefficient/A)**2

# %% [markdown]
# #### Latency(Paths) Model

# %% [markdown]
# $L(N) = \beta_{prop}N + \beta_{setup}$

# %%
def latency_paths(N,latency_coefficient,latency_setup):
    return latency_coefficient*N + latency_setup*(N>0)

# %% [markdown]
# #### Latency(Accuracy) Model

# %% [markdown]
# $$L(A) = \beta_{prop}(\frac{\alpha}{A})^2 + \beta_{setup}$$

# %%
def latency_accuracy(A,accuracy_coefficient,latency_coefficient,latency_setup):
    return latency_coefficient*paths_accuracy(A,accuracy_coefficient) + latency_setup

# %% [markdown]
# #### Latency(Accuracy) Coefficient Model

# %% [markdown]
# $$ L_{coeff}(A) = \beta_{prop}(\frac{\alpha}{A})^2 $$

# %%
def latency_accuracy_prop(A,accuracy_coefficient,latency_coefficient):
    return latency_coefficient*paths_accuracy(A,accuracy_coefficient)

# %% [markdown]
# ### Cost Models

# %%
def select_coefficients(data,platform,platform_type,task):
    selection = numpy.logical_and(data["Platform"]==platform,data["Type"]==platform_type)
    selection = numpy.logical_and(selection[:],data["Task"]==task)
    accuracy_coefficient,latency_coefficient,latency_setup = data[selection]["Accuracy Coefficient"],data[selection]["Latency Coefficient"],data[selection]["Latency Setup"]
    
    return accuracy_coefficient,latency_coefficient,latency_setup

# %%
"""
cost_models = []
for platform,platform_type in platforms:
    cost_models += [[]]
    for task in tasks[:]:
        accuracy_coefficient,latency_coefficient,latency_setup = select_coefficients(data,platform,platform_type,task)
        coefficient_model = latency_accuracy_coefficient(accuracy_coefficient,latency_coefficient)
        setup_model = lambda A,latency_setup=latency_setup: latency_setup
        cost_models[-1] += [(coefficient_model,setup_model)]
"""
# Out:
# '\ncost_models = []\nfor platform,platform_type in platforms:\n    cost_models += [[]]\n    for task in tasks[:]:\n        accuracy_coefficient,latency_coefficient,latency_setup = select_coefficients(data,platform,platform_type,task)\n        coefficient_model = latency_accuracy_coefficient(accuracy_coefficient,latency_coefficient)\n        setup_model = lambda A,latency_setup=latency_setup: latency_setup\n        cost_models[-1] += [(coefficient_model,setup_model)]\n'

# %%
cost_matrices = []
for accuracy_target in accuracy_range[:]:
    pp_latencies = []
    setup_latencies = []
    for platform,platform_type in platforms:
        pp_latencies += [[]]
        setup_latencies += [[]]
        for t in range(len(tasks)):
            accuracy_coefficient,latency_coefficient,latency_setup = select_coefficients(data,platform,platform_type,t)
            pp_latencies[-1] += [latency_accuracy_prop(accuracy_target,accuracy_coefficient,latency_coefficient)]
            setup_latencies[-1] += [latency_setup]
            
    pp_latencies = numpy.copy(numpy.array(pp_latencies).reshape(len(platforms),len(tasks))) 
    setup_latencies = numpy.copy(numpy.array(setup_latencies).reshape(len(platforms),len(tasks))) 
    
    cost_matrices += [(setup_latencies,pp_latencies)]

# %% [markdown]
# Function for calculating the value of an allocation, given its cost matrices:

# %%
def allocation_cost(allocation,pp_costs,setup_costs,number_platforms=None,number_tasks=None):
    #print(allocation)
    #print(pp_costs)
    #print(setup_costs)
    #print("PP Cost: ",numpy.any(numpy.logical_not(numpy.isfinite(pp_costs)))))
    #print("Setup Cost: ",numpy.any(numpy.logical_not(numpy.isfinite(setup_costs))))
    #print("Allocation Cost: ",numpy.any(numpy.logical_not(numpy.isfinite(allocation))))
    
    if(number_platforms and number_tasks):
        allocation = allocation.reshape(number_platforms,number_tasks)
        pp_costs = pp_costs.reshape(number_platforms,number_tasks)
        setup_costs = setup_costs.reshape(number_platforms,number_tasks)
    
    selection = numpy.isfinite(pp_costs)
    selection &= numpy.isfinite(setup_costs)
    selection = numpy.logical_not(selection)
    
    if(numpy.any(allocation[selection]>0.0)):
        invalid_values = []
        for p in range(pp_costs.shape[0]):
            for t in range(pp_costs.shape[1]):
                if (not numpy.isfinite(selection[p,t]) and allocation[p,t]>0.0): invalid_values += [(p,t)]
                    
        raise ValueError("Allocating to invalid value(s): %s"%str(invalid_values))
    
    platform_task_costs = numpy.zeros(pp_costs.shape)#pp_costs*allocation+setup_costs*(allocation>0)
    
    #for p in range(pp_costs.shape[0]):
        #for t in range(pp_costs.shape[1]):
            #if(allocation[p,t]):
                #platform_task_costs[p,t] = pp_costs[p,t]*allocation[p,t] + setup_costs[p,t]
                
    platform_task_costs = pp_costs*allocation + setup_costs*(allocation>0)
            
    """
    platform_task_costs = platform_allocation_totals
    selection = numpy.isfinite(platform_allocation_totals)
    
    platform_task_costs = numpy.zeros(pp_costs.shape)
    for p in range(setup_costs.shape[0]):
        for t in range(setup_costs.shape[1]):
            if(selection[p,t]): platform_task_costs[p,t] = platform_allocation_totals[p,t]
    """
    
    cost = numpy.max(numpy.sum(platform_task_costs,axis=1)) #find the longest running platform

    return cost

# %% [markdown]
# Function for plotting partitions for a range of accuracies.

# %%
def platform_task_allocations(allocations,accuracy_range,platforms,tasks,step_size=1):
    plot_number = len(allocations)/step_size
    step_size = step_size
    fig, axes = plt.subplots(plot_number,sharex=True,sharey=True)
    imgs = []

    print(platforms)
    for i,ax in enumerate(axes):
        index = step_size*i
        ax.set_title("$%.4f"%accuracy_range[index])
        imgs += [ax.imshow(numpy.array(allocations[index]),interpolation='nearest',cmap='hot',vmin=0,vmax=1)]
        print("$%.4f: "%accuracy_range[index],numpy.sum(allocations[index]))
        
        print(numpy.mean(allocations[index],axis=1))
        #print("$%.4f: "%accuracy_range[index],allocations[index].T)

    #tasks = allocations[0].shape[1]
    
    axes[-1].set_xticks(range(len(tasks)))
    axes[-1].set_xticklabels([])
    axes[-1].set_yticks(range(len(platforms)))
    axes[-1].set_yticklabels([(platform,platform_types) for platform,platform_types in platforms]) #,rotation=90

    cax,kw = matplotlib.colorbar.make_axes([ax for ax in axes.flat])
    fig.colorbar(imgs[-1], cax=cax, **kw)

    fig.set_size_inches(30,20)

# %% [markdown]
# Function for plotting the mean allocations

# %%
def platform_mean_allocations(allocations,accuracy_range,platforms,tasks,step_size=1):
    plot_number = len(allocations)/step_size
    step_size = step_size
    fig, axes = plt.subplots(plot_number,sharex=True,sharey=True)
    imgs = []

    for i,ax in enumerate(axes):
        index = step_size*i
        ax.set_title("$%.4f"%accuracy_range[index])
        allocation_platform_means = numpy.mean(allocations[index],axis=1).reshape(1,16)
        imgs += [ax.imshow(allocation_platform_means,interpolation='nearest',cmap='hot',vmin=0,vmax=1)]
        print("$%.4f: "%accuracy_range[index],allocation_platform_means)
        #print(numpy.sum(cost_matrices[index][0]+cost_matrices[index][1],axis=1)) #sanity test

    axes[-1].set_yticks([])
    axes[-1].set_xticks(range(len(platforms)))
    axes[-1].set_xticklabels([(platform,platform_types) for platform,platform_types in platforms],rotation=90)

    cax,kw = matplotlib.colorbar.make_axes([ax for ax in axes.flat])
    fig.colorbar(imgs[0], cax=cax, **kw)

    fig.set_size_inches(18.5,10.5)

# %% [markdown]
# ## Comparing Partitions

# %%
scip_cost = []
num_opt_cost = []
prop_cost = []
best_platform_cost = []

#,num_opt
#,numerical_optimiser_allocations
for accuracy_target,(setup_cost_matrix,pp_cost_matrix),scip,prop,num_opt in zip(accuracy_range,cost_matrices,scip_allocations,proportional_allocations,numerical_optimiser_allocations):
    scip_cost += [allocation_cost(scip,pp_cost_matrix,setup_cost_matrix)]
    num_opt_cost += [allocation_cost(num_opt,pp_cost_matrix,setup_cost_matrix)]
    prop_cost += [allocation_cost(prop,pp_cost_matrix,setup_cost_matrix)]
    
    best_platform_index = numpy.argmax(numpy.mean(prop,axis=1))
    best_platform_allocation = numpy.zeros(prop.shape)
    best_platform_allocation[best_platform_index,:] = 1.0
    best_platform_cost += [allocation_cost(best_platform_allocation,pp_cost_matrix,setup_cost_matrix)]
    
scip_cost = numpy.array(scip_cost)
num_opt_cost = numpy.array(num_opt_cost)
prop_cost = numpy.array(prop_cost)
best_platform_cost = numpy.array(best_platform_cost)
    

plt.plot(accuracy_range,prop_cost/scip_cost,"-x",label="SCIP Partitioner")
plt.plot(accuracy_range,prop_cost/num_opt_cost,"-o",label="Numerical Optimiser Partitioner")
plt.plot(accuracy_range,prop_cost/best_platform_cost,"-+",label="Best Platform Partitioner")

plt.legend(loc='best')

ax = plt.gca()

upper_limit = numpy.ceil(max(numpy.max(prop_cost/scip_cost),numpy.max(prop_cost/num_opt_cost))*1.1/100)*100

#ax.set_ylim([1,upper_limit])
ax.set_xscale('log')
ax.set_xlabel("Accuracy Target ($)")

ax.set_yscale('log')
ax.set_ylabel("Latency Improvement over Proportional")

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

# %%
print(prop_cost)
print(num_opt_cost)
print(scip_cost)
print(best_platform_cost)
# Out:
# [   1497.97596419    1497.97596551    1497.97601595    1497.97624624
#     1497.99114719    1498.05746401    1503.54361376    1536.3155863
#     3245.00046975    8737.85156401  184641.29144051]
# [  4.88980819e+00   4.93406702e+00   6.35034937e+00   1.07762317e+01
#    6.04571935e+01   7.30413692e+01   2.37819075e+02   4.52283971e+02
#    3.00297638e+03   7.91871058e+03   1.83360492e+05]
# [  2.76861077e+00   2.78984175e+00   3.19120881e+00   3.57665314e+00
#    5.48264738e+00   7.34344866e+00   2.21750097e+01   5.40647874e+01
#    9.27416730e+02   3.60459646e+03   8.91952380e+04]
# [  4.88980842e+00   4.93406792e+00   6.35037192e+00   1.07763219e+01
#    6.04573078e+01   7.30418264e+01   2.37819939e+02   4.52287428e+02
#    7.31524708e+03   2.85995028e+04   7.08949441e+05]

# %% [markdown]
# ## Executing Partitions

# %% [markdown]
# ### Setup

# %%
import csv

options = []
with open('valid_seeds_file4.csv','r') as valid_seeds_file:
    csvreader = csv.DictReader(valid_seeds_file,delimiter=',')
    options = [row for row in csvreader]

# %%
import ForwardFinancialFramework.bin.option_generator as option_generator

option_tasks = [option_generator.generate_option(int(o['seed']),underlying_type=o['underlying'],option_type=o['option']) for o in options]

# %% [markdown]
# Platform setup:

# %%
from ForwardFinancialFramework.Platforms.MulticoreCPU import MulticoreCPU_MonteCarlo, MulticoreCPU
from ForwardFinancialFramework.Platforms.OpenCLGPU import OpenCLGPU_MonteCarlo,OpenCLGPU
from ForwardFinancialFramework.Platforms.OpenCLAlteraFPGA import OpenCLAlteraFPGA_MonteCarlo,OpenCLAlteraFPGA
from ForwardFinancialFramework.Platforms.MaxelerFPGA import MaxelerFPGA_MonteCarlo,MaxelerFPGA

# %%
execution_platforms = [MulticoreCPU.MulticoreCPU(threads=7)] #0
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="ee-benjamin")] #1
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="pi")] #2
#execution_platforms += [MulticoreCPU.MulticoreCPU(threads=7,remote=True,ssh_alias="ee-mollie")] #3
execution_platforms += [MulticoreCPU.MulticoreCPU(threads=31,remote=True,ssh_alias="phi")] #4
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball0")] #5
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="ee-snowball1")] #6
execution_platforms += [MaxelerFPGA.MaxelerFPGA(remote=True,ssh_alias="ee-mollie")] #7
execution_platforms += [OpenCLAlteraFPGA.OpenCLAlteraFPGA(remote=True,ssh_alias="ee-snowball2")] #8
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="phi")] #9
execution_platforms[-1].device_type=8
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-cpu-0")] #10
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-cpu-1")] #11
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-gpu-0",threads=7)] #12
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="amazon-gpu-1",threads=7)] #13
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="amazon-gpu-0")] #14
execution_platforms += [OpenCLGPU.OpenCLGPU(remote=True,ssh_alias="amazon-gpu-1")] #15
execution_platforms += [MulticoreCPU.MulticoreCPU(remote=True,ssh_alias="google-cpu-0")] #16

# %% [markdown]
# ### Calculating the paths manifests for the different partitions

# %% [markdown]
# Essentially the Hammard product of the allocation and the number of paths required for each task on each platform to achieve the targetted accuracy

# %%
scip_manifest = numpy.zeros((len(platforms),len(accuracy_range),len(tasks)))
scip_manifest_times = numpy.zeros(scip_manifest.shape)

no_manifest = numpy.zeros(scip_manifest.shape)
no_manifest_times = numpy.zeros(scip_manifest.shape)

prop_manifest = numpy.zeros(scip_manifest.shape)
prop_manifest_times = numpy.zeros(scip_manifest.shape)

# %%
for i,accuracy_target,(setup_cost_matrix,pp_cost_matrix) in zip(range(len(accuracy_range)),accuracy_range,cost_matrices):
    for j,(platform,platform_type) in enumerate(platforms):
        for k,task in enumerate(tasks):
            accuracy_coefficient,latency_coefficient,latency_setup = select_coefficients(data,platform,platform_type,task)
            if not numpy.any(numpy.logical_not(numpy.isfinite([accuracy_coefficient,latency_coefficient,latency_setup]))):
                task_paths = paths_accuracy(accuracy_target,accuracy_coefficient)
                scip_manifest[j][i][k] = numpy.ceil(task_paths*scip_allocations[i][j][k])
                scip_manifest_times[j][i][k] = latency_paths(scip_manifest[j][i][k],latency_coefficient,latency_setup)
                
                no_manifest[j][i][k] = numpy.ceil(task_paths*numerical_optimiser_allocations[i][j][k])
                no_manifest_times[j][i][k] = latency_paths(no_manifest[j][i][k],latency_coefficient,latency_setup)
                
                prop_manifest[j][i][k] = numpy.ceil(task_paths*proportional_allocations[i][j][k])
                prop_manifest_times[j][i][k] = latency_paths(prop_manifest[j][i][k],latency_coefficient,latency_setup)
                #print("SCIP ",scip_allocations[i][j][k],k,' on ',platform,platform_type)
                #print("Prop ",proportional_allocations[i][j][0],k,' on ',platform,platform_type)

# %% [markdown]
# ### Running Partition Manifests

# %% [markdown]
# Rounding off the number of paths seems to be a significant issue - implementations should be made more robust in handling this, particularly the Xeon Phi.
#
# Snowball2 seems to have a particular issue when large numbers of work items (100Ms).

# %%
def platform_execute(platform,option_tasks,platform_paths,accuracy_targets,queue,output_queue,error_queue,expected_times,):
    import subprocess32 as subprocess
    import time
    for i,o in enumerate(option_tasks):
        results = []
        
        for target_accuracy,paths in zip(accuracy_targets,platform_paths[:,i]):
            retries = 10
            
            accuracy_index = accuracy_targets.index(target_accuracy)
            timeout = max(expected_times[accuracy_index,i]*2,100) #give it 100% leeway or 100 seconds
            
            while(retries):
                if(paths):
                    if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #rounding up the number of paths
                        paths = int(numpy.ceil(1.0*paths/20)*20)
                    #else:
                        #paths = int(numpy.ceil(1.0*paths/10)*10)
                    
                    if(isinstance(platform,MulticoreCPU.MulticoreCPU)): 
                        mc_solver = MulticoreCPU_MonteCarlo.MulticoreCPU_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,OpenCLGPU.OpenCLGPU) and platform.device_type==8): 
                        mc_solver = OpenCLGPU_MonteCarlo.OpenCLGPU_MonteCarlo([o],paths,platform,kernel_path_max=1)
                    elif(isinstance(platform,OpenCLGPU.OpenCLGPU)): 
                        mc_solver = OpenCLGPU_MonteCarlo.OpenCLGPU_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,OpenCLAlteraFPGA.OpenCLAlteraFPGA)): 
                        mc_solver = OpenCLAlteraFPGA_MonteCarlo.OpenCLAlteraFPGA_MonteCarlo([o],paths,platform)
                    elif(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                        if("heston" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],1000,platform,instances=8)
                        elif("black_scholes" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],1000,platform,instances=16)
                    
                    if(isinstance(platform,MaxelerFPGA.MaxelerFPGA)):
                        mc_solver.dummy_run()
                        mc_solver.execute()
                        
                        if("heston" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=8)
                        elif("black_scholes" in o.underlying[0].name): mc_solver = MaxelerFPGA_MonteCarlo.MaxelerFPGA_MonteCarlo([o],paths,platform,instances=16)
                    
              
                    try:
                        if(platform.ssh_alias!="phi" and platform.ssh_alias!=""): timeout = None
                        result = mc_solver.execute(timeout=timeout)
                        #print(expected_times[accuracy_index,i],timeout)
                        #print(i,target_accuracy,result)
                        if(numpy.isnan(float(result[1])) or float(result[1])==0): raise ValueError()
                            
                        retries = 0
                        results.append((paths,result[-1]/10e6,target_accuracy,float(result[1])))
                        output_queue.put_nowait((platform.ssh_alias,platform.name,(paths,result[-1]/10e6,target_accuracy,float(result[1]))))
                    
                    #print((platform.ssh_alias,platform.name,(paths,result[-1]/10e6,float(result[1]))))
            
                    except subprocess.CalledProcessError as e:
                        output_queue.put_nowait("Command Error!\nCommand:" + str(e.cmd) + "\nReturn: " + str(e.output) + "\nReturncode: " + str(e.returncode))
                        retries -= 1
                        
                        if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #increasing the number of paths
                            paths += 20
                        
                        """
                        else:
                            paths += 10
                        """
                        
                        if not(retries): error_queue.put_nowait((platform.ssh_alias,platform.name,paths,i,target_accuracy))
                    
                    except subprocess.TimeoutExpired as e:
                        #print("timeout on ",i,target_accuracy)
                        output_queue.put_nowait("Timeout!\nCommand:" + str(e.cmd) + "\nReturn: " + str(e.output) + "\nTimeout (expected time): " + str(e.timeout) + "("+str(expected_times[accuracy_index,i])+")")
                        timeout += max(1,timeout*0.5) #give a second or 50% more, whichever is greater
                        retries -= 1
                        time.sleep(5) #seems to need a cool down period
                        
                        if not(retries): error_queue.put_nowait((platform.ssh_alias,platform.name,paths,i,target_accuracy))
                    
                    except ValueError:
                        output_queue.put_nowait("Value Error!\nPlatform:" + platform.ssh_alias + "\nPlatform Type:" + platform.name + "\nTask: " + str(i) + "\nValue: " + result[1])
                        retries -= 1
                        
                        #if not(isinstance(platform,MulticoreCPU.MulticoreCPU)): #increasing the number of paths
                        if(timeout): timeout = timeout*(paths+20.0)/paths
                        paths += 20
                        
                        if not(retries):
                            results.append((paths,result[-1]/10e6,target_accuracy,0.0))
                            error_queue.put_nowait((platform.ssh_alias,platform.name,paths,i,target_accuracy))
                else:
                    retries = 0
                
        if(results):
            #print(str(i) + " on " + platform.ssh_alias + "("+platform.name+")" + ": " + str(results) + "\n")
            output_queue.put_nowait(str(i) + " on " + platform.ssh_alias + "("+platform.name+")" + ": " + str(results) + "\n")
            queue.put_nowait((platform.ssh_alias,platform.name,i,results))

# %%
import multiprocessing

queue = multiprocessing.Queue(len(platforms)*len(option_tasks)*2)
output_queue = multiprocessing.Queue()
error_queue = multiprocessing.Queue(len(platforms)*len(option_tasks))

# %%
def run_manifest(path_manifest,platforms,execution_platforms,option_tasks,accuracy_range,queue,output_queue,error_queue,manifest_times,parallel=True):
    results = []
    if(parallel):
        try:
            pool = [multiprocessing.Process(target=platform_execute,args=(p,option_tasks,path_manifest[platforms.index((p.ssh_alias,p.name))],accuracy_range,queue,output_queue,error_queue,manifest_times[platforms.index((p.ssh_alias,p.name))],)) for j,p in enumerate(execution_platforms)]
    
            for p in pool: p.start()
        
            while(True):
                while not(output_queue.empty()): print(output_queue.get())
                while not(queue.empty()): results += [queue.get()]
        
                flag = True
                for p in pool: 
                    if(p.is_alive() and flag): flag = False
                if(flag): break
            
                time.sleep(1)
            
            for p in pool: 
                p.join()
                del p
        except KeyboardInterrupt:
            for p in pool: 
                p.terminate()
                del p
    
    else: 
        for j,p in enumerate(execution_platforms): platform_execute(p,option_tasks,path_manifest[platforms.index((p.ssh_alias,p.name))],accuracy_range,queue,output_queue,error_queue,manifest_times[platforms.index((p.ssh_alias,p.name))],)
            
    return results
        
#print(scip_manifest[j].shape)
#print(accuracy_range)
        
#for p in execution_platforms: platform_execute(p,option_tasks,scip_manifest[j],accuracy_range,queue,output_queue,)

# %%
# !ssh pi pkill -u pi
# !ssh phi pkill -u gordoni
# !ssh ee-benjamin pkill -u gi11
# !ssh ee-snowball0 pkill -u gi11
# !ssh ee-snowball1 pkill -u gi11
#!ssh ee-snowball2 pkill -u gi11
# !ssh ee-mollie pkill -u gi11
# !ssh amazon-cpu-0 pkill -u ubuntu
# !ssh amazon-cpu-1 pkill -u ubuntu
# !ssh amazon-gpu-0 pkill -u ec2-user
# !ssh amazon-gpu-1 pkill -u ec2-user
# !ssh google-cpu-0 pkill -u gordon
# Out:
# Connection to 129.31.139.85 closed by remote host.
# Write failed: Broken pipe
# Connection to ee-benjamin closed by remote host.
# Connection to ee-snowball0 closed by remote host.
# Connection to ee-snowball1 closed by remote host.
# id: cannot find name for group ID 6950
# Connection to ee-mollie closed by remote host.
# bash: warning: setlocale: LC_ALL: cannot change locale (en_GB.UTF-8)
# Connection to ec2-54-146-72-20.compute-1.amazonaws.com closed by remote host.
# bash: warning: setlocale: LC_ALL: cannot change locale (en_GB.UTF-8)
# Connection to ec2-54-186-236-146.us-west-2.compute.amazonaws.com closed by remote host.
# Connection to ec2-54-196-128-54.compute-1.amazonaws.com closed by remote host.
# Connection to ec2-54-191-111-112.us-west-2.compute.amazonaws.com closed by remote host.
# Warning: Permanently added '104.154.64.61' (ECDSA) to the list of known hosts.
# bash: warning: setlocale: LC_ALL: cannot change locale (en_GB.UTF-8)
# Connection to 104.154.64.61 closed by remote host.

# %%
scip_manifest_results = run_manifest(scip_manifest[:,:,:],platforms,execution_platforms,option_tasks,accuracy_range[:],queue,output_queue,error_queue,scip_manifest_times[:],parallel=True)
# Out:
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (41.0, 0.003839707374572754, 10.0, 0.821308))
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (21.0, 0.004259800910949707, 5.0, 0.508354))
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu',

# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 1
# Value: 0.000000
# ('ee-benjamin', 'multicore_cpu', (271074.0, 0.2703364849090576, 0.01, 0.011898))
# 6 on ee-benjamin(multicore_cpu): [(271074.0, 0.2703364849090576, 0.01, 0.011898)]
#
# ('ee-snowball1', 'opencl_gpu', (2912820, 0.9443001985549927, 0.001, 0.002164))
# 0 on ee-snowball1(opencl_gpu): [(2912820, 0.9443001985549927, 0.001, 0.002164)]
#
# ('pi', 'multicore_cpu', (4.0, 0.13486671447753906, 10.0, 9.791883))
# 38 on pi(multicore_cpu): [(4.0, 0.13486671447753906, 10.0, 9.791883)]
#
# ('ee-benjamin', 'multicore_cpu', (29916.0, 0.07967979907989502, 0.10000000000000001, 0.118531))
# ('amazon-gpu-0', 'opencl_gpu', (11651240, 1.0386215925216675, 0.00050000000000000001, 0.001079))
# ('amazon-gpu-0', 'multicore_cpu', (114269.0, 1.0462257862091064, 0.01, 0.01226))
# 2 on amazon-gpu-0(multicore_cpu): [(114269.0, 1.0462257862091064, 0.01, 0.01226)]
#
# ('pi', 'multicore_cpu', (5.0, 0.1387476921081543, 5.0, 1.132))
# 40 on pi(multicore_cpu): [(5.0, 0.1387476921081543, 5.0, 1.132)]
#
# ('ee-benjamin', 'multicore_cpu', (119664.0, 0.13953511714935302, 0.050000000000000003, 0.059974))
# ('amazon-cpu-0', 'multicore_cpu', (237700.0, 0.554055118560791, 0.0050000000000000001, 0.00755))
# 0 on amazon-cpu-0(multicore_cpu): [(59425.0, 0.6632627964019775, 0.01, 0.015153), (237700.0, 0.554055118560791, 0.0050000000000000001, 0.00755)]
#
# ('pi', 'multicore_cpu', (6.0, 0.14047548770904542, 10.0, 13.670889))
# 41 on pi(multicore_cpu): [(6.0, 0.14047548770904542, 10.0, 13.670889)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 1
# Value: 0.000000
# ('ee-snowball1', 'opencl_gpu', (2868000, 0.3856046199798584, 0.001, 0.002442))
# ('ee-snowball2', 'opencl_alterafpga', (4035640, 0.46550259590148924, 0.0050000000000000001, 0.010102))
# 5 on ee-snowball2(opencl_alterafpga): [(2847900, 0.8686594009399414, 0.01, 0.01191), (4035640, 0.46550259590148924, 0.0050000000000000001, 0.010102)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 66
# Value: 0.000000
# ('ee-snowball0', 'opencl_gpu', (12920920, 1.484037184715271, 0.001, 0.001077))
# 3 on ee-snowball0(opencl_gpu): [(12920920, 1.484037184715271, 0.001, 0.001077)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 66
# Value: 0.000000
# ('ee-snowball2', 'opencl_alterafpga', (1770940, 0.2395540952682495, 0.01, 0.011093))
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 1
# Value: 0.000000
# ('ee-benjamin', 'multicore_cpu', (1023953.0, 0.5082239866256714, 0.01, 0.020518))
# ('ee-snowball0', 'opencl_gpu', (1315000, 0.18034040927886963, 0.0050000000000000001, 0.005376))
# 6 on ee-snowball0(opencl_gpu): [(1315000, 0.18034040927886963, 0.0050000000000000001, 0.005376)]
#
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 66
# Value: 0.000000
# ('ee-snowball0', 'opencl_gpu', (1203740, 0.15530991554260254, 0.01, 0.012005))
# ('pi', 'multicore_cpu', (73.0, 0.16614170074462892, 0.050000000000000003, 0.001646))
# ('amazon-cpu-0', 'multicore_cpu', (364936.0, 0.7770288944244385, 0.0050000000000000001, 0.006135))
# 4 on amazon-cpu-0(multicore_cpu): [(364936.0, 0.7770288944244385, 0.0050000000000000001, 0.006135)]
#
# ('amazon-gpu-1', 'multicore_cpu', (312292.0, 1.9989506959915162, 0.0050000000000000001, 0.036111))
# 5 on amazon-gpu-1(multicore_cpu): [(312292.0, 1.9989506959915162, 0.0050000000000000001, 0.036111)]
# ('ee-mollie', 'maxeler_fpga', (13480, 0.10830750465393066, 0.10000000000000001, 0.114413))
# ('ee-mollie', 'maxeler_fpga', (53920, 0.06295650005340576, 0.050000000000000003, 0.056186))
# 7 on ee-mollie(maxeler_fpga): [(13480, 0.10830750465393066, 0.10000000000000001, 0.114413), (53920, 0.06295650005340576, 0.050000000000000003, 0.056186)]
#
# ('ee-mollie', 'maxeler_fpga', (820, 0.06366069316864013, 0.5, 0.429356))
# ('ee-mollie', 'maxeler_fpga', (20340, 0.07747089862823486, 0.10000000000000001, 0.094158))
# ('ee-mollie', 'maxeler_fpga', (81360, 0.07227349281311035, 0.050000000000000003, 0.047478))
# 9 on ee-mollie(maxeler_fpga): [(820, 0.06366069316864013, 0.5, 0.429356), (20340, 0.07747089862823486, 0.10000000000000001, 0.094158), (81360, 0.07227349281311035, 0.050000000000000003, 0.047478)]
#
# ('ee-mollie', 'maxeler_fpga', (20, 0.06211998462677002, 10.0, 0.278988))
# ('ee-snowball0', 'opencl_gpu', (120372100, 8.075505113601684, 0.001, 0.0012))
# ('ee-mollie', 'maxeler_fpga', (20, 0.12112600803375244, 5.0, 3.111083))
# ('ee-mollie', 'maxeler_fpga', (240, 0.06210920810699463, 1.0, 0.833386))
# ('ee-mollie', 'maxeler_fpga', (960, 0.08751788139343261, 0.5, 0.372353))
# ('ee-mollie', 'maxeler_fpga', (23680, 0.08890550136566162, 0.10000000000000001, 0.094923))
# ('', 'multicore_cpu', (2329059.0, 9.271535205841065, 0.001, 0.009739))
# 11 on (multicore_cpu): [(3.0, 0.003033089637756348, 10.0, 0.726179), (9.0, 0.0028779983520507814, 5.0, 3.421986), (224.0, 0.004199409484863281, 1.0, 0.986958), (2329059.0, 9.271535205841065, 0.001, 0.009739)]
#
# ('', 'multicore_cpu', (2.0, 0.0028332948684692385, 10.0, 5.942814))
# 12 on (multicore_cpu): [(2.0, 0.0028332948684692385, 10.0, 5.942814)]
#
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 13
# Value: 0.000000
# ('', 'multicore_cpu', (25.0, 0.0029710054397583006, 10.0, 3.501352))
# ('', 'multicore_cpu', (18.0, 0.0030879974365234375, 5.0, 7.126873))
# ('', 'multicore_cpu', (443.0, 0.004850316047668457, 1.0, 0.99221))
# ('ee-mollie', 'maxeler_fpga', (94720, 0.08349218368530273, 0.050000000000000003, 0.046989))
# 10 on ee-mollie(maxeler_fpga): [(20, 0.06211998462677002, 10.0, 0.278988), (20, 0.12112600803375244, 5.0, 3.111083), (240, 0.06210920810699463, 1.0, 0.833386), (960, 0.08751788139343261, 0.5, 0.372353), (23680, 0.08890550136566162, 0.10000000000000001, 0.094923), (94720, 0.08349218368530273, 0.050000000000000003, 0.046989)]
#
# ('', 'multicore_cpu', (83505.0, 0.17439610958099366, 0.001, 0.072022))
# ('ee-mollie', 'maxeler_fpga', (940, 0.07527210712432861, 0.5, 0.485319))
# ('ee-snowball2', 'opencl_alterafpga', (177093140, 10.738792395591735, 0.001, 0.001111))

# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 82
# Value: 0.000000
# ('pi', 'multicore_cpu', (31.0, 0.15632641315460205, 1.0, 0.548866))
# ('pi', 'multicore_cpu', (43.0, 0.160994291305542, 0.5, 0.35269))
# 82 on pi(multicore_cpu): [(31.0, 0.15632641315460205, 1.0, 0.548866), (43.0, 0.160994291305542, 0.5, 0.35269)]
#
# ('ee-mollie', 'maxeler_fpga', (1353560, 0.24287638664245606, 0.01, 0.011804))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('pi', 'multicore_cpu', (61.0, 0.1810300827026367, 5.0, 0.035791))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('ee-mollie', 'maxeler_fpga', (5414220, 0.792090892791748, 0.0050000000000000001, 0.005895))
# ('pi', 'multicore_cpu', (61.0, 0.1728687047958374, 0.5, 0.123788))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('pi', 'multicore_cpu', (61.0, 0.17401769161224365, 0.10000000000000001, 0.123788))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('phi', 'multicore_cpu', (10858713.0, 16.710648488998412, 0.001, 0.003081))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('pi', 'multicore_cpu', (61.0, 0.17654378414154054, 0.050000000000000003, 0.123788))
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# Value Error!
# Platform:pi
# Platform Type:multicore_cpu
# Task: 85
# Value: 0.000000
# ('pi', 'multicore_cpu', (80.0, 0.18747289180755616, 0.01, 0.013705))
# ('pi', 'multicore_cpu', (77.0, 0.18099761009216309, 0.0050000000000000001, 0.055045))
# ('pi', 'multicore_cpu', (1901.0, 1.3719177007675172, 0.001, 0.01467))
# ('ee-mollie', 'maxeler_fpga', (28907220, 3.975051999092102, 0.001, 0.002551))
# ('amazon-gpu-0', 'opencl_gpu', (270566280, 11.677274107933044, 0.001, 0.00123))
# ('ee-snowball1', 'opencl_gpu', (286799360, 24.202669405937193, 0.0001, 0.000244))
# 2 on ee-snowball1(opencl_gpu): [(2868000, 0.3856046199798584, 0.001, 0.002442), (11471980, 1.1087548971176147, 0.00050000000000000001, 0.001205), (286799360, 24.202669405937193, 0.0001, 0.000244)]
#
# ('pi', 'multicore_cpu', (7603.0, 5.084431290626526, 0.00050000000000000001, 0.005207))
# ('ee-snowball1', 'opencl_gpu', (36447300, 3.2214294910430907, 0.00050000000000000001, 0.000626))
# 3 on ee-snowball1(opencl_gpu): [(36447300, 3.2214294910430907, 0.00050000000000000001, 0.000626)]
#
# ('ee-snowball1', 'opencl_gpu', (4440320, 0.5561715126037597, 0.0050000000000000001, 0.005603))
# 18 on ee-snowball1(opencl_gpu): [(4440320, 0.5561715126037597, 0.0050000000000000001, 0.005603)]
#
# ('ee-snowball1', 'opencl_gpu', (1004200, 0.2322098970413208, 0.01, 0.010767))
# ('ee-snowball1', 'opencl_gpu', (4016800, 0.5147641181945801, 0.0050000000000000001, 0.005411))
# 19 on ee-snowball1(opencl_gpu): [(1004200, 0.2322098970413208, 0.01, 0.010767), (4016800, 0.5147641181945801, 0.0050000000000000001, 0.005411)]
#
# ('ee-snowball1', 'opencl_gpu', (511160, 0.1915583848953247, 0.0050000000000000001, 0.010415))
# ('ee-snowball1', 'opencl_gpu', (12779000, 1.2910515069961548, 0.001, 0.002084))
# ('ee-snowball1', 'opencl_gpu', (51115960, 4.726190996170044, 0.00050000000000000001, 0.001043))
# ('amazon-gpu-1', 'opencl_gpu', (646618920, 30.220301699638366, 0.00050000000000000001, 0.000584))
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472820', '3695304754', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472840', '1481414797', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472860', '3333552639', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472880', '3784328170', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472900', '3252179316', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472920', '3101418921', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472940', '424494771', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472960', '3208906852', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165472980', '1596550434', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_ba_1', '4096', '8', '4096', '16165473000', '3634732678', '1', '1', '0.0296289883299', '100', '0.0544219541594', '3', '1', '95', '4096', '125', '1', '0']
# Return:
# Returncode: 134
# 11 on amazon-gpu-1(opencl_gpu): [(159971460, 8.050484991073608, 0.001, 0.001177), (646618920, 30.220301699638366, 0.00050000000000000001, 0.000584)]
#
# ('ee-snowball0', 'opencl_gpu', (481488360, 32.058317518234254, 0.00050000000000000001, 0.0006))
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208780', '3252179316', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 134
# ('ee-mollie', 'maxeler_fpga', (142200640, 19.642421293258668, 0.00050000000000000001, 0.00115))
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208800', '3101418921', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208820', '424494771', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208840', '3208906852', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208860', '1596550434', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('phi', 'opencl_gpu', (687174360, 43.22242720127106, 0.0001, 0.000148))
# 3 on phi(opencl_gpu): [(687174360, 43.22242720127106, 0.0001, 0.000148)]
#
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208880', '3634732678', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208900', '2259205370', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208920', '914867359', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208940', '260337252', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_bl_1_as_1', '4096', '8', '4096', '12037208960', '219956196', '1', '1', '0.0997094282241', '100', '0.0766084201476', '3', '1', '101', '4096']
# Return:
# Returncode: 141
# 7 on ee-snowball0(opencl_gpu): [(1203740, 0.15530991554260254, 0.01, 0.012005), (4814900, 0.3959942102432251, 0.0050000000000000001, 0.006004), (120372100, 8.075505113601684, 0.001, 0.0012), (481488360, 32.058317518234254, 0.00050000000000000001, 0.0006)]
#
# ('ee-snowball0', 'opencl_gpu', (1842440, 0.1934596061706543, 0.01, 0.010023))
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('ee-snowball0', 'opencl_gpu', (7369720, 0.5878175020217895, 0.0050000000000000001, 0.005008))
# 9 on ee-snowball0(opencl_gpu): [(1842440, 0.1934596061706543, 0.01, 0.010023), (7369720, 0.5878175020217895, 0.0050000000000000001, 0.005008)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('ee-snowball0', 'opencl_gpu', (765380, 0.19161450862884521, 0.0050000000000000001, 0.008616))
# 32 on ee-snowball0(opencl_gpu): [(765380, 0.19161450862884521, 0.0050000000000000001, 0.008616)]
#
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_he_1_as_1', '4096', '8', '4096', '20', '3910315632', '1', '1', '0.0245074486325', '100', '0.13009803664', '0.907369704079', '-0.0175800875971', '1.92750910986', '0.245361640352', '1.0', '-0.0175800875971', '0.0', '0.999845458318', '1', '0', '91', '4096']
# Return:
# Returncode: 134
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_he_1_as_1', '4096', '8', '4096', '40', '4148088932', '1', '1', '0.0245074486325', '100', '0.13009803664', '0.907369704079', '-0.0175800875971', '1.92750910986', '0.245361640352', '1.0', '-0.0175800875971', '0.0', '0.999845458318', '1', '0', '91', '4096']
# Return:
# Returncode: 141
# Command Error!
# Command:['ssh', '-t', 'ee-snowball0', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_ee_snowball0_he_1_as_1', '4096', '8', '4096', '60', '2566526935', '1', '1', '0.0245074486325', '100', '0.13009803664', '0.907369704079', '-0.0175800875971', '1.92750910986', '0.245361640352', '1.0', '-0.0175800875971', '0.0', '0.999845458318', '1', '0', '91', '4096']
# Return:
# Returncode: 141
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('ee-snowball0', 'opencl_gpu', (80, 0.0980452060699463, 5.0, 1.744927))
# ('ee-snowball0', 'opencl_gpu', (300, 0.08963561058044434, 1.0, 0.864979))
# ('ee-snowball0', 'opencl_gpu', (114660, 0.10084321498870849, 0.050000000000000003, 0.047683))
# 35 on ee-snowball0(opencl_gpu): [(80, 0.0980452060699463, 5.0, 1.744927), (300, 0.08963561058044434, 1.0, 0.864979), (114660, 0.10084321498870849, 0.050000000000000003, 0.047683)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('ee-snowball0', 'opencl_gpu', (1500, 0.09267959594726563, 0.5, 0.556225))
# ('ee-snowball0', 'opencl_gpu', (37500, 0.07045271396636962, 0.10000000000000001, 0.106804))
# 36 on ee-snowball0(opencl_gpu): [(1500, 0.09267959594726563, 0.5, 0.556225), (37500, 0.07045271396636962, 0.10000000000000001, 0.106804)]
#
# ('ee-snowball0', 'opencl_gpu', (1180, 0.09571530818939208, 0.5, 0.558699))
# ('ee-snowball0', 'opencl_gpu', (29200, 0.09651730060577393, 0.10000000000000001, 0.10665))
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# ('ee-snowball0', 'opencl_gpu', (116800, 0.09683399200439453, 0.050000000000000003, 0.053284))
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 14
# Value: -0.000000
# 14 on ee-mollie(maxeler_fpga): [(13540, 0.09942409992218018, 0.10000000000000001, 0.116326), (54160, 0.06981158256530762, 0.050000000000000003, 0.058987), (1353560, 0.24287638664245606, 0.01, 0.011804), (5414220, 0.792090892791748, 0.0050000000000000001, 0.005895), (28907220, 3.975051999092102, 0.001, 0.002551), (142200640, 19.642421293258668, 0.00050000000000000001, 0.00115), (3299087460, 0.07447128295898438, 0.0001, 0.0)]
#
# ('ee-snowball0', 'opencl_gpu', (2919780, 0.3674881935119629, 0.01, 0.010632))
# ('ee-mollie', 'maxeler_fpga', (420, 0.062432289123535156, 0.5, 0.582676))
# ('ee-mollie', 'maxeler_fpga', (10060, 0.06160538196563721, 0.10000000000000001, 0.136248))
# ('ee-mollie', 'maxeler_fpga', (40240, 0.11784789562225342, 0.050000000000000003, 0.067787))
# ('ee-snowball0', 'opencl_gpu', (11679100, 1.1877171993255615, 0.0050000000000000001, 0.005328))
# ('ee-mollie', 'maxeler_fpga', (1005580, 0.19223291873931886, 0.01, 0.013766))
# 15 on ee-mollie(maxeler_fpga): [(420, 0.062432289123535156, 0.5, 0.582676), (10060, 0.06160538196563721, 0.10000000000000001, 0.136248), (40240, 0.11784789562225342, 0.050000000000000003, 0.067787), (1005580, 0.19223291873931886, 0.01, 0.013766)]
#
# ('ee-mollie', 'maxeler_fpga', (5740, 0.05714569091796875, 0.0001, 0.021728))
# 16 on ee-mollie(maxeler_fpga): [(5740, 0.05714569091796875, 0.0001, 0.021728)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 18
# Value: -nan
# ('phi', 'opencl_gpu', (77743340, 5.832322502136231, 0.001, 0.001543))
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 18
# Value: -nan
# ('ee-mollie', 'maxeler_fpga', (60, 0.07754781246185302, 10.0, 1.128667))
# ('ee-mollie', 'maxeler_fpga', (460, 0.10177600383758545, 0.5, 0.503335))
# ('ee-mollie', 'maxeler_fpga', (11320, 0.06462030410766602, 0.10000000000000001, 0.10879))
# ('ee-mollie', 'maxeler_fpga', (45260, 0.06297881603240967, 0.050000000000000003, 0.055131))
# ('ee-mollie', 'maxeler_fpga', (1131080, 0.2086400032043457, 0.01, 0.011101))
# ('ee-mollie', 'maxeler_fpga', (245740, 0.09390821456909179, 0.0050000000000000001, 0.023818))
# ('ee-mollie', 'maxeler_fpga', (6284600, 0.9014456033706665, 0.001, 0.004692))
# 18 on ee-mollie(maxeler_fpga): [(60, 0.07754781246185302, 10.0, 1.128667), (460, 0.10177600383758545, 0.5, 0.503335), (11320, 0.06462030410766602, 0.10000000000000001, 0.10879), (45260, 0.06297881603240967, 0.050000000000000003, 0.055131), (1131080, 0.2086400032043457, 0.01, 0.011101), (245740, 0.09390821456909179, 0.0050000000000000001, 0.023818), (6284600, 0.9014456033706665, 0.001, 0.004692)]
#
# ('ee-mollie', 'maxeler_fpga', (480, 0.05649769306182861, 0.5, 0.328775))
# ('ee-mollie', 'maxeler_fpga', (11880, 0.07757611274719238, 0.10000000000000001, 0.104108))
# ('ee-mollie', 'maxeler_fpga', (47480, 0.06322369575500489, 0.050000000000000003, 0.051773))
# 19 on ee-mollie(maxeler_fpga): [(480, 0.05649769306182861, 0.5, 0.328775), (11880, 0.07757611274719238, 0.10000000000000001, 0.104108), (47480, 0.06322369575500489, 0.050000000000000003, 0.051773)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 20
# Value: -nan
# ('amazon-gpu-1', 'opencl_gpu', (300984200, 14.206719589233398, 0.00050000000000000001, 0.00068))
# ('ee-mollie', 'maxeler_fpga', (40, 0.05749940872192383, 1.0, 0.06672))
# 20 on ee-mollie(maxeler_fpga): [(40, 0.05749940872192383, 1.0, 0.06672)]
#
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 21
# Value: 0.000000
# ('ee-mollie', 'maxeler_fpga', (40, 0.08950650691986084, 10.0, 0.118459))
# ('ee-snowball2', 'opencl_alterafpga', (708372540, 42.48120999336243, 0.00050000000000000001, 0.000556))
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931316', '1', '1', '4096', '17709313160', '3252179316', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 21
# Value: 0.000000
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931318', '1', '1', '4096', '17709313180', '3101418921', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931320', '1', '1', '4096', '17709313200', '424494771', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# ('ee-mollie', 'maxeler_fpga', (40, 0.08798410892486572, 5.0, 0.145082))
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931322', '1', '1', '4096', '17709313220', '3208906852', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931324', '1', '1', '4096', '17709313240', '1596550434', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 21
# Value: 0.000000
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931326', '1', '1', '4096', '17709313260', '3634732678', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931328', '1', '1', '4096', '17709313280', '2259205370', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Value Error!
# Platform:ee-mollie
# Platform Type:maxeler_fpga
# Task: 21
# Value: 0.000000
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931330', '1', '1', '4096', '17709313300', '914867359', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_bl_1_ba_1_cslow_True_pipe_20_insts_1_simd_2', '4096', '1770931332', '1', '1', '4096', '17709313320', '260337252', '1', '1', '0.0550685772996', '100', '0.138268058129', '2', '1', '111', '4096', '149', '1', '0']
# Return:
# Returncode: 1
# ('ee-mollie', 'maxeler_fpga', (60, 0.07676100730895996, 1.0, 0.066831))
# Command Error!
# ...
# Return:
# Returncode: 143
# 37 on ee-snowball2(opencl_alterafpga): [(20, 0.15476539134979247, 10.0, 1.711929), (20, 0.1856978178024292, 5.0, 2.455966), (8760, 0.15379319190979004, 0.10000000000000001, 0.140483), (34980, 0.14776978492736817, 0.050000000000000003, 0.065779), (874100, 0.28886399269104, 0.01, 0.013442), (87408280, 8.917867398262024, 0.001, 0.00132), (349633120, 38.426147603988646, 0.00050000000000000001, 0.000671)]
#
# ('ee-snowball2', 'opencl_alterafpga', (1360, 0.21396250724792482, 0.5, 0.403372))
# ('ee-snowball2', 'opencl_alterafpga', (134300, 0.17509791851043702, 0.050000000000000003, 0.046332))

# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739806', '1', '1', '4096', '22937398060', '913708853', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739808', '1', '1', '4096', '22937398080', '2547306140', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739810', '1', '1', '4096', '22937398100', '30308855', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739812', '1', '1', '4096', '22937398120', '378726922', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739814', '1', '1', '4096', '22937398140', '656442714', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739816', '1', '1', '4096', '22937398160', '4232974830', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739818', '1', '1', '4096', '22937398180', '64019808', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739820', '1', '1', '4096', '22937398200', '3004622728', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739822', '1', '1', '4096', '22937398220', '2325844715', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# Command Error!
# Command:['ssh', '-t', 'ee-snowball2', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/gi11/workspace/ForwardFinancialFramework/Platforms/OpenCLAlteraFPGA/openclalterafpga_code/mc_solver_opencl_alterafpga_he_1_as_1_cslow_True_pipe_10_insts_1_simd_2', '4096', '2293739824', '1', '1', '4096', '22937398240', '372281507', '1', '1', '0.0443273350088', '100', '0.0405379496229', '0.623008410709', '-0.2919021715', '1.7988709612', '0.246995438865', '1.0', '-0.2919021715', '0.0', '0.956448180653', '1', '1', '102', '4096']
# Return:
# Returncode: 1
# 58 on ee-snowball2(opencl_alterafpga): [(460, 0.18816831111907958, 1.0, 1.014861), (18313260, 2.1729897975921633, 0.0050000000000000001, 0.005447), (208913040, 21.112531208992003, 0.001, 0.00161), (888110160, 89.25194630622863, 0.00050000000000000001, 0.000788)]
#
# ('ee-snowball2', 'opencl_alterafpga', (201460, 0.17275519371032716, 0.050000000000000003, 0.043745))
# 59 on ee-snowball2(opencl_alterafpga): [(201460, 0.17275519371032716, 0.050000000000000003, 0.043745)]
#
# ('ee-snowball2', 'opencl_alterafpga', (15920, 0.20968987941741943, 0.10000000000000001, 0.117669))
# ('ee-snowball2', 'opencl_alterafpga', (63660, 0.1620546817779541, 0.050000000000000003, 0.058383))
# 97 on ee-snowball2(opencl_alterafpga): [(15920, 0.20968987941741943, 0.10000000000000001, 0.117669), (63660, 0.1620546817779541, 0.050000000000000003, 0.058383)]
#
# ('ee-snowball2', 'opencl_alterafpga', (2985320, 0.5293232917785644, 0.01, 0.011438))
# 126 on ee-snowball2(opencl_alterafpga): [(2985320, 0.5293232917785644, 0.01, 0.011438)]

# %%
no_manifest_results = run_manifest(no_manifest[:,:-1,:],platforms,execution_platforms,option_tasks,accuracy_range[:-1],queue,output_queue,error_queue,no_manifest_times[:],parallel=True)
# Out:
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (41.0, 0.004843401908874512, 10.0, 0.821308))
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (21.0, 0.004265618324279785, 5.0, 0.508354))
# Value Error!
# Platform:
# Platform Type:multicore_cpu
# Task: 0
# Value: 0.000000
# ('', 'multicore_cpu', (30.0, 0.006212401390075684, 1.0, 0.658355))
# ('', 'multicore_cpu', (39.0, 0.004119491577148438, 0.5, 0.027587))
# ('', 'multicore_cpu', (12306.0, 0.05764529705047607, 0.001, 0.033711))
# ('ee-benjamin', 'multicore_cpu', (83690.0, 0.13431909084320068, 0.001, 0.012945))
# ('amazon-gpu-0', 'opencl_gpu', (29140, 0.11961169242858886, 0.01, 0.022798))
# ('amazon-cpu-0', 'multicore_cpu', (19374.0, 0.1528176784515381, 0.001, 0.026997))
# ('amazon-gpu-0', 'multicore_cpu', (11786.0, 0.16154818534851073, 0.001, 0.034456))
# ('ee-snowball0', 'opencl_gpu', (1113340, 0.18314898014068604, 0.001, 0.003483))
#
# ('pi', 'multicore_cpu', (22.0, 0.1418765068054199, 0.050000000000000003, 1.013498))
# ('google-cpu-0', 'multicore_cpu', (41.0, 0.17704381942749023, 5.0, 0.427345))
# ('ee-snowball2', 'opencl_alterafpga', (20, 0.1477341890335083, 10.0, 0.22645))
# ('ee-snowball1', 'opencl_gpu', (1039780, 0.22967031002044677, 0.001, 0.003731))
# Command Error!
# Command:['ssh', '-t', 'amazon-gpu-1', 'shopt', '-s', 'huponexit;', 'source', '/etc/profile;', '/home/ec2-user/workspace/ForwardFinancialFramework/Platforms/OpenCLGPU/opencl_code/mc_solver_opencl_gpu_amazon_gpu_1_bl_1_as_1', '4096', '8', '4096', '20', '4242262380', '1', '1', '0.0257998835591', '100', '0.0661709675147', '4', '1', '114', '4096']
# Return:
# Returncode: 134
# Value Error!
# Platform:amazon-gpu-0
# Platform Type:multicore_cpu
# Task: 4
# Value: 0.000000
# ('amazon-gpu-1', 'multicore_cpu', (21.0, 0.208434796333313, 5.0, 1.09343))
# ('pi', 'multicore_cpu', (6.0, 0.13774960041046141, 0.01, 0.237911))
# Value Error!
# Platform:google-cpu-0
# Platform Type:multicore_cpu
# Task: 3
# Value: 0.000000

# %% [markdown]
# ### Collating Results

# %%
#verification_results[accuracy_range][task] = [[paths][latency][accuracy]]
def process_results(manifest_result_set,accuracy_range,tasks,platforms):
    verification_accuracy_results = numpy.zeros((len(accuracy_range),len(platforms),len(tasks))) #[[[] for t in tasks] for target_accuracy in accuracy_range]
    verification_path_results = numpy.zeros(verification_accuracy_results.shape)
    verification_latency_results = numpy.zeros(verification_accuracy_results.shape) #[[[] for p in platforms] for target_accuracy in accuracy_range]
    
    for result in manifest_result_set:
        platform,platform_type,task,results = result
        
        platform_index = platforms.index((platform,platform_type))
        for r in results:
            paths,latency,target_accuracy,accuracy = r
            
            accuracy_index = numpy.argmin(numpy.abs(accuracy_range-target_accuracy))
            verification_accuracy_results[accuracy_index][platform_index][task] = accuracy
            verification_path_results[accuracy_index][platform_index][task] = paths
            
            verification_latency_results[accuracy_index][platform_index][task] = latency
            
            
    return verification_accuracy_results,verification_path_results,verification_latency_results

# %%
scip_verification_results = process_results(scip_manifest_results,accuracy_range[:],option_tasks,platforms)

# %%
prop_verification_results = process_results(prop_manifest_results,accuracy_range[:],option_tasks,platforms)

# %%
no_verification_results = process_results(no_manifest_results,accuracy_range[:],option_tasks,platforms)

# %% [markdown]
# $$ CI_{95\%} = 1.96\frac{\sigma}{\sqrt{N}} $$
# To sum the 95% CIs, the 95% CIs have to be converted to variances and the mean variance found. The resulting variance must then be converted back to a 95% CI value, i.e. :
# $$ CI_{95\%,a} + CI_{95\%,b} = 1.96\frac{\sqrt{\overline{(\sqrt{N_a}\frac{\sigma_a}{1.96})^2,(\sqrt{N_b}\frac{\sigma_b}{1.96})^2}}}{\sum{N_a,N_b}} $$

# %%
def ci95_sum(paths,cis):
    selection = paths!=0
    selection &= cis!=0
    
    vars = (cis[selection]*paths[selection]**0.5*1.0/1.96)**2
    cis_sum_sqs = numpy.sum(vars*paths[selection])
    combined_var = cis_sum_sqs/numpy.sum(paths[selection])
    
    return 1.96*(combined_var/numpy.sum(paths[selection]))**0.5

# %%
def generate_verification_data(verification_results,accuracy_range,tasks,platforms):
    accuracy_results,path_results,latency_results = verification_results
    
    verification_accuracies = numpy.zeros((len(accuracy_range),len(tasks)))
    #verification_paths = numpy.zeros(verification_accuracies.shape)
    verification_latencies = numpy.zeros((len(accuracy_range),len(platforms)))
    
    missing_tasks = []
    for i,accuracy_set in enumerate(accuracy_range):
        #Find the Accuracy for each task
        missing_tasks += [[]]
        for j in range(len(tasks)):
            combined_accuracy = ci95_sum(path_results[i,:,j],accuracy_results[i,:,j])
            
            if (numpy.isfinite(combined_accuracy)): verification_accuracies[i,j] = combined_accuracy
            else: missing_tasks[-1] += [j]
        
        #print(verification_accuracies[i,:])
        
        #Find the latency for each platform, minus the latencies from the missing tasks
        for j in range(len(platforms)):
            verification_latencies[i,j] = numpy.sum(latency_results[i,j])
            for mt in missing_tasks[-1]: verification_latencies[i,j] -= latency_results[i,j,mt]
            
    return verification_latencies,verification_accuracies,missing_tasks

# %%
def calculate_verification_stats(verification_latencies,verification_accuracies):
    latency_results = []
    accuracy_results = []
    for vl,va in zip(verification_latencies,verification_accuracies):
        selection = va!=0 
        
        accuracy_mean = scipy.stats.gmean(va[selection])
        accuracy_std = numpy.std(va[selection])
        accuracy_max = numpy.max(va[selection])
        accuracy_min = numpy.min(va[selection])
        accuracy_results += [(accuracy_min,accuracy_mean,accuracy_std,accuracy_max)]
        
        selection =  vl!=0 
        latency_mean = scipy.stats.gmean(vl[selection])
        latency_std = numpy.std(vl[selection])
        latency_max = numpy.max(vl[selection])
        latency_min = numpy.min(vl[selection])
        latency_results += [(latency_min,latency_mean,latency_std,latency_max)]
        
    return numpy.array(latency_results),numpy.array(accuracy_results)

# %%
scip_verification_latencies,scip_verification_accuracies,scip_missing_tasks = generate_verification_data(scip_verification_results[:],accuracy_range[:],option_tasks[:],platforms)
scip_latency_results,scip_accuracy_results = calculate_verification_stats(scip_verification_latencies,scip_verification_accuracies)

# %%
prop_verification_latencies,prop_verification_accuracies,prop_missing_tasks = generate_verification_data(prop_verification_results,accuracy_range[:-1],option_tasks,platforms)
prop_latency_results,prop_accuracy_results = calculate_verification_stats(prop_verification_latencies,prop_verification_accuracies)

# %%
no_verification_latencies,no_verification_accuracies,no_missing_tasks = generate_verification_data(no_verification_results,accuracy_range[:-1],option_tasks,platforms)
no_latency_results,no_accuracy_results = calculate_verification_stats(no_verification_latencies,no_verification_accuracies)

# %% [markdown]
# ### Checking Results

# %% [markdown]
# Function for reading results from file

# %%
scip_latency_results = []
scip_accuracy_results = []
no_latency_results = []
no_accuracy_results = []

with open('partitioner_verification_data_output5_3.csv','r') as verification_file:
    csvreader = csv.reader(verification_file,delimiter=',')
    headers = csvreader.next()
    for row in csvreader:
        partitioner,latency_min,latency_mean,latency_std,latency_max,accuracy_min,accuracy_mean,accuracy_std,accuracy_max = row
        latency_results = (latency_min,latency_mean,latency_std,latency_max)
        accuracy_results = (accuracy_min,accuracy_mean,accuracy_std,accuracy_max)
    
        if(partitioner=="SCIP Verification"):
            scip_latency_results += [numpy.array(latency_results).astype(numpy.float)]
            scip_accuracy_results += [numpy.array(accuracy_results).astype(numpy.float)]
            
        elif(partitioner=="NO Verification"):
            no_latency_results += [numpy.array(latency_results).astype(numpy.float)]
            no_accuracy_results += [numpy.array(accuracy_results).astype(numpy.float)]
        
scip_latency_results = numpy.array(scip_latency_results)
scip_accuracy_results = numpy.array(scip_accuracy_results)
no_latency_results = numpy.array(no_latency_results)
no_accuracy_results = numpy.array(no_accuracy_results)

# %% [markdown]
# Results indicate that the SCIP model predicts latency very well, but the numerical optimiser is dramatically overestimating. This is possibly due to how invalid model values are being handled before being given to the partitioner.
#
# Beyond the model sources of error, there is the path rounding off which has a disproportionate impact due to the distributed nature of the calculation.
#
# ~~Another important point is that the accuracy region of interest should be where using the cluster makes sense from a common sense point of view, i.e. where the proportional allocation latency is less than the best platform latency. It is useful however to show this counter-intuitive result.~~

# %%
print no_missing_tasks
# Out:
# [[122], [104], [99, 122], [], [8, 16, 62, 68, 71, 87, 90, 94, 99, 104, 108, 121, 122], [62, 66, 68, 87, 88, 90, 94, 99, 104, 121, 122], [94, 95, 99, 121, 122], [8, 95, 99, 104, 121], [], []]

# %%
start_offset = 2
ax = plt.gca()
corrected_scip_cost = numpy.copy(scip_cost)
corrected_no_cost = numpy.copy(num_opt_cost)

for i,target_accuracy in enumerate(accuracy_range[:-1]):
    setup_cost_matrix,pp_cost_matrix = cost_matrices[i]
    for smt in scip_missing_tasks[i]:
        corrected_scip_cost[i] -= allocation_cost(scip_allocations[i,:,smt],pp_cost_matrix[:,smt],setup_cost_matrix[:,smt],len(platforms),1)

    for nomt in no_missing_tasks[i]:
        corrected_no_cost[i] -= allocation_cost(numerical_optimiser_allocations[i,:,nomt],pp_cost_matrix[:,nomt],setup_cost_matrix[:,nomt],len(platforms),1)
        
#print(num_opt_cost-corrected_no_cost)
#print(scip_missing_tasks)
    
ax.plot(corrected_scip_cost[start_offset:],accuracy_range[start_offset:],"--o",label="SCIP Model")
ax.plot(prop_cost[start_offset:],accuracy_range[start_offset:],"--o",label="Proportional Model")
ax.plot(corrected_no_cost[start_offset:],accuracy_range[start_offset:],"--o",label="Numerical Optimiser Model")
#plt.plot(best_platform_cost[:],accuracy_range[:],"--o",label="Best Platform Model")

number_tasks = numpy.array([len(tasks) - len(smt) for smt in scip_missing_tasks[start_offset:]])
latency_confidence_interval = 0#scip_latency_results[start_offset:,2]/(number_tasks)**0.5
accuracy_confidence_interval = 1.645*scip_accuracy_results[start_offset:,2]/(number_tasks)**0.5

#ax.plot(scip_latency_results[start_offset:,1]+latency_confidence_interval,scip_accuracy_results[start_offset:,1]+accuracy_confidence_interval,"-x",label="SCIP Verification Upper")
#ax.plot(scip_latency_results[start_offset:,1]-latency_confidence_interval,scip_accuracy_results[start_offset:,1]-accuracy_confidence_interval,"-x",label="SCIP Verification Lower")

#ax.plot(scip_cost[start_offset:],scip_accuracy_results[start_offset:,1],"-x",label="SCIP Accuracy Mean")
#ax.plot(scip_latency_results[start_offset:,3],accuracy_range[start_offset:],"-x",label="SCIP Latency Mean")
ax.plot(scip_latency_results[start_offset:,3],scip_accuracy_results[start_offset:,1],"-x",label="SCIP Latency Verification Mean")

#plt.plot(corrected_scip_cost[:],scip_accuracy_results[:,1],"-x",label="SCIP Accuracy Verification Mean")


#plt.plot(scip_latency_results[:,0],scip_accuracy_results[:,0],"--",label="SCIP Verification Min")
#plt.plot(scip_latency_results[:,3],scip_accuracy_results[:,3],"--",label="SCIP Verification Max")

#latency_confidence_interval = 1.96*no_latency_results[:,2]/len(no_latency_results[:,2])**0.5
#accuracy_confidence_interval = 1.96*no_accuracy_results[:,2]/len(no_accuracy_results[:,2])**0.5

#plt.plot(no_latency_results[:,1]+latency_confidence_interval,no_accuracy_results[:,1]+accuracy_confidence_interval,"-x",label="Numerical Optimiser Verification Upper")
#plt.plot(no_latency_results[:,1]-latency_confidence_interval,no_accuracy_results[:,1]-accuracy_confidence_interval,"-x",label="Numerical Optimiser Verification Lower")

#no_accuracy_results[:,1]
ax.plot(no_latency_results[start_offset:,3],no_accuracy_results[start_offset:,1],"-x",label="Numerical Optimiser Verification Mean")
#plt.plot(no_latency_results[:,1],accuracy_range[:],"-x",label="Numerical Optimiser Latency Verification Mean")
#plt.plot(num_opt_cost[:],no_accuracy_results[:,1],"-x",label="Numerical Optimiser Accuracy Verification Mean")

ax.plot(prop_latency_results[start_offset:,3],prop_accuracy_results[start_offset:,1],"-x",label="Proportional Verification Mean")

ax.set_xlabel("Latency(S)")
ax.set_xscale('log')

ax.set_ylabel("Accuracy ($)")
ax.set_yscale('log')

ax.grid()

fig = plt.gcf()
fig.set_size_inches(18.5,10.5)

plt.legend(loc='best')

# %% [markdown]
# ### Outputting Results

# %%
with open('partitioner_verification_data_output_seed4_13000_4.csv','w') as verification_file:
    csvwriter = csv.writer(verification_file,delimiter=',')
    
    csvwriter.writerow(['Partitioner','Latency Min','Latency Mean','Latency Std','Latency Max','Accuracy Min','Accuracy Mean','Accuracy Std','Accuracy Max'])
    for scip_latency,scip_accuracy in zip(scip_latency_results,scip_accuracy_results):
        results = ['SCIP Verification']
        results += scip_latency
        results += scip_accuracy
        
        csvwriter.writerow(results)
        
    for no_latency,no_accuracy in zip(no_latency_results,no_accuracy_results):
        results = ['NO Verification']
        results += no_latency
        results += no_accuracy
        
        csvwriter.writerow(results)
        
    for prop_latency,prop_accuracy in zip(prop_latency_results,prop_accuracy_results):
        results = ['Prop Verification']
        results += prop_latency
        results += prop_accuracy
        
        csvwriter.writerow(results)

# %%
with open('partitioner_model_data_output_seed4_13000_2.csv','w') as model_file:
    csvwriter = csv.writer(model_file,delimiter=',')
    
    csvwriter.writerow(['Partitioner','Latency','Accuracy'])
    for accuracy,scip,prop,no in zip(accuracy_range,scip_cost,prop_cost,num_opt_cost):
        scip_model_results = ['SCIP Model']
        scip_model_results += [scip,accuracy]
        csvwriter.writerow(scip_model_results)
        
        prop_model_results = ['Proportional Model']
        prop_model_results += [prop,accuracy]
        csvwriter.writerow(prop_model_results)
        
        no_model_results = ['Numerical Optimiser Results']
        no_model_results += [no,accuracy]
        csvwriter.writerow(no_model_results)
